# %%
import pandas as pd

# %%
df_hosp = pd.read_csv("../../data/hospitals.csv")

# %%
#beds in New York
df_hosp[(df_hosp["STATE"]=="NY")&(df_hosp["BEDS"]>0)]["BEDS"].sum()
# Out:
# 57083

# %%
df_hosp.head()
# Out:
#             X          Y  OBJECTID        ID  \
# 0 -119.645667  36.336159         1   5793230
# 1 -118.815736  34.154939         2  53391362
# 2 -118.184165  34.023647         3  11190023
# 3 -118.325235  34.096391         4  17090028
# 4 -117.967438  34.063039         5  23691706
#
#                                                 NAME  \
# 0                    CENTRAL VALLEY GENERAL HOSPITAL
# 1  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 2                  EAST LOS ANGELES DOCTORS HOSPITAL
# 3          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 4                      KINDRED HOSPITAL BALDWIN PARK
#
#                      ADDRESS             CITY STATE    ZIP           ZIP4  \
# 0    1025 NORTH DOUTY STREET          HANFORD    CA  93230  NOT AVAILABLE
# 1             150 VIA MERIDA  WESTLAKE VILAGE    CA  91362  NOT AVAILABLE
# 2    4060 WHITTIER BOULEVARD      LOS ANGELES    CA  90023  NOT AVAILABLE
# ...

# %%
df_hosp.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'ID', 'NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP',
#        'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY',
#        'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE',
#        'NAICS_DESC', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE',
#        'WEBSITE', 'STATE_ID', 'ALT_NAME', 'ST_FIPS', 'OWNER', 'TTL_STAFF',
#        'BEDS', 'TRAUMA', 'HELIPAD'],
#       dtype='object')

# %%
df_hosp["COUNTRY"].unique()
# Out:
# array(['USA', 'PRI', 'VIR', 'GUM', 'MNP', 'PLW', 'ASM'], dtype=object)

# %%
df_hosp_all = df_hosp[["NAME", "ADDRESS", "CITY", "STATE", "ZIP", "TELEPHONE", "POPULATION", "COUNTY", "BEDS"]]

# %%
df_hosp_clean = df_hosp[df_hosp["COUNTRY"] == "USA"][["NAME","X","Y", "ADDRESS", "CITY", "STATE", "ZIP", "TELEPHONE", "POPULATION", "COUNTY", "BEDS"]]

# %%
df_hosp_clean = df_hosp_clean[df_hosp_clean["BEDS"] > 0]

# %%
df_hosp_clean
# Out:
#                                                    NAME           X  \
# 0                       CENTRAL VALLEY GENERAL HOSPITAL -119.645667
# 1     LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA... -118.815736
# 2                     EAST LOS ANGELES DOCTORS HOSPITAL -118.184165
# 3             SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD -118.325235
# 4                         KINDRED HOSPITAL BALDWIN PARK -117.967438
# ...                                                 ...         ...
# 7576     WILLIAM J MCCORD ADOLESCENT TREATMENT FACILITY  -80.822206
# 7577                    HAYWOOD PARK COMMUNITY HOSPITAL  -89.242977
# 7578            CENTRA HEALTH VIRGINIA BAPTIST HOSPITAL  -79.187842
# 7579    HEALTHSOUTH REHABILITATION HOSPITAL OF FLORENCE  -79.754976
# 7580   HEALTHSOUTH REHABILITATION HOSPITAL OF ROCK HILL  -81.052591
#
#               Y                       ADDRESS             CITY STATE    ZIP  \
# ...

# %%
df_hosp_all
# Out:
#                                                    NAME  \
# 0                       CENTRAL VALLEY GENERAL HOSPITAL
# 1     LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 2                     EAST LOS ANGELES DOCTORS HOSPITAL
# 3             SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 4                         KINDRED HOSPITAL BALDWIN PARK
# ...                                                 ...
# 7576     WILLIAM J MCCORD ADOLESCENT TREATMENT FACILITY
# 7577                    HAYWOOD PARK COMMUNITY HOSPITAL
# 7578            CENTRA HEALTH VIRGINIA BAPTIST HOSPITAL
# 7579    HEALTHSOUTH REHABILITATION HOSPITAL OF FLORENCE
# 7580   HEALTHSOUTH REHABILITATION HOSPITAL OF ROCK HILL
#
#                            ADDRESS             CITY STATE    ZIP  \
# 0          1025 NORTH DOUTY STREET          HANFORD    CA  93230
# 1                   150 VIA MERIDA  WESTLAKE VILAGE    CA  91362
# 2          4060 WHITTIER BOULEVARD      LOS ANGELES    CA  90023
# ...

# %%
df_hosp_clean["BEDS"].sum()
# Out:
# 1007161

# %%
df_hosp_all["BEDS"].sum()
# Out:
# 352772

# %%
df_hosp["BEDS"].describe()
# Out:
# count    7581.000000
# mean       46.533703
# std       364.693889
# min      -999.000000
# 25%        25.000000
# 50%        66.000000
# 75%       178.000000
# max      1592.000000
# Name: BEDS, dtype: float64

# %%
df_hosp[df_hosp["BEDS"] < 0]
# Out:
#                X          Y  OBJECTID         ID  \
# 19    -82.005057  30.845275        20    1931537
# 21    -90.749306  29.620861        22    2070364
# 44    -92.481988  31.252192        45  159171301
# 45    -93.250350  30.181132        46  159670605
# 46    -92.114554  32.499821        47  160270505
# ...          ...        ...       ...        ...
# 7389  -79.410028  36.554757      6809   20324541
# 7457  -76.740598  37.255513      6877   13623185
# 7467  -77.308405  38.512653      6887   16222134
# 7497 -123.081708  44.046021      6917    4397401
# 7515 -122.216761  47.975593      6935    5198206
#
#                                                    NAME              ADDRESS  \
# 19                           CHARLTON MEMORIAL HOSPITAL    2449 THIRD STREET
# 21                   COMPASS BEHAVIORAL CENTER OF HOUMA      4701 W PARK AVE
# 44              COMPASS BEHAVIORAL CENTER OF ALEXANDRIA   6410 MASONIC DRIVE
# ...

# %%
df_hosp_clean
# Out:
#                                                    NAME           X  \
# 0                       CENTRAL VALLEY GENERAL HOSPITAL -119.645667
# 1     LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA... -118.815736
# 2                     EAST LOS ANGELES DOCTORS HOSPITAL -118.184165
# 3             SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD -118.325235
# 4                         KINDRED HOSPITAL BALDWIN PARK -117.967438
# ...                                                 ...         ...
# 7576     WILLIAM J MCCORD ADOLESCENT TREATMENT FACILITY  -80.822206
# 7577                    HAYWOOD PARK COMMUNITY HOSPITAL  -89.242977
# 7578            CENTRA HEALTH VIRGINIA BAPTIST HOSPITAL  -79.187842
# 7579    HEALTHSOUTH REHABILITATION HOSPITAL OF FLORENCE  -79.754976
# 7580   HEALTHSOUTH REHABILITATION HOSPITAL OF ROCK HILL  -81.052591
#
#               Y                       ADDRESS             CITY STATE    ZIP  \
# ...

# %%
df_hosp_clean.to_json("hospitals.json", orient="records")

# %%
df_hosp_clean.columns
# Out:
# Index(['NAME', 'X', 'Y', 'ADDRESS', 'CITY', 'STATE', 'ZIP', 'TELEPHONE',
#        'POPULATION', 'COUNTY', 'BEDS'],
#       dtype='object')

# %%
df_hosp_clean.groupby("STATE")["BEDS"].sum()
# Out:
# STATE
# AK      1813
# AL     19000
# AR     11699
# AZ     15452
# CA    104034
# CO     11899
# CT      9451
# DC      4304
# DE      2780
# FL     72088
# GA     30778
# HI      3365
# IA     13785
# ID      3802
# IL     35811
# IN     19415
# KS     11261
# KY     18497
# LA     18413
# MA     20882
# MD     13557
# ME      4470
# MI     26632
# MN     15778
# MO     24026
# MS     15020
# MT      4126
# NC     27175
# ND      3878
# NE      7394
# NH      3398
# NJ     31359
# NM      5132
# NV      7771
# NY     57083
# OH     49177
# OK     15177
# OR      7624
# PA     46167
# RI      3985
# SC     15056
# SD      3407
# TN     25551
# TX     91310
# UT      6110
# VA     22196
# VT      1468
# WA     15873
# WI     19131
# WV      7772
# WY      1829
# Name: BEDS, dtype: int64

# %%
df_hosp_PR= df_hosp[df_hosp["COUNTRY"] == "PRI"][["NAME","X","Y", "ADDRESS", "CITY", "STATE", "ZIP", "TELEPHONE", "POPULATION", "COUNTY", "BEDS"]]
df_hosp_PR = df_hosp_PR[df_hosp_PR["BEDS"] > 0]
df_hosp_PR["BEDS"].sum()
# Out:
# 6334
