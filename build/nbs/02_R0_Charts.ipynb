# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
R0 = 2
base = 8

# %%
vals5 = np.logspace(3, 3+(40/5), num=40, base=2)
vals6 = np.logspace(3, 3+(40/6), num=40, base=2)
vals7 = np.logspace(3, 3+(40/7), num=40, base=2)
vals8 = np.logspace(3, 3+(40/8), num=40, base=2)
vals9 = np.logspace(3, 3+(40/9), num=40, base=2)

# %%
vals
# Out:
# [16, 32, 64, 128, 256, 512, 1024, 2048, 4096]

# %%
dfStyler = df.style.set_properties(**{'text-align': 'center'})
dfStyler.set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
# Out:
# <style  type="text/css" >
#     #T_101a3490_64cb_11ea_b757_708bcd9db679 th {
#           text-align: center;
#     }    #T_101a3490_64cb_11ea_b757_708bcd9db679row0_col0 {
#             text-align:  center;
#         }    #T_101a3490_64cb_11ea_b757_708bcd9db679row0_col1 {
#             text-align:  center;
#         }    #T_101a3490_64cb_11ea_b757_708bcd9db679row0_col2 {
#             text-align:  center;
#         }    #T_101a3490_64cb_11ea_b757_708bcd9db679row1_col0 {
#             text-align:  center;
#         }    #T_101a3490_64cb_11ea_b757_708bcd9db679row1_col1 {
#             text-align:  center;
#         }    #T_101a3490_64cb_11ea_b757_708bcd9db679row1_col2 {
#             text-align:  center;
#         }    #T_101a3490_64cb_11ea_b757_708bcd9db679row2_col0 {
#             text-align:  center;
#         }    #T_101a3490_64cb_11ea_b757_708bcd9db679row2_col1 {
#             text-align:  center;
#         }    #T_101a3490_64cb_11ea_b757_708bcd9db679row2_col2 {
# ...

# %%
plt.scatter(range(0,40), vals5, label="5 Days")
plt.scatter(range(0,40), vals6, label="6 Days")
plt.scatter(range(0,40), vals7, label="7 Days")
plt.scatter(range(0,40), vals8, label="8 Days")
plt.scatter(range(0,40), vals9, label="9 Days")
plt.xlabel("Number of Days",fontsize='large')
plt.ylabel("Number of Infections",fontsize='large')
plt.legend(title="Doubling Time", fontsize='large')
plt.show()
# total = [vals5, vals6, vals7, vals8, vals9]
days = list(range(5,10))
total= [int(vals5[-1]), int(vals6[-1]), int(vals7[-1]), int(vals8[-1]), int(vals9[-1])]
new_cases = [int(vals5[-1]-vals5[-2]), int(vals6[-1]-vals6[-2]), int(vals7[-1]-vals7[-2]), int(vals8[-1]-vals8[-2]), int(vals9[-1]-vals9[-2])]
df=pd.DataFrame(list(zip(days, total, new_cases)), columns=["Doubling Time in Days", "Total Cases", "New Cases on Last Day"])
heading_properties = [('font-size', '18px')]
df
# Out:
#    Doubling Time in Days  Total Cases  New Cases on Last Day
# 0                      5         2048                    271
# 1                      6          812                     90
# 2                      7          420                     40
# 3                      8          256                     21
# 4                      9          174                     13

# %%
vals4[-1]
# Out:
# 8192.0

# %%
plt.plot(range(1,8), vals_2)
plt.plot(range(1,8), vals_175)
plt.plot(range(1,8), vals_15)
plt.plot(range(1,8), vals_225)
plt.plot(range(1,8), vals_25)
plt.xlabel("Number of Periods")
plt.xlabel("Number of Infections")
# Out:
# Text(0.5, 0, 'Number of Infections')

# %%
plt.rcParams["figure.figsize"] = (12,8)
