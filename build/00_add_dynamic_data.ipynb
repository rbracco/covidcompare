# %%
import pandas as pd
import json, requests
import math
import numpy as np
from pathlib import Path
from collections import defaultdict
import datetime
import shutil
import logging

# %% [markdown]
# ## General Setup

# %% [markdown]
# ### Read in static data

# %%
county_data_folder = Path('static_data/county')
with open(county_data_folder/"staticCounties.json", 'r') as f:
    county_json = json.load(f)

# %%
state_data_folder = Path('static_data/state')
with open(state_data_folder/"staticStates.json", 'r') as f:
    state_json = json.load(f)

# %% [markdown]
# We make one request that will be parsed once for State Data and once for county

# %%
def request_multiple_attempts(url):
    #print_and_log(f"Requesting data from {url}")
    num_requests = 0
    max_requests = 5
    req = requests.get(api_url)
    if(not req.status_code == 200):
        num_requests += 1 
        if(num_requests >= max_requests): req.raise_for_status()
        req = requests.get(api_url)
    #print_and_log("Data Received\n")
    return req

# %% [markdown]
# ### Go through the county_json records and index by geo_id

# %%
geo_id_index_dict = {}
counties = county_json["features"]
for idx, county in enumerate(counties):
    geo_id = county["properties"]["geo_id"]
    geo_id_index_dict[geo_id] = idx

# %% [markdown]
# ### Setup logging

# %%
now = datetime.datetime.now()
date_str = f"{now.month}-{now.day}-{now.year}-{now.hour}{now.minute}"

# %%
logging.basicConfig(filename=f'logs/message_logs/{date_str}.log',level=logging.DEBUG)

# %%
def print_and_log(message):
    logging.info(message)
    print(message)

# %% [markdown]
# ## Add new data from APIs

# %% [markdown]
# ### Add State Covid19 data from John's Hopkins

# %%
#data from John Hopkins CSSE
api_url = "https://covid19.mathdro.id/api/countries/USA/confirmed"
covid_jh = request_multiple_attempts(api_url).json()

# %% [markdown]
# #### Test that data appears to be valid

# %%
# there should be at least 1700 counties
num_counties = len(covid_jh)
if (num_counties < 1700): raise ValueError("Only", num_counties, " counties found in Johns Hopkins data")
mandatory_keys = ['fips', 'confirmed', 'recovered', 'deaths', 'active', 'combinedKey', 'provinceState']
for key in mandatory_keys:
    if not key in covid_jh[120]: raise ValueError("John's Hopkins Record missing key: ", key)

# %%
covid_jh[0].keys()
# Out:
# dict_keys(['provinceState', 'countryRegion', 'lastUpdate', 'lat', 'long', 'confirmed', 'recovered', 'deaths', 'active', 'admin2', 'fips', 'combinedKey', 'incidentRate', 'peopleTested'])

# %%
#includes ms which fromtimestamp doesnt accept so we cut it off
def get_str_from_timestamp(timestamp):
    timestamp = int(str(timestamp)[:-3])
    cur = datetime.datetime.fromtimestamp(timestamp)
    return cur.strftime('%#m/%d %#I:%M%p')

# %%
#initialize all state case data to 0
null_dict = {"cases":0, "deaths":0, "active":0, "recovered":0}
for state in state_json["features"]:
    state["properties"].update(null_dict)

# %%
keys = ["deaths", "recovered", "active"]
def add_record_to_state(record):
    for state in state_json["features"]:
        if(record["provinceState"] == state["properties"]["statename"]):
            for key in keys:
                state["properties"][key] += int(record[key])
            state["properties"]["cases"] += int(record["confirmed"])
            state["properties"]["time_cases_update"] = get_str_from_timestamp(record["lastUpdate"])
            return
    print_and_log(f"{record} unmatched")

# %%
def add_unassigned_to_state(statename, record):
    for state in state_json["features"]:
        props = state["properties"]
        if(props["statename"].lower() == statename.lower()):
            print_and_log(f'{record["confirmed"]} unassigned cases added to {statename}')
            props["unassigned_cases"] = record["confirmed"]
            props["unassigned_deaths"] = record["deaths"]

# %%
skips = ["Diamond Princess, US", "Guam, US", "Grand Princess, US", "Puerto Rico, US", "Virgin Islands, US"]
for record in covid_jh:
    if(record == {}): continue
    if record["combinedKey"] in skips: continue
    county, state, _ = map(str.strip, record["combinedKey"].split(','))
    if county == "Unassigned":
        add_unassigned_to_state(state, record)
    add_record_to_state(record)
# Out:
# 1984 unassigned cases added to New Jersey
# 303 unassigned cases added to Massachusetts
# 207 unassigned cases added to Georgia
# 172 unassigned cases added to Tennessee
# 136 unassigned cases added to Colorado
# 129 unassigned cases added to Virginia
# 93 unassigned cases added to Nevada
# 90 unassigned cases added to Kentucky
# 71 unassigned cases added to Rhode Island
# 55 unassigned cases added to Wisconsin
# 32 unassigned cases added to Arkansas
# 22 unassigned cases added to Michigan
# 16 unassigned cases added to Louisiana
# 6 unassigned cases added to Vermont
# 5 unassigned cases added to Hawaii
# 3 unassigned cases added to Maine
# 3 unassigned cases added to Maine
# 1 unassigned cases added to Minnesota

# %% [markdown]
# ### Add County Covid Data19 from John's Hopkins

# %%
#initialize all county case data to 0
for county in counties:
    county["properties"].update(null_dict)

# %%
skips = ["Diamond Princess, US", "Guam, US", "Grand Princess, US", "Puerto Rico, US", "Virgin Islands, US"]
missing_fips = {
    "Dona Ana,New Mexico,US":"35013", 
    "Kansas City,Missouri,US":"29095", 
    "Dukes and Nantucket,Massachusetts,US":"25007"
}

# %%
def add_record_to_county(record):
    if("Unassigned" in record["combinedKey"]): return
    #sub in countyid for counties that have missing county id
    if(record["combinedKey"] in missing_fips): 
        record["fips"] = missing_fips[record["combinedKey"]]
    #skip anything without a countyID
    if(record['fips'] is None):
        print_and_log(f'No geo_id, skipping {record["combinedKey"]}')
        return
    #skip anything in the skip list
    if(record["combinedKey"] in skips): return
    geo_id = '0500000US' + record["fips"]
    
    county = counties[geo_id_index_dict[geo_id]]
    #Add the contents of record to the county
    for key in keys:
        county["properties"][key] += int(record[key])
    county["properties"]["cases"] += int(record["confirmed"])
    county["properties"]["time_cases_update"] = get_str_from_timestamp(record["lastUpdate"])

# %%
for record in covid_jh:
    add_record_to_county(record)
# Out:
# No geo_id, skipping Out of TN,Tennessee,US
# No geo_id, skipping Puerto Rico, US
# No geo_id, skipping Out of UT,Utah,US
# No geo_id, skipping Out of MI,Michigan,US

# %% [markdown]
# #### Reassign NYC to the proper counties

# %%
new_york_county = counties[geo_id_index_dict['0500000US36061']]
queens_county = counties[geo_id_index_dict['0500000US36081']]
ny_cases = new_york_county["properties"]["cases"]
ny_deaths = new_york_county["properties"]["deaths"]
ny_time_updated = new_york_county["properties"]["time_cases_update"]
queens_cases = queens_county["properties"]["cases"]
nyc_reassignment_needed = ny_cases > 0 and queens_cases == 0
if(ny_cases <= 0 or not isinstance(ny_cases, int)): raise ValueError("Problem with NYCases, value:", ny_cases)
print_and_log(f"{ny_cases} cases initially in New York County")
print_and_log(f"{queens_cases} in queens.")
print_and_log(f"Reassign needed: {nyc_reassignment_needed}")
# Out:
# 26697 cases initially in New York County
# 0 in queens.
# Reassign needed: True

# %%
# This is based on an estimate on 3/21/20 in which NYC had 5687 cases broken down as follows
# this has since been updated on 3/26/20 for data from here: 
# https://www1.nyc.gov/assets/doh/downloads/pdf/imm/covid-19-daily-data-summary.pdf
# https://www1.nyc.gov/assets/doh/downloads/pdf/imm/covid-19-daily-data-summary-deaths.pdf
# # Kings - 1750, Queens - 1514, New York 1402, Bronx 736, Richmond 285
cases_proportion_dict = {
    #code:proportion of NYC cases
    #queens
    '0500000US36081':.32139,
    #kings
    '0500000US36047':.26191,
    #Bronx
    '0500000US36005':.17731,
    #Richmond (Staten Island)
    '0500000US36085':.05837,
    #New York (Manhattan)
    '0500000US36061':.18102,
}
deaths_proportion_dict = {
    #code:proportion of NYC cases
    #queens
    '0500000US36081':.33,
    #kings
    '0500000US36047':.23,
    #Bronx
    '0500000US36005':.21,
    #Richmond (Staten Island)
    '0500000US36085':.08,
    #New York (Manhattan)
    '0500000US36061':.15,
}
# #get cases that were all aggregated in NY county

# %%
ny_county_names = {
    '0500000US36081':'Queens County',
    '0500000US36047':'Kings County',
    '0500000US36005':'Bronx County',
    '0500000US36085':'Richmond County',
    '0500000US36061':'Manhattan',
}

# %%
print_and_log(f"\nTotal Cases listed for New York County {ny_cases}")
if(nyc_reassignment_needed):
    print_and_log("Reassigning NYC with proportional estimates")
    for county in counties:
        county_id = county["properties"]["geo_id"]
        if county_id in cases_proportion_dict.keys():
            county["properties"]["cases"] = int(ny_cases*cases_proportion_dict[county_id])
            county["properties"]["deaths"] = int(ny_deaths*deaths_proportion_dict[county_id])
            county["properties"]["time_cases_update"] = ny_time_updated
            county["properties"]["notes"] = "Data for this county is estimated"
else:
    print_and_log("\nQueens County found, not estimating NYC")
# Out:
# Total Cases listed for New York County 26697
# Reassigning NYC with proportional estimates

# %% [markdown]
# ### Add Covid Test Data from Covid Tracking Project

# %%
def format_test_time(test_time):
    d, h = test_time.split(' ')
    h, m = h.split(":")
    h = int(h)
    am_pm = "AM" if h <= 12 else "PM"
    if(am_pm) == "pm": h-=12
    return f"{d} {h}:{m}{am_pm}"

# %%
#https://covidtracking.com/api/states/info <- this api has info about where the data comes from
api_url = 'https://covidtracking.com/api/states'
state_tests = request_multiple_attempts(api_url).json()

# %% [markdown]
# #### Test that data appears to be valid

# %%
# there should be at least 50 entries
num_states = len(state_tests)
if (num_states < 50): raise ValueError("Only", num_states, " states found in covidtracking testing data")
mandatory_keys = ['state', 'lastUpdateEt', 'positive', 'negative', 'total']
for key in mandatory_keys:
    if not key in state_tests[20]: raise ValueError("CovidTracking testing missing key: ", key)

# %%
state_tests[20]
# Out:
# {'state': 'MD',
#  'positive': 992,
#  'positiveScore': 1,
#  'negativeScore': 1,
#  'negativeRegularScore': 1,
#  'commercialScore': 1,
#  'grade': 'A',
#  'score': 4,
#  'negative': 11516,
#  'pending': None,
#  'hospitalized': 226,
#  'death': 5,
#  'total': 12508,
#  'lastUpdateEt': '3/28 10:00',
#  'checkTimeEt': '3/28 10:16',
#  'totalTestResults': 12508,
#  'fips': '24',
#  'dateModified': '2020-03-28T14:00:00Z',
#  'dateChecked': '2020-03-28T14:16:00Z',
#  'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.'}

# %%
for state1 in state_tests:
    if(state1 == {}): continue
    for state2 in state_json["features"]:
        if(state1["state"] == state2["properties"]["abbr"]):
            state2["properties"]["time_tests_updated"] = format_test_time(state1["lastUpdateEt"])
            state2["properties"]["test_grade"] = state1["grade"]
            testing_keys = ["test_positive", "test_negative", "test_total"]
            for key in testing_keys:
                state2["properties"][key] = state1[key.split('_')[1]]

# %% [markdown]
# ## Per Capita Calculations and Data

# %%
print_and_log("\nAdding per capita stats for county")
for county in counties:
    props = county["properties"]
    per_cap = props["population"]/100000
    props["pc_cases"] = props["cases"]/per_cap
    props["pc_deaths"] = props["deaths"]/per_cap
# Out:
# Adding per capita stats for county

# %%
print_and_log("Adding per capita stats for states")
for state in state_json["features"]:
    props = state["properties"]
    per_cap = props["population"]/100000
    props["pc_cases"] = props["cases"]/per_cap
    props["pc_active"] = props["active"]/per_cap
    props["pc_deaths"] = props["deaths"]/per_cap
    props["pc_tests"] = props["test_total"]/per_cap
# Out:
# Adding per capita stats for states

# %% [markdown]
# ## Time Series Data

# %% [markdown]
# ### Add County time series

# %%
with open(county_data_folder/'countyTimeData.json', 'r') as f:
    county_time_data = json.load(f)

# %% [markdown]
# #### Add today's data to time series

# %% [markdown]
# Note we wont display this in time series until tomorrow becauseit makes it look like curve is flattening

# %%
today = datetime.datetime.today()
todays_date = f"{today.month}-{today.day}-{today.year}"
print_and_log(f"Adding time series for today: {todays_date}")
# Out:
# Adding time series for today: 3-28-2020

# %%
counties
# Out:
# [{'type': 'Feature',
#   'properties': {'geo_id': '0500000US01001',
#    'county': '001',
#    'name': 'Autauga',
#    'lsad': 'County',
#    'censusarea': 594.436,
#    'state': '01',
#    'statename': 'Alabama',
#    'stateabbr': 'AL',
#    'population': 55601,
#    'land_area': '594.44',
#    'housing_units': '22135',
#    'population_density': 93.53509185115402,
#    'lat': -86.64274644826507,
#    'long': 32.53492681419619,
#    'cases': 6,
#    'deaths': 0,
#    'active': 6,
#    'recovered': 0,
#    'time_cases_update': '3/28 12:15PM',
#    'pc_cases': 10.791172820632722,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-86.496774, 32.344437],
#      [-86.717897, 32.402814],
#      [-86.814912, 32.340803],
#      [-86.890581, 32.502974],
#      [-86.917595, 32.664169],
#      [-86.71339, 32.661732],
#      [-86.714219, 32.705694],
#      [-86.413116, 32.707386],
#      [-86.411172, 32.409937],
#      [-86.496774, 32.344437]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US01009',
#    'county': '009',
#    'name': 'Blount',
#    'lsad': 'County',
#    'censusarea': 644.776,
#    'state': '01',
#    'statename': 'Alabama',
#    'stateabbr': 'AL',
#    'population': 57840,
#    'land_area': '644.78',
#    'housing_units': '23887',
#    'population_density': 89.70501566425759,
#    'lat': -86.5673817538303,
#    'long': 33.98086991880072,
#    'cases': 5,
#    'deaths': 0,
#    'active': 5,
#    'recovered': 0,
#    'time_cases_update': '3/28 12:15PM',
#    'pc_cases': 8.644536652835408,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-86.577799, 33.765316],
#      [-86.759144, 33.840617],
#      [-86.953664, 33.815297],
#      [-86.954305, 33.844862],
#      [-86.96296, 33.844865],
#      [-86.963358, 33.858221],
#      [-86.924387, 33.909222],
#      [-86.793914, 33.952059],
#      [-86.685365, 34.05914],
#      [-86.692061, 34.092654],
#      [-86.599632, 34.119914],
#      [-86.514881, 34.25437],
#      [-86.45302, 34.259317],
#      [-86.303516, 34.099073],
#      [-86.332723, 33.986109],
#      [-86.370152, 33.93977],
#      [-86.325622, 33.940147],
#      [-86.377532, 33.861706],
#      [-86.577528, 33.801977],
#      [-86.577799, 33.765316]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US01017',
#    'county': '017',
#    'name': 'Chambers',
#    'lsad': 'County',
#    'censusarea': 596.531,
#    'state': '01',
#    'statename': 'Alabama',
#    'stateabbr': 'AL',
#    'population': 33615,
#    'land_area': '596.53',
#    'housing_units': '17004',
#    'population_density': 56.35089601528842,
#    'lat': -85.39238174532437,
#    'long': 32.91447723862047,
#    'cases': 15,
#    'deaths': 0,
#    'active': 15,
#    'recovered': 0,
#    'time_cases_update': '3/28 12:15PM',
#    'pc_cases': 44.62293618920125,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-85.184131, 32.870525],
#      [-85.123421, 32.772248],
#      [-85.13204, 32.764211],
#      [-85.136776, 32.746512],
#      [-85.285043, 32.730731],
#      [-85.593151, 32.72853],
#      [-85.593177, 33.10734],
#      [-85.232378, 33.108077],
#      [-85.223261, 33.06258],
#      [-85.221868, 33.055538],
#      [-85.184131, 32.870525]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US01021',
#    'county': '021',
#    'name': 'Chilton',
#    'lsad': 'County',
#    'censusarea': 692.854,
#    'state': '01',
#    'statename': 'Alabama',
#    'stateabbr': 'AL',
#    'population': 44153,
#    'land_area': '692.85',
#    'housing_units': '19278',
#    'population_density': 63.72663635707585,
#    'lat': -86.7188216764018,
#    'long': 32.84785864838486,
#    'cases': 7,
#    'deaths': 0,
#    'active': 7,
#    'recovered': 0,
#    'time_cases_update': '3/28 12:15PM',
#    'pc_cases': 15.85396235816366,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-86.517344, 33.020566],
#      [-86.515959, 32.929361],
#      [-86.457015, 32.813899],
#      [-86.374974, 32.75358],
#      [-86.413335, 32.750591],
#      [-86.413116, 32.707386],
#      [-86.714219, 32.705694],
#      [-86.71339, 32.661732],
#      [-86.917595, 32.664169],
#      [-87.01766, 32.663269],
#      [-87.017762, 32.729532],
#      [-87.019157, 32.837034],
#      [-86.876118, 32.836264],
#      [-86.881182, 33.049901],
#      [-86.881638, 33.071861],
#      [-86.610003, 33.070003],
#      [-86.517344, 33.020566]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US01033',
#    'county': '033',
#    'name': 'Colbert',
#    'lsad': 'County',
#    'censusarea': 592.619,
#    'state': '01',
#    'statename': 'Alabama',
#    'stateabbr': 'AL',
#    'population': 54762,
#    'land_area': '592.62',
#    'housing_units': '25758',
#    'population_density': 92.40660119469474,
#    'lat': -87.80523718802779,
#    'long': 34.700286302662654,
#    'cases': 1,
#    'deaths': 0,
#    'active': 1,
#    'recovered': 0,
#    'time_cases_update': '3/28 12:15PM',
#    'pc_cases': 1.8260837807238597,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-88.139988, 34.581703],
#      [-88.139246, 34.587795],
#      [-88.138719, 34.589215],
#      [-88.118407, 34.724292],
#      [-88.097888, 34.892202],
#      [-87.973222, 34.88255],
#      [-87.835833, 34.741239],
#      [-87.524363, 34.832384],
#      [-87.42651, 34.800022],
#      [-87.416484, 34.767544],
#      [-87.529667, 34.567081],
#      [-88.139988, 34.581703]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US01045',
#    'county': '045',
#    'name': 'Dale',
#    'lsad': 'County',
#    'censusarea': 561.15,
#    'state': '01',
#    'statename': 'Alabama',
#    'stateabbr': 'AL',
#    'population': 48956,
#    'land_area': '561.15',
#    'housing_units': '22677',
#    'population_density': 87.24227033769937,
#    'lat': -85.6110548906156,
#    'long': 31.431778442739304,
#    'cases': 0,
#    'deaths': 0,
#    'active': 0,
#    'recovered': 0,
#    'pc_cases': 0.0,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-85.416437, 31.619466],
#      [-85.417434, 31.314973],
#      [-85.485854, 31.246096],
#      [-85.659985, 31.270889],
#      [-85.710866, 31.195179],
#      [-85.791402, 31.196349],
#      [-85.789142, 31.617964],
#      [-85.749941, 31.617914],
#      [-85.748251, 31.618048],
#      [-85.416437, 31.619466]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US01051',
#    'county': '051',
#    'name': 'Elmore',
#    'lsad': 'County',
#    'censusarea': 618.485,
#    'state': '01',
#    'statename': 'Alabama',
#    'stateabbr': 'AL',
#    'population': 81887,
#    'land_area': '618.48',
#    'housing_units': '32657',
#    'population_density': 132.40040098305522,
#    'lat': -86.14915267315266,
#    'long': 32.596636297144315,
#    'cases': 12,
#    'deaths': 0,
#    'active': 12,
#    'recovered': 0,
#    'time_cases_update': '3/28 12:15PM',
#    'pc_cases': 14.654340737846056,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-86.336776, 32.767469],
#      [-86.31948, 32.753698],
#      [-86.007187, 32.754984],
#      [-85.87986, 32.754528],
#      [-85.886148, 32.493053],
#      [-85.89442, 32.447578],
#      [-86.023012, 32.419978],
#      [-86.192284, 32.43613],
#      [-86.237068, 32.49498],
#      [-86.411172, 32.409937],
#      [-86.413116, 32.707386],
#      [-86.413335, 32.750591],
#      [-86.374974, 32.75358],
#      [-86.336768, 32.753783],
#      [-86.336776, 32.767469]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US01065',
#    'county': '065',
#    'name': 'Hale',
#    'lsad': 'County',
#    'censusarea': 643.943,
#    'state': '01',
#    'statename': 'Alabama',
#    'stateabbr': 'AL',
#    'population': 14726,
#    'land_area': '643.94',
#    'housing_units': '7655',
#    'population_density': 22.868590241326828,
#    'lat': -87.6291479166871,
#    'long': 32.76265564167777,
#    'cases': 0,
#    'deaths': 0,
#    'active': 0,
#    'recovered': 0,
#    'pc_cases': 0.0,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-87.4212, 32.874508],
#      [-87.472174, 32.83062],
#      [-87.473915, 32.655867],
#      [-87.525198, 32.655713],
#      [-87.524485, 32.482028],
#      [-87.728744, 32.480918],
#      [-87.812559, 32.52456],
#      [-87.736786, 32.58919],
#      [-87.813401, 32.633875],
#      [-87.796043, 32.715632],
#      [-87.828542, 32.768903],
#      [-87.870464, 32.762442],
#      [-87.715709, 33.006824],
#      [-87.421936, 33.003379],
#      [-87.420132, 32.902605],
#      [-87.4212, 32.874508]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US01079',
#    'county': '079',
#    'name': 'Lawrence',
#    'lsad': 'County',
#    'censusarea': 690.678,
#    'state': '01',
#    'statename': 'Alabama',
#    'stateabbr': 'AL',
#    'population': 32957,
#    'land_area': '690.68',
#    'housing_units': '15229',
#    'population_density': 47.716742920020856,
#    'lat': -87.31098627133326,
#    'long': 34.521679805079835,
#    'cases': 3,
#    'deaths': 0,
#    'active': 3,
#    'recovered': 0,
#    'time_cases_update': '3/28 12:15PM',
#    'pc_cases': 9.102770276420792,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-87.105073, 34.686037],
#      [-87.105913, 34.587643],
#      [-87.110111, 34.313799],
#      [-87.109911, 34.299299],
#      [-87.529722, 34.304598],
#      [-87.529667, 34.567081],
#      [-87.416484, 34.767544],
#      [-87.42651, 34.800022],
#      [-87.260676, 34.758626],
#      [-87.105073, 34.686037]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US01083',
#    'county': '083',
#    'name': 'Limestone',
#    'lsad': 'County',
#    'censusarea': 559.936,
#    'state': '01',
#    'statename': 'Alabama',
#    'stateabbr': 'AL',
#    'population': 96174,
#    'land_area': '559.94',
#    'housing_units': '34977',
#    'population_density': 171.75768832374897,
#    'lat': -86.98138197492098,
#    'long': 34.810095716199875,
#    'cases': 16,
#    'deaths': 0,
#    'active': 16,
#    'recovered': 0,
#    'time_cases_update': '3/28 12:15PM',
#    'pc_cases': 16.63651298687795,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-86.836306, 34.991764],
#      [-86.820657, 34.991764],
#      [-86.783648, 34.991925],
#      [-86.783628, 34.991925],
#      [-86.790056, 34.55079],
#      [-86.942899, 34.598053],
#      [-87.105073, 34.686037],
#      [-87.260676, 34.758626],
#      [-87.214914, 34.816011],
#      [-87.210759, 34.999024],
#      [-87.011174, 34.995162],
#      [-87.000007, 34.995121],
#      [-86.974412, 34.994513],
#      [-86.972613, 34.99461],
#      [-86.970236, 34.994546],
#      [-86.96712, 34.9944],
#      [-86.862147, 34.991956],
#      [-86.849794, 34.991924],
#      [-86.846466, 34.99186],
#      [-86.83637, 34.991764],
#      [-86.836306, 34.991764]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US01099',
#    'county': '099',
#    'name': 'Monroe',
#    'lsad': 'County',
#    'censusarea': 1025.675,
#    'state': '01',
#    'statename': 'Alabama',
#    'stateabbr': 'AL',
#    'population': 21067,
#    'land_area': '1025.67',
#    'housing_units': '11333',
#    'population_density': 20.539744752210748,
#    'lat': -87.36542316379226,
#    'long': 31.570845400479296,
#    'cases': 0,
#    'deaths': 0,
#    'active': 0,
#    'recovered': 0,
#    'pc_cases': 0.0,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-86.905899, 31.753035],
#      [-87.052284, 31.716761],
#      [-87.135051, 31.642417],
#      [-87.166581, 31.519561],
#      [-87.427455, 31.260386],
#      [-87.61589, 31.244458],
#      [-87.765152, 31.297346],
#      [-87.784796, 31.324672],
#      [-87.665572, 31.423166],
#      [-87.603137, 31.409556],
#      [-87.565413, 31.553573],
#      [-87.566841, 31.697115],
#      [-87.516131, 31.697824],
#      [-87.50093, 31.829251],
#      [-86.906899, 31.830628],
#      [-86.905899, 31.753035]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US01107',
#    'county': '107',
#    'name': 'Pickens',
#    'lsad': 'County',
#    'censusarea': 881.408,
#    'state': '01',
#    'statename': 'Alabama',
#    'stateabbr': 'AL',
#    'population': 19938,
#    'land_area': '881.41',
#    'housing_units': '9483',
#    'population_density': 22.62057385325785,
#    'lat': -88.08868793628486,
#    'long': 33.28083164279957,
#    'cases': 1,
#    'deaths': 0,
#    'active': 1,
#    'recovered': 0,
#    'time_cases_update': '3/28 12:15PM',
#    'pc_cases': 5.0155481994181965,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-88.291127, 33.399061],
#      [-88.277421, 33.512436],
#      [-88.276805, 33.516463],
#      [-88.274619, 33.534008],
#      [-87.946519, 33.524065],
#      [-87.85856, 33.525326],
#      [-87.840683, 33.524839],
#      [-87.837521, 33.153637],
#      [-88.026971, 33.063602],
#      [-88.171852, 32.99586],
#      [-88.340432, 32.991199],
#      [-88.304514, 33.28832],
#      [-88.291127, 33.399061]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US01121',
#    'county': '121',
#    'name': 'Talladega',
#    'lsad': 'County',
#    'censusarea': 736.775,
#    'state': '01',
#    'statename': 'Alabama',
#    'stateabbr': 'AL',
#    'population': 79828,
#    'land_area': '736.78',
#    'housing_units': '37088',
#    'population_density': 108.34713211542116,
#    'lat': -86.16589155378637,
#    'long': 33.380071468229374,
#    'cases': 4,
#    'deaths': 0,
#    'active': 4,
#    'recovered': 0,
#    'time_cases_update': '3/28 12:15PM',
#    'pc_cases': 5.010773162298943,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-86.17437, 33.104394],
#      [-86.226271, 33.104115],
#      [-86.491029, 33.102944],
#      [-86.503127, 33.179144],
#      [-86.35734, 33.296917],
#      [-86.378665, 33.390983],
#      [-86.281999, 33.509895],
#      [-86.235328, 33.494532],
#      [-86.145562, 33.679098],
#      [-86.050669, 33.67459],
#      [-85.994935, 33.586475],
#      [-85.794559, 33.585565],
#      [-85.796054, 33.55622],
#      [-85.796852, 33.541849],
#      [-85.85189, 33.498742],
#       [-136.762198, 58.286765],
#       [-136.784326, 58.290497],
#       [-136.857605, 58.31636],
#       [-136.848992, 58.328994],
#       [-136.946663, 58.393185],
#       [-136.986384, 58.404043],
#       [-137.009415, 58.408877],
#       [-137.018409, 58.409141],
#       [-137.078109, 58.397474],
#       [-137.111802, 58.392594],
#       [-137.134453, 58.406596],
#       [-137.180029, 58.429939],
#       [-137.239366, 58.453159],
#       [-137.25271, 58.456338],
#       [-137.278612, 58.459484],
#       [-137.295788, 58.466179],
#       [-137.408758, 58.515822],
#       [-137.497002, 58.557721],
#       [-137.568216, 58.587989],
#       [-137.608804, 58.601234],
#       [-137.632889, 58.599982],
#       [-137.67169, 58.615523],
#       [-137.680811, 58.621835],
#       [-137.676857, 58.64677],
#       [-137.683516, 58.660267],
#       [-137.687627, 58.664989],
#       [-137.795037, 58.724855],
#       [-137.87535, 58.757232],
#       [-137.901675, 58.765316],
# ...
#      [-90.636727, 42.518702],
#      [-90.636927, 42.513202],
#      [-90.640927, 42.508302],
#      [-90.655927, 42.491703],
#      [-90.656527, 42.489203],
#      [-90.656327, 42.483603],
#      [-90.654027, 42.478503],
#      [-90.646727, 42.471904],
#      [-90.624328, 42.458904],
#      [-90.559451, 42.430695],
#      [-90.477279, 42.383794],
#      [-90.474834, 42.381473],
#      [-90.665029, 42.382155],
#      [-90.665551, 42.294699],
#      [-90.89802, 42.295236],
#      [-91.130079, 42.295761],
#      [-91.132766, 42.645844],
#      [-90.897415, 42.645714],
#      [-90.896961, 42.674407]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US19069',
#    'county': '069',
#    'name': 'Franklin',
#    'lsad': 'County',
#    'censusarea': 581.972,
#    'state': '19',
#    'statename': 'Iowa',
#    'stateabbr': 'IA',
#    'population': 10124,
#    'land_area': '581.97',
#    'housing_units': '4894',
#    'population_density': 17.396085708885337,
#    'lat': -93.26247358504106,
#    'long': 42.73254383146262,
#    'cases': 0,
#    'deaths': 0,
#    'active': 0,
#    'recovered': 0,
#    'pc_cases': 0.0,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-93.498617, 42.908512],
#      [-93.025144, 42.907549],
#      [-93.027, 42.55681],
#      [-93.499485, 42.5577],
#      [-93.498617, 42.908512]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US19075',
#    'county': '075',
#    'name': 'Grundy',
#    'lsad': 'County',
#    'censusarea': 501.858,
#    'state': '19',
#    'statename': 'Iowa',
#    'stateabbr': 'IA',
#    'population': 12304,
#    'land_area': '501.86',
#    'housing_units': '5530',
#    'population_density': 24.516797513250708,
#    'lat': -92.79142800432362,
#    'long': 42.40186490700887,
#    'cases': 0,
#    'deaths': 0,
#    'active': 0,
#    'recovered': 0,
#    'pc_cases': 0.0,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-92.53351, 42.297001],
#      [-92.76809, 42.29668],
#      [-92.767463, 42.21014],
#      [-93.001674, 42.209267],
#      [-93.002902, 42.470638],
#      [-93.027, 42.55681],
#      [-92.5543, 42.555854],
#      [-92.53351, 42.297001]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US19077',
#    'county': '077',
#    'name': 'Guthrie',
#    'lsad': 'County',
#    'censusarea': 590.62,
#    'state': '19',
#    'statename': 'Iowa',
#    'stateabbr': 'IA',
#    'population': 10720,
#    'land_area': '590.62',
#    'housing_units': '5756',
#    'population_density': 18.15041820459856,
#    'lat': -94.50106567185207,
#    'long': 41.68375083738455,
#    'cases': 0,
#    'deaths': 0,
#    'active': 0,
#    'recovered': 0,
#    'pc_cases': 0.0,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-94.700629, 41.504148],
#      [-94.744204, 41.602185],
#      [-94.744876, 41.862394],
#      [-94.676942, 41.862994],
#      [-94.67542, 41.862895],
#      [-94.674259, 41.862657],
#      [-94.673119, 41.86265],
#      [-94.672368, 41.86289],
#      [-94.671695, 41.862828],
#      [-94.667977, 41.862682],
#      [-94.628724, 41.862763],
#      [-94.28034, 41.862999],
#      [-94.280057, 41.601312],
#      [-94.241593, 41.503679],
#      [-94.700629, 41.504148]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US19089',
#    'county': '089',
#    'name': 'Howard',
#    'lsad': 'County',
#    'censusarea': 473.248,
#    'state': '19',
#    'statename': 'Iowa',
#    'stateabbr': 'IA',
#    'population': 9187,
#    'land_area': '473.25',
#    'housing_units': '4367',
#    'population_density': 19.41257263602747,
#    'lat': -92.31720692346191,
#    'long': 43.35675675523317,
#    'cases': 0,
#    'deaths': 0,
#    'active': 0,
#    'recovered': 0,
#    'pc_cases': 0.0,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-92.553128, 43.5003],
#      [-92.464505, 43.500345],
#      [-92.448948, 43.50042],
#      [-92.408832, 43.500614],
#      [-92.40613, 43.500476],
#      [-92.388298, 43.500483],
#      [-92.368908, 43.500454],
#      [-92.279084, 43.500436],
#      [-92.277425, 43.500466],
#      [-92.198788, 43.500527],
#      [-92.178863, 43.500713],
#      [-92.103886, 43.500735],
#      [-92.08997, 43.500684],
#      [-92.079954, 43.500647],
#      [-92.079802, 43.500647],
#      [-92.080976, 43.212947],
#      [-92.554381, 43.212813],
#      [-92.553128, 43.5003]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US19093',
#    'county': '093',
#    'name': 'Ida',
#    'lsad': 'County',
#    'censusarea': 431.508,
#    'state': '19',
#    'statename': 'Iowa',
#    'stateabbr': 'IA',
#    'population': 6841,
#    'land_area': '431.51',
#    'housing_units': '3426',
#    'population_density': 15.853630275080532,
#    'lat': -95.51352629875969,
#    'long': 42.38691480560074,
#    'cases': 0,
#    'deaths': 0,
#    'active': 0,
#    'recovered': 0,
#    'pc_cases': 0.0,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-95.323497, 42.210932],
#      [-95.670822, 42.211408],
#      [-95.669265, 42.474645],
#      [-95.741821, 42.474865],
#      [-95.741611, 42.561285],
#      [-95.38801, 42.561742],
#      [-95.387445, 42.474796],
#      [-95.322357, 42.474737],
#      [-95.323497, 42.210932]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US19101',
#    'county': '101',
#    'name': 'Jefferson',
#    'lsad': 'County',
#    'censusarea': 435.51,
#    'state': '19',
#    'statename': 'Iowa',
#    'stateabbr': 'IA',
#    'population': 18381,
#    'land_area': '435.51',
#    'housing_units': '7594',
#    'population_density': 42.205689880829375,
#    'lat': -91.94888547175127,
#    'long': 41.03175522321235,
#    'cases': 0,
#    'deaths': 0,
#    'active': 0,
#    'recovered': 0,
#    'pc_cases': 0.0,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-91.945571, 41.163578],
#      [-91.83906, 41.161515],
#      [-91.715893, 41.162822],
#      [-91.718268, 40.900805],
#      [-92.179072, 40.89972],
#      [-92.179974, 41.162662],
#      [-91.945571, 41.163578]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US19103',
#    'county': '103',
#    'name': 'Johnson',
#    'lsad': 'County',
#    'censusarea': 614.04,
#    'state': '19',
#    'statename': 'Iowa',
#    'stateabbr': 'IA',
#    'population': 151260,
#    'land_area': '614.04',
#    'housing_units': '55967',
#    'population_density': 246.3357435997655,
#    'lat': -91.58810001535298,
#    'long': 41.67155020618314,
#    'cases': 58,
#    'deaths': 0,
#    'active': 58,
#    'recovered': 0,
#    'time_cases_update': '3/28 12:15PM',
#    'pc_cases': 38.344572259685314,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-91.829231, 41.511457],
#      [-91.831379, 41.861851],
#      [-91.366079, 41.860068],
#      [-91.366448, 41.598373],
#      [-91.368521, 41.423178],
#      [-91.483995, 41.423848],
#      [-91.52248, 41.511035],
#      [-91.829231, 41.511457]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US19107',
#    'county': '107',
#    'name': 'Keokuk',
#    'lsad': 'County',
#    'censusarea': 579.179,
#    'state': '19',
#    'statename': 'Iowa',
#    'stateabbr': 'IA',
#    'population': 10225,
#    'land_area': '579.18',
#    'housing_units': '4931',
#    'population_density': 17.654269829759315,
#    'lat': -92.17864192284254,
#    'long': 41.33645744741213,
#    'cases': 0,
#    'deaths': 0,
#    'active': 0,
#    'recovered': 0,
#    'pc_cases': 0.0,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-92.411995, 41.509548],
#      [-92.297494, 41.50979],
#      [-91.946043, 41.510749],
#      [-91.945571, 41.163578],
#      [-92.179974, 41.162662],
#      [-92.410233, 41.161942],
#      [-92.411995, 41.509548]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US19111',
#    'county': '111',
#    'name': 'Lee',
#    'lsad': 'County',
#    'censusarea': 517.518,
#    'state': '19',
#    'statename': 'Iowa',
#    'stateabbr': 'IA',
#    'population': 34055,
#    'land_area': '517.52',
#    'housing_units': '16205',
#    'population_density': 65.8042201267584,
#    'lat': -91.4792637338499,
#    'long': 40.64198868861343,
#    'cases': 0,
#    'deaths': 0,
#    'active': 0,
#    'recovered': 0,
#    'pc_cases': 0.0,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-91.409324, 40.812682],
#      [-91.182551, 40.7081],
#      [-91.112258, 40.696218],
#      [-91.122421, 40.670675],
#      [-91.138055, 40.660893],
#      [-91.185415, 40.638052],
#      [-91.18698, 40.637297],
#      [-91.197906, 40.636107],
#      [-91.218437, 40.638437],
#      [-91.253074, 40.637962],
#      [-91.306524, 40.626231],
#      [-91.339719, 40.613488],
#      [-91.348733, 40.609695],
#      [-91.359873, 40.601805],
#      [-91.405241, 40.554641],
#      [-91.406851, 40.547557],
#      [-91.404125, 40.539127],
#      [-91.384531, 40.530948],
#      [-91.369059, 40.512532],
#      [-91.364211, 40.500043],
#      [-91.36391, 40.490122],
#      [-91.372554, 40.4012],
#      [-91.375746, 40.391879],
#      [-91.38836, 40.384929],
#      [-91.419422, 40.378264],
#      [-91.484507, 40.3839],
#      [-91.490977, 40.393484],
#      [-91.524612, 40.410765],
#      [-91.619486, 40.507134],
#      [-91.622362, 40.514362],
#      [-91.618028, 40.53403],
#      [-91.620071, 40.540817],
#      [-91.696359, 40.588148],
#      [-91.716769, 40.59853],
#      [-91.718787, 40.813544],
#      [-91.409324, 40.812682]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US19127',
#    'county': '127',
#    'name': 'Marshall',
#    'lsad': 'County',
#    'censusarea': 572.501,
#    'state': '19',
#    'statename': 'Iowa',
#    'stateabbr': 'IA',
#    'population': 39981,
#    'land_area': '572.50',
#    'housing_units': '16831',
#    'population_density': 69.83580786026201,
#    'lat': -92.99876743679745,
#    'long': 42.035855387756456,
#    'cases': 1,
#    'deaths': 0,
#    'active': 1,
#    'recovered': 0,
#    'time_cases_update': '3/28 12:15PM',
#    'pc_cases': 2.501188064330557,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-92.765999, 41.862373],
#      [-93.231858, 41.862711],
#      [-93.231722, 42.208886],
#      [-93.001674, 42.209267],
#      [-92.767463, 42.21014],
#      [-92.765999, 41.862373]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US19129',
#    'county': '129',
#    'name': 'Mills',
#    'lsad': 'County',
#    'censusarea': 437.437,
#    'state': '19',
#    'statename': 'Iowa',
#    'stateabbr': 'IA',
#    'population': 15063,
#    'land_area': '437.44',
#    'housing_units': '6109',
#    'population_density': 34.43443672275055,
#    'lat': -95.62131418073272,
#    'long': 41.03343109725732,
#    'cases': 0,
#    'deaths': 0,
#    'active': 0,
#    'recovered': 0,
#    'pc_cases': 0.0,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-95.823123, 40.900924],
#      [-95.829074, 40.975688],
#      [-95.835434, 40.984184],
#      [-95.867286, 41.001599],
#      [-95.867246, 41.043671],
#      [-95.866289, 41.051731],
#      [-95.853396, 41.16028],
#      [-95.384349, 41.160011],
#      [-95.384964, 40.90155],
#      [-95.813465, 40.901693],
#      [-95.823123, 40.900924]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US19135',
#    'county': '135',
#    'name': 'Monroe',
#    'lsad': 'County',
#    'censusarea': 433.715,
#    'state': '19',
#    'statename': 'Iowa',
#    'stateabbr': 'IA',
#    'population': 7790,
#    'land_area': '433.72',
#    'housing_units': '3884',
#    'population_density': 17.960896430877064,
#    'lat': -92.8689926527406,
#    'long': 41.029801268854776,
#    'cases': 0,
#    'deaths': 0,
#    'active': 0,
#    'recovered': 0,
#    'pc_cases': 0.0,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-92.869771, 41.161066],
#      [-92.640361, 41.161298],
#      [-92.639091, 40.898886],
#      [-93.097595, 40.898451],
#      [-93.097724, 40.899738],
#      [-93.099217, 41.160867],
#      [-92.869771, 41.161066]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US19139',
#    'county': '139',
#    'name': 'Muscatine',
#    'lsad': 'County',
#    'censusarea': 437.469,
#    'state': '19',
#    'statename': 'Iowa',
#    'stateabbr': 'IA',
#    'population': 42929,
#    'land_area': '437.47',
#    'housing_units': '17910',
#    'population_density': 98.13015749651404,
#    'lat': -91.11271053555662,
#    'long': 41.483925070360335,
#    'cases': 7,
#    'deaths': 0,
#    'active': 7,
#    'recovered': 0,
#    'time_cases_update': '3/28 12:15PM',
#    'pc_cases': 16.305993617368213,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-91.366448, 41.598373],
#      [-90.899853, 41.597133],
#      [-90.783812, 41.596531],
#      [-90.786282, 41.452888],
#      [-90.847458, 41.455019],
#      [-90.989976, 41.431962],
#      [-91.027787, 41.423603],
#      [-91.039872, 41.418523],
#      [-91.047819, 41.4109],
#      [-91.078682, 41.336089],
#      [-91.079657, 41.333727],
#      [-91.369332, 41.336063],
#      [-91.368521, 41.423178],
#      [-91.366448, 41.598373]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US19145',
#    'county': '145',
#    'name': 'Page',
#    'lsad': 'County',
#    'censusarea': 534.942,
#    'state': '19',
#    'statename': 'Iowa',
#    'stateabbr': 'IA',
#    'population': 15249,
#    'land_area': '534.94',
#    'housing_units': '7181',
#    'population_density': 28.506000672972668,
#    'lat': -95.15019075775942,
#    'long': 40.73914391518788,
#    'cases': 2,
#    'deaths': 0,
#    'active': 2,
#    'recovered': 0,
#    'time_cases_update': '3/28 12:15PM',
#    'pc_cases': 13.115614138632042,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-94.914896, 40.575068],
#      [-94.955134, 40.575669],
#      [-94.966491, 40.575839],
#      [-95.068921, 40.57688],
#      [-95.079742, 40.577007],
#      [-95.097607, 40.577168],
#      [-95.107213, 40.577116],
#      [-95.110303, 40.57716],
#      [-95.110663, 40.577206],
#      [-95.112222, 40.577228],
#      [-95.120829, 40.577413],
#      [-95.154499, 40.57786],
#      [-95.164058, 40.578017],
#      [-95.202264, 40.578528],
#      [-95.211408, 40.57865],
#      [-95.21159, 40.578654],
#      [-95.212715, 40.578679],
#      [-95.213327, 40.578689],
#      [-95.217455, 40.578759],
#      [-95.218783, 40.578781],
#      [-95.221525, 40.578827],
#      [-95.335588, 40.579871],
#      [-95.357802, 40.5801],
#      [-95.373893, 40.580501],
#      [-95.373923, 40.580501],
#      [-95.384964, 40.90155],
#      [-94.928459, 40.900653],
#      [-94.914896, 40.575068]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US20181',
#    'county': '181',
#    'name': 'Sherman',
#    'lsad': 'County',
#    'censusarea': 1056.066,
#    'state': '20',
#    'statename': 'Kansas',
#    'stateabbr': 'KS',
#    'population': 5899,
#    'land_area': '1056.07',
#    'housing_units': '3148',
#    'population_density': 5.585803971327659,
#    'lat': -101.71997921016312,
#    'long': 39.35143850501125,
#    'cases': 0,
#    'deaths': 0,
#    'active': 0,
#    'recovered': 0,
#    'pc_cases': 0.0,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-101.389068, 39.568369],
#      [-101.391717, 39.135117],
#      [-101.478195, 39.134761],
#      [-102.047189, 39.133147],
#      [-102.04725, 39.13702],
#      [-102.048449, 39.303138],
#      [-102.04896, 39.373712],
#      [-102.049167, 39.403597],
#      [-102.04937, 39.41821],
#      [-102.049369, 39.423333],
#      [-102.049679, 39.506183],
#      [-102.049673, 39.536691],
#      [-102.049554, 39.538932],
#      [-102.049764, 39.56818],
#      [-101.413913, 39.568361],
#      [-101.389068, 39.568369]]]}},
#  {'type': 'Feature',
#   'properties': {'geo_id': '0500000US19153',
#    'county': '153',
#    'name': 'Polk',
#    'lsad': 'County',
#    'censusarea': 573.795,
#    'state': '19',
#    'statename': 'Iowa',
#    'stateabbr': 'IA',
#    'population': 487204,
#    'land_area': '573.79',
#    'housing_units': '182262',
#    'population_density': 849.0981020931004,
#    'lat': -93.57354249351559,
#    'long': 41.68550140946249,
#    'cases': 28,
#    'deaths': 0,
#    'active': 28,
#    'recovered': 0,
#    'time_cases_update': '3/28 12:15PM',
#    'pc_cases': 5.747079252222888,
#    'pc_deaths': 0.0},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-93.328614, 41.507824],
#      [-93.328486, 41.49134],
#      [-93.328407, 41.490921],
#      [-93.41226, 41.505549],
#      [-93.790612, 41.511916],
#      [-93.814282, 41.600448],
#      [-93.815527, 41.863419],
#      [-93.698032, 41.86337],
#      [-93.347933, 41.863104],
#      [-93.348681, 41.600999],
#      [-93.328614, 41.507824]]]}},
#  ...]

# %%
for county in counties:
    props = county["properties"]
    geo_id = props["geo_id"]
    cases = props["cases"]
    deaths = props["deaths"]
    county_time_data[geo_id][todays_date] = {"cases":cases, "deaths":deaths}

# %% [markdown]
# #### Add time series to county geojson

# %%
for county in counties:
    geo_id = county["properties"]["geo_id"]
    county["properties"]["time_series"] = county_time_data[geo_id]

# %%
counties[0]
# Out:
# {'type': 'Feature',
#  'properties': {'geo_id': '0500000US01001',
#   'county': '001',
#   'name': 'Autauga',
#   'lsad': 'County',
#   'censusarea': 594.436,
#   'state': '01',
#   'statename': 'Alabama',
#   'stateabbr': 'AL',
#   'population': 55601,
#   'land_area': '594.44',
#   'housing_units': '22135',
#   'population_density': 93.53509185115402,
#   'lat': -86.64274644826507,
#   'long': 32.53492681419619,
#   'cases': 6,
#   'deaths': 0,
#   'active': 6,
#   'recovered': 0,
#   'time_cases_update': '3/28 12:15PM',
#   'pc_cases': 10.791172820632722,
#   'pc_deaths': 0.0,
#   'time_series': {'3-15-2020': {'cases': 0, 'deaths': None},
#    '3-17-2020': {'cases': 0, 'deaths': None},
#    '3-18-2020': {'cases': 0, 'deaths': 0},
#    '3-19-2020': {'cases': 0, 'deaths': 0},
#    '3-20-2020': {'cases': 0, 'deaths': 0},
#    '3-23-2020': {'cases': 0, 'deaths': 0},
#    '3-24-2020': {'cases': 1, 'deaths': 0},
#    '3-25-2020': {'cases': 4, 'deaths': 0},
#    '3-26-2020': {'cases': 6, 'deaths': 0},
#    '3-27-2020': {'cases': 6, 'deaths': 0},
#    '3-28-2020': {'cases': 6, 'deaths': 0}}},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-86.496774, 32.344437],
#     [-86.717897, 32.402814],
#     [-86.814912, 32.340803],
#     [-86.890581, 32.502974],
#     [-86.917595, 32.664169],
#     [-86.71339, 32.661732],
#     [-86.714219, 32.705694],
#     [-86.413116, 32.707386],
#     [-86.411172, 32.409937],
#     [-86.496774, 32.344437]]]}}

# %% [markdown]
# #### Save latest state time series data to file

# %%
with open(county_data_folder/"countyTimeData.json", 'w') as f:
    json.dump(county_time_data, f)

# %% [markdown]
# ### Add State time series

# %%
with open(state_data_folder/'stateTimeData.json', 'r') as f:
    state_time_data = json.load(f)

# %%
state_time_data
# Out:
# {'Alabama': {'3-13-2020': {'cases': 5,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 12,
#    'test_positive': 1,
#    'test_negative': 11},
#   '3-14-2020': {'cases': 6,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 74,
#    'test_positive': 6,
#    'test_negative': 22},
#   '3-15-2020': {'cases': 12,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 86,
#    'test_positive': 12,
#    'test_negative': 28},
#   '3-16-2020': {'cases': 29,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 96,
#    'test_positive': 28,
#    'test_negative': 28},
#   '3-17-2020': {'cases': 39,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 64,
#    'test_positive': 36,
#    'test_negative': 28},
#   '3-18-2020': {'cases': 46,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 74,
#    'test_positive': 46,
#    'test_negative': 28},
#   '3-19-2020': {'cases': 78,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 96,
#    'test_positive': 68,
#    'test_negative': 28},
#   '3-20-2020': {'cases': 83,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 109,
#    'test_positive': 81,
#    'test_negative': 28},
#   '3-21-2020': {'cases': 131,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 152,
#    'test_positive': 124,
#    'test_negative': 28},
#   '3-22-2020': {'cases': 157,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1602,
#    'test_positive': 138,
#    'test_negative': 1464},
#   '3-23-2020': {'cases': 196,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1832,
#    'test_positive': 167,
#    'test_negative': 1665},
#   '3-24-2020': {'cases': 242,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2321,
#    'test_positive': 215,
#    'test_negative': 2106},
#   '3-25-2020': {'cases': 381,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 2812,
#    'test_positive': 283,
#    'test_negative': 2529},
#   '3-26-2020': {'cases': 517,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 4099,
#    'test_positive': 506,
#    'test_negative': 3593},
#   '3-27-2020': {'cases': 587,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 4771,
#    'test_positive': 587,
#    'test_negative': 4184},
#   '3-12-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#   '3-11-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#   '3-10-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#   '3-9-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': None},
#   '3-8-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': None},
#   '3-7-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': None}},
#  'Alaska': {'3-10-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 32,
#    'test_positive': 0,
#    'test_negative': 23},
#   '3-11-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 60,
#    'test_positive': 0,
#    'test_negative': 46},
#   '3-12-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 60,
#    'test_positive': 0,
#    'test_negative': 46},
#   '3-13-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 60,
#    'test_positive': 1,
#    'test_negative': 59},
#   '3-15-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 144,
#    'test_positive': 1,
#    'test_negative': 143},
#   '3-16-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 144,
#    'test_positive': 1,
#    'test_negative': 143},
#   '3-17-2020': {'cases': 3,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 337,
#    'test_positive': 3,
#    'test_negative': 334},
#   '3-18-2020': {'cases': 6,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 412,
#    'test_positive': 6,
#    'test_negative': 406},
#   '3-19-2020': {'cases': 9,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 406,
#    'test_positive': 6,
#    'test_negative': 400},
#   '3-20-2020': {'cases': 12,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 698,
#    'test_positive': 12,
#    'test_negative': 686},
#   '3-21-2020': {'cases': 15,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 772,
#    'test_positive': 14,
#    'test_negative': 758},
#   '3-22-2020': {'cases': 20,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 968,
#    'test_positive': 22,
#    'test_negative': 946},
#   '3-23-2020': {'cases': 30,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 968,
#    'test_positive': 22,
#    'test_negative': 946},
#   '3-24-2020': {'cases': 34,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1022,
#    'test_positive': 36,
#    'test_negative': 986},
#   '3-25-2020': {'cases': 41,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 1691,
#    'test_positive': 42,
#    'test_negative': 1649},
#   '3-26-2020': {'cases': 56,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 1860,
#    'test_positive': 59,
#    'test_negative': 1801},
#   '3-27-2020': {'cases': 58,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 2401,
#    'test_positive': 69,
#    'test_negative': 2319},
#   '3-14-2020': {'test_total': 144, 'test_positive': 1, 'test_negative': 143},
#   '3-9-2020': {'test_total': 32, 'test_positive': 0, 'test_negative': 23},
#   '3-8-2020': {'test_total': 20, 'test_positive': 0, 'test_negative': 14},
#   '3-7-2020': {'test_total': 14, 'test_positive': 0, 'test_negative': 12},
#   '3-6-2020': {'test_total': 9, 'test_positive': 0, 'test_negative': 8}},
#  'Arizona': {'1-26-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-27-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-28-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-29-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-30-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-31-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-1-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-2-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-3-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-4-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-5-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-6-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-7-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-8-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-9-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-10-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-11-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-12-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-13-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-14-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-15-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-16-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-17-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-18-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-19-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-20-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-21-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-22-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-23-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-24-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-25-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-26-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-27-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-28-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-29-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '3-1-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '3-2-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '3-3-2020': {'cases': 2, 'deaths': 0, 'recovered': 1},
#   '3-4-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 34,
#    'test_positive': 2,
#    'test_negative': 27},
#   '3-5-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 36,
#    'test_positive': 2,
#    'test_negative': 28},
#   '3-6-2020': {'cases': 3,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 51,
#    'test_positive': 3,
#    'test_negative': 33},
#   '3-7-2020': {'cases': 5,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 56,
#    'test_positive': 5,
#    'test_negative': 44},
#   '3-8-2020': {'cases': 5,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 56,
#    'test_positive': 5,
#    'test_negative': 44},
#   '3-9-2020': {'cases': 5,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 56,
#    'test_positive': 5,
#    'test_negative': 44},
#   '3-10-2020': {'cases': 6,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 84,
#    'test_positive': 6,
#    'test_negative': 51},
#   '3-11-2020': {'cases': 9,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 100,
#    'test_positive': 9,
#    'test_negative': 59},
#   '3-12-2020': {'cases': 9,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 115,
#    'test_positive': 9,
#    'test_negative': 82},
#   '3-13-2020': {'cases': 9,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 143,
#    'test_positive': 9,
#    'test_negative': 94},
#   '3-14-2020': {'cases': 12,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 183,
#    'test_positive': 12,
#    'test_negative': 121},
#   '3-15-2020': {'cases': 13,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 183,
#    'test_positive': 12,
#    'test_negative': 121},
#   '3-16-2020': {'cases': 18,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 206,
#    'test_positive': 18,
#    'test_negative': 125},
#   '3-17-2020': {'cases': 20,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 228,
#    'test_positive': 20,
#    'test_negative': 142},
#   '3-18-2020': {'cases': 27,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 278,
#    'test_positive': 28,
#    'test_negative': 148},
#   '3-19-2020': {'cases': 45,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 349,
#    'test_positive': 44,
#    'test_negative': 175},
#   '3-20-2020': {'cases': 78,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 377,
#    'test_positive': 65,
#    'test_negative': 211},
#   '3-21-2020': {'cases': 118,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 466,
#    'test_positive': 104,
#    'test_negative': 240},
#   '3-22-2020': {'cases': 152,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 521,
#    'test_positive': 152,
#    'test_negative': 282},
#   '3-23-2020': {'cases': 235,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 580,
#    'test_positive': 265,
#    'test_negative': 309},
#   '3-24-2020': {'cases': 326,
#    'deaths': 5,
#    'recovered': 0,
#    'test_total': 692,
#    'test_positive': 357,
#    'test_negative': 313},
#   '3-25-2020': {'cases': 401,
#    'deaths': 6,
#    'recovered': 0,
#    'test_total': 826,
#    'test_positive': 450,
#    'test_negative': 323},
#   '3-26-2020': {'cases': 508,
#    'deaths': 8,
#    'recovered': 0,
#    'test_total': 957,
#    'test_positive': 577,
#    'test_negative': 347},
#   '3-27-2020': {'cases': 665,
#    'deaths': 13,
#    'recovered': 0,
#    'test_total': 8221,
#    'test_positive': 736,
#    'test_negative': 7455}},
#  'Arkansas': {'3-10-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 15,
#    'test_positive': 0,
#    'test_negative': 12},
#   '3-11-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 26,
#    'test_positive': 0,
#    'test_negative': 12},
#   '3-12-2020': {'cases': 6,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 50,
#    'test_positive': 6,
#    'test_negative': 24},
#   '3-13-2020': {'cases': 6,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 61,
#    'test_positive': 9,
#    'test_negative': 30},
#   '3-14-2020': {'cases': 12,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 103,
#    'test_positive': 12,
#    'test_negative': 65},
#   '3-15-2020': {'cases': 16,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 149,
#    'test_positive': 16,
#    'test_negative': 103},
#   '3-16-2020': {'cases': 22,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 168,
#    'test_positive': 22,
#    'test_negative': 132},
#   '3-17-2020': {'cases': 22,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 260,
#    'test_positive': 22,
#    'test_negative': 197},
#   '3-18-2020': {'cases': 33,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 319,
#    'test_positive': 33,
#    'test_negative': 236},
#   '3-19-2020': {'cases': 62,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 469,
#    'test_positive': 46,
#    'test_negative': 310},
#   '3-20-2020': {'cases': 96,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 650,
#    'test_positive': 96,
#    'test_negative': 351},
#   '3-21-2020': {'cases': 122,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 839,
#    'test_positive': 118,
#    'test_negative': 567},
#   '3-22-2020': {'cases': 165,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 995,
#    'test_positive': 165,
#    'test_negative': 711},
#   '3-23-2020': {'cases': 192,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1080,
#    'test_positive': 174,
#    'test_negative': 906},
#   '3-24-2020': {'cases': 219,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 1165,
#    'test_positive': 218,
#    'test_negative': 947},
#   '3-25-2020': {'cases': 280,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 1717,
#    'test_positive': 280,
#    'test_negative': 1437},
#   '3-26-2020': {'cases': 335,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 1839,
#    'test_positive': 335,
#    'test_negative': 1504},
#   '3-27-2020': {'cases': 381,
#    'deaths': 3,
#    'recovered': 0,
#    'test_total': 1926,
#    'test_positive': 381,
#    'test_negative': 1545},
#   '3-9-2020': {'test_total': 12, 'test_positive': 0, 'test_negative': 12},
#   '3-8-2020': {'test_total': 6, 'test_positive': 0, 'test_negative': 6},
#   '3-7-2020': {'test_total': 6, 'test_positive': 0, 'test_negative': 6},
#   '3-6-2020': {'test_total': 6, 'test_positive': 0, 'test_negative': 6}},
#  'California': {'1-26-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '1-27-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '1-28-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '1-29-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '1-30-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '1-31-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '2-1-2020': {'cases': 3, 'deaths': 0, 'recovered': 0},
#   '2-2-2020': {'cases': 3, 'deaths': 0, 'recovered': 0},
#   '2-3-2020': {'cases': 6, 'deaths': 0, 'recovered': 0},
#   '2-4-2020': {'cases': 6, 'deaths': 0, 'recovered': 0},
#   '2-5-2020': {'cases': 6, 'deaths': 0, 'recovered': 0},
#   '2-6-2020': {'cases': 6, 'deaths': 0, 'recovered': 0},
#   '2-7-2020': {'cases': 6, 'deaths': 0, 'recovered': 0},
#   '2-8-2020': {'cases': 6, 'deaths': 0, 'recovered': 0},
#   '2-9-2020': {'cases': 6, 'deaths': 0, 'recovered': 0},
#   '2-10-2020': {'cases': 6, 'deaths': 0, 'recovered': 0},
#   '2-11-2020': {'cases': 7, 'deaths': 0, 'recovered': 0},
#   '2-12-2020': {'cases': 7, 'deaths': 0, 'recovered': 0},
#   '2-13-2020': {'cases': 8, 'deaths': 0, 'recovered': 0},
#   '2-14-2020': {'cases': 8, 'deaths': 0, 'recovered': 0},
#   '2-15-2020': {'cases': 8, 'deaths': 0, 'recovered': 0},
#   '2-16-2020': {'cases': 8, 'deaths': 0, 'recovered': 0},
#   '2-17-2020': {'cases': 8, 'deaths': 0, 'recovered': 0},
#   '2-18-2020': {'cases': 8, 'deaths': 0, 'recovered': 0},
#   '2-19-2020': {'cases': 8, 'deaths': 0, 'recovered': 0},
#   '2-20-2020': {'cases': 8, 'deaths': 0, 'recovered': 0},
#   '2-21-2020': {'cases': 15, 'deaths': 0, 'recovered': 2},
#   '2-22-2020': {'cases': 15, 'deaths': 0, 'recovered': 2},
#   '2-23-2020': {'cases': 15, 'deaths': 0, 'recovered': 2},
#   '2-24-2020': {'cases': 10, 'deaths': 0, 'recovered': 2},
#   '2-25-2020': {'cases': 10, 'deaths': 0, 'recovered': 2},
#   '2-26-2020': {'cases': 10, 'deaths': 0, 'recovered': 2},
#   '2-27-2020': {'cases': 11, 'deaths': 0, 'recovered': 2},
#   '2-28-2020': {'cases': 11, 'deaths': 0, 'recovered': 2},
#   '2-29-2020': {'cases': 12, 'deaths': 0, 'recovered': 2},
#   '3-1-2020': {'cases': 12, 'deaths': 0, 'recovered': 2},
#   '3-2-2020': {'cases': 21, 'deaths': 0, 'recovered': 2},
#   '3-3-2020': {'cases': 25, 'deaths': 0, 'recovered': 2},
#   '3-4-2020': {'cases': 35,
#    'deaths': 1,
#    'recovered': 2,
#    'test_total': 515,
#    'test_positive': 53,
#    'test_negative': 462},
#   '3-5-2020': {'cases': 51,
#    'deaths': 1,
#    'recovered': 2,
#    'test_total': 515,
#    'test_positive': 53,
#    'test_negative': 462},
#   '3-6-2020': {'cases': 59,
#    'deaths': 1,
#    'recovered': 2,
#    'test_total': 522,
#    'test_positive': 60,
#    'test_negative': 462},
#   '3-7-2020': {'cases': 82,
#    'deaths': 1,
#    'recovered': 2,
#    'test_total': 531,
#    'test_positive': 69,
#    'test_negative': 462},
#   '3-8-2020': {'cases': 98,
#    'deaths': 1,
#    'recovered': 2,
#    'test_total': 550,
#    'test_positive': 88,
#    'test_negative': 462},
#   '3-9-2020': {'cases': 104,
#    'deaths': 1,
#    'recovered': 2,
#    'test_total': 804,
#    'test_positive': 114,
#    'test_negative': 690},
#   '3-10-2020': {'cases': 144,
#    'deaths': 2,
#    'recovered': 2,
#    'test_total': 823,
#    'test_positive': 133,
#    'test_negative': 690},
#   '3-11-2020': {'cases': 177,
#    'deaths': 3,
#    'recovered': 2,
#    'test_total': 1073,
#    'test_positive': 157,
#    'test_negative': 916},
#   '3-12-2020': {'cases': 221,
#    'deaths': 4,
#    'recovered': 6,
#    'test_total': 1118,
#    'test_positive': 202,
#    'test_negative': 916},
#   '3-13-2020': {'cases': 282,
#    'deaths': 4,
#    'recovered': 6,
#    'test_total': 1118,
#    'test_positive': 202,
#    'test_negative': 916},
#   '3-14-2020': {'cases': 340,
#    'deaths': 5,
#    'recovered': 6,
#    'test_total': 1168,
#    'test_positive': 252,
#    'test_negative': 916},
#   '3-15-2020': {'cases': 426,
#    'deaths': 6,
#    'recovered': 6,
#    'test_total': 1209,
#    'test_positive': 293,
#    'test_negative': 916},
#   '3-16-2020': {'cases': 557,
#    'deaths': 7,
#    'recovered': 6,
#    'test_total': 8316,
#    'test_positive': 335,
#    'test_negative': 7981},
#   '3-17-2020': {'cases': 698,
#    'deaths': 12,
#    'recovered': 6,
#    'test_total': 8464,
#    'test_positive': 483,
#    'test_negative': 7981},
#   '3-18-2020': {'cases': 751,
#    'deaths': 13,
#    'recovered': 0,
#    'test_total': 8592,
#    'test_positive': 611,
#    'test_negative': 7981},
#   '3-19-2020': {'cases': 952,
#    'deaths': 18,
#    'recovered': 0,
#    'test_total': 9711,
#    'test_positive': 924,
#    'test_negative': 8787},
#   '3-20-2020': {'cases': 1177,
#    'deaths': 23,
#    'recovered': 0,
#    'test_total': 11487,
#    'test_positive': 1063,
#    'test_negative': 10424},
#   '3-21-2020': {'cases': 1364,
#    'deaths': 24,
#    'recovered': 0,
#    'test_total': 12528,
#    'test_positive': 1279,
#    'test_negative': 11249},
#   '3-22-2020': {'cases': 1646,
#    'deaths': 30,
#    'recovered': 0,
#    'test_total': 12840,
#    'test_positive': 1536,
#    'test_negative': 11304},
#   '3-23-2020': {'cases': 2108,
#    'deaths': 39,
#    'recovered': 0,
#    'test_total': 26400,
#    'test_positive': 1733,
#    'test_negative': 12567},
#   '3-24-2020': {'cases': 2538,
#    'deaths': 50,
#    'recovered': 0,
#    'test_total': 27654,
#    'test_positive': 2102,
#    'test_negative': 13452},
#   '3-25-2020': {'cases': 2998,
#    'deaths': 65,
#    'recovered': 0,
#    'test_total': 66876,
#    'test_positive': 2355,
#    'test_negative': 15921},
#   '3-26-2020': {'cases': 3899,
#    'deaths': 81,
#    'recovered': 0,
#    'test_total': 77786,
#    'test_positive': 3006,
#    'test_negative': 17380},
#   '3-27-2020': {'cases': 4657,
#    'deaths': 94,
#    'recovered': 0,
#    'test_total': 78659,
#    'test_positive': 3879,
#    'test_negative': 17380}},
#  'Colorado': {'3-6-2020': {'cases': 4,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 78,
#    'test_positive': 2,
#    'test_negative': 46},
#   '3-7-2020': {'cases': 8,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 132,
#    'test_positive': 8,
#    'test_negative': 55},
#   '3-8-2020': {'cases': 8,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 112,
#    'test_positive': 8,
#    'test_negative': 104},
#   '3-9-2020': {'cases': 8,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 142,
#    'test_positive': 9,
#    'test_negative': 133},
#   '3-10-2020': {'cases': 15,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 155,
#    'test_positive': 12,
#    'test_negative': 142},
#   '3-11-2020': {'cases': 34,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 279,
#    'test_positive': 28,
#    'test_negative': 251},
#   '3-12-2020': {'cases': 45,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 343,
#    'test_positive': 45,
#    'test_negative': 298},
#   '3-13-2020': {'cases': 49,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 596,
#    'test_positive': 72,
#    'test_negative': 524},
#   '3-14-2020': {'cases': 101,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 711,
#    'test_positive': 101,
#    'test_negative': 610},
#   '3-15-2020': {'cases': 131,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 758,
#    'test_positive': 131,
#    'test_negative': 627},
#   '3-16-2020': {'cases': 160,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 758,
#    'test_positive': 131,
#    'test_negative': 627},
#   '3-17-2020': {'cases': 160,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 1216,
#    'test_positive': 160,
#    'test_negative': 1056},
#   '3-18-2020': {'cases': 184,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 1800,
#    'test_positive': 183,
#    'test_negative': 1617},
#   '3-19-2020': {'cases': 277,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 2328,
#    'test_positive': 216,
#    'test_negative': 2112},
#   '3-20-2020': {'cases': 363,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 2952,
#    'test_positive': 277,
#    'test_negative': 2675},
#   '3-21-2020': {'cases': 390,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 3680,
#    'test_positive': 363,
#    'test_negative': 3317},
#   '3-22-2020': {'cases': 591,
#    'deaths': 6,
#    'recovered': 0,
#    'test_total': 4550,
#    'test_positive': 475,
#    'test_negative': 4075},
#   '3-23-2020': {'cases': 704,
#    'deaths': 7,
#    'recovered': 0,
#    'test_total': 5436,
#    'test_positive': 591,
#    'test_negative': 4845},
#   '3-24-2020': {'cases': 723,
#    'deaths': 8,
#    'recovered': 0,
#    'test_total': 6224,
#    'test_positive': 720,
#    'test_negative': 5504},
#   '3-25-2020': {'cases': 1021,
#    'deaths': 16,
#    'recovered': 0,
#    'test_total': 7701,
#    'test_positive': 912,
#    'test_negative': 6789},
#   '3-26-2020': {'cases': 1430,
#    'deaths': 19,
#    'recovered': 0,
#    'test_total': 8064,
#    'test_positive': 1086,
#    'test_negative': 6978},
#   '3-27-2020': {'cases': 1433,
#    'deaths': 27,
#    'recovered': 0,
#    'test_total': 10122,
#    'test_positive': 1430,
#    'test_negative': 8692},
#   '3-5-2020': {'test_total': 40, 'test_positive': 0, 'test_negative': 19}},
#  'Connecticut': {'3-7-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 0,
#    'test_positive': 0,
#    'test_negative': None},
#   '3-8-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 38,
#    'test_positive': 1,
#    'test_negative': 29},
#   '3-9-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 47,
#    'test_positive': 1,
#    'test_negative': 46},
#   '3-10-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 56,
#    'test_positive': 2,
#    'test_negative': 54},
#   '3-11-2020': {'cases': 3,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 74,
#    'test_positive': 3,
#    'test_negative': 71},
#   '3-12-2020': {'cases': 5,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 95,
#    'test_positive': 6,
#    'test_negative': 89},
#   '3-13-2020': {'cases': 11,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 105,
#    'test_positive': 6,
#    'test_negative': 99},
#   '3-14-2020': {'cases': 22,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 136,
#    'test_positive': 11,
#    'test_negative': 125},
#   '3-15-2020': {'cases': 24,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 145,
#    'test_positive': 20,
#    'test_negative': 125},
#   '3-16-2020': {'cases': 30,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 151,
#    'test_positive': 26,
#    'test_negative': 125},
#   '3-17-2020': {'cases': 68,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 166,
#    'test_positive': 41,
#    'test_negative': 125},
#   '3-18-2020': {'cases': 68,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 193,
#    'test_positive': 68,
#    'test_negative': 125},
#   '3-19-2020': {'cases': 159,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 700,
#    'test_positive': 96,
#    'test_negative': 604},
#   '3-20-2020': {'cases': 194,
#    'deaths': 3,
#    'recovered': 0,
#    'test_total': 798,
#    'test_positive': 194,
#    'test_negative': 604},
#   '3-21-2020': {'cases': 194,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 2300,
#    'test_positive': 194,
#    'test_negative': 2106},
#   '3-22-2020': {'cases': 327,
#    'deaths': 8,
#    'recovered': 0,
#    'test_total': 3100,
#    'test_positive': 223,
#    'test_negative': 2877},
#   '3-23-2020': {'cases': 415,
#    'deaths': 10,
#    'recovered': 0,
#    'test_total': 4500,
#    'test_positive': 415,
#    'test_negative': 4085},
#   '3-24-2020': {'cases': 618,
#    'deaths': 12,
#    'recovered': 0,
#    'test_total': 5300,
#    'test_positive': 618,
#    'test_negative': 4682},
#   '3-25-2020': {'cases': 875,
#    'deaths': 19,
#    'recovered': 0,
#    'test_total': 5898,
#    'test_positive': 875,
#    'test_negative': 5023},
#   '3-26-2020': {'cases': 1012,
#    'deaths': 21,
#    'recovered': 0,
#    'test_total': 6637,
#    'test_positive': 1012,
#    'test_negative': 5625},
#   '3-27-2020': {'cases': 1291,
#    'deaths': 27,
#    'recovered': 0,
#    'test_total': 8400,
#    'test_positive': 1291,
#    'test_negative': 7109}},
#  'Delaware': {'3-10-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 20,
#    'test_positive': 0,
#    'test_negative': 17},
#   '3-11-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 20,
#    'test_positive': 1,
#    'test_negative': 17},
#   '3-12-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 41,
#    'test_positive': 4,
#    'test_negative': 23},
#   '3-13-2020': {'cases': 4,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 44,
#    'test_positive': 4,
#    'test_negative': 30},
#   '3-14-2020': {'cases': 6,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 74,
#    'test_positive': 6,
#    'test_negative': 36},
#   '3-15-2020': {'cases': 7,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 74,
#    'test_positive': 6,
#    'test_negative': 36},
#   '3-16-2020': {'cases': 8,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 76,
#    'test_positive': 8,
#    'test_negative': 36},
#   '3-17-2020': {'cases': 16,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 52,
#    'test_positive': 16,
#    'test_negative': 36},
#   '3-18-2020': {'cases': 19,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 61,
#    'test_positive': 25,
#    'test_negative': 36},
#   '3-19-2020': {'cases': 30,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 66,
#    'test_positive': 30,
#    'test_negative': 36},
#   '3-20-2020': {'cases': 38,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 74,
#    'test_positive': 38,
#    'test_negative': 36},
#   '3-21-2020': {'cases': 45,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 81,
#    'test_positive': 45,
#    'test_negative': 36},
#   '3-22-2020': {'cases': 56,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 92,
#    'test_positive': 56,
#    'test_negative': 36},
#   '3-23-2020': {'cases': 68,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 104,
#    'test_positive': 68,
#    'test_negative': 36},
#   '3-24-2020': {'cases': 104,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 127,
#    'test_positive': 91,
#    'test_negative': 36},
#   '3-25-2020': {'cases': 119,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 151,
#    'test_positive': 115,
#    'test_negative': 36},
#   '3-26-2020': {'cases': 130,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 166,
#    'test_positive': 130,
#    'test_negative': 36},
#   '3-27-2020': {'cases': 163,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 199,
#    'test_positive': 163,
#    'test_negative': 36},
#   '3-9-2020': {'test_total': 18, 'test_positive': 0, 'test_negative': 15},
#   '3-8-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#   '3-7-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#   '3-6-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10}},
#  'District of Columbia': {'3-8-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 11,
#    'test_positive': 1,
#    'test_negative': 10},
#   '3-9-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 18,
#    'test_positive': 1,
#    'test_negative': 14},
#   '3-10-2020': {'cases': 5,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 24,
#    'test_positive': 5,
#    'test_negative': 17},
#   '3-11-2020': {'cases': 10,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 39,
#    'test_positive': 4,
#    'test_negative': 20},
#   '3-12-2020': {'cases': 10,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 30,
#    'test_positive': 10,
#    'test_negative': 20},
#   '3-13-2020': {'cases': 10,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 30,
#    'test_positive': 10,
#    'test_negative': 20},
#   '3-14-2020': {'cases': 10,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 69,
#    'test_positive': 10,
#    'test_negative': 49},
#   '3-15-2020': {'cases': 16,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 115,
#    'test_positive': 16,
#    'test_negative': 79},
#   '3-16-2020': {'cases': 22,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 120,
#    'test_positive': 17,
#    'test_negative': 96},
#   '3-17-2020': {'cases': 22,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 126,
#    'test_positive': 22,
#    'test_negative': 104},
#   '3-18-2020': {'cases': 31,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 170,
#    'test_positive': 31,
#    'test_negative': 138},
#   '3-19-2020': {'cases': 40,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 203,
#    'test_positive': 39,
#    'test_negative': 153},
#   '3-20-2020': {'cases': 71,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 573,
#    'test_positive': 71,
#    'test_negative': 501},
#   '3-21-2020': {'cases': 77,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 583,
#    'test_positive': 77,
#    'test_negative': 506},
#   '3-22-2020': {'cases': 102,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 1055,
#    'test_positive': 98,
#    'test_negative': 957},
#   '3-23-2020': {'cases': 120,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 1229,
#    'test_positive': 116,
#    'test_negative': 1113},
#   '3-24-2020': {'cases': 141,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 1334,
#    'test_positive': 137,
#    'test_negative': 1195},
#   '3-25-2020': {'cases': 187,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 1609,
#    'test_positive': 183,
#    'test_negative': 1423},
#   '3-26-2020': {'cases': 231,
#    'deaths': 3,
#    'recovered': 0,
#    'test_total': 1858,
#    'test_positive': 231,
#    'test_negative': 1626},
#   '3-27-2020': {'cases': 271,
#    'deaths': 3,
#    'recovered': 0,
#    'test_total': 2166,
#    'test_positive': 267,
#    'test_negative': 1897},
#   '3-7-2020': {'test_total': 9, 'test_positive': 0, 'test_negative': 8},
#   '3-6-2020': {'test_total': 9, 'test_positive': 0, 'test_negative': 8},
#   '3-5-2020': {'test_total': 8, 'test_positive': 0, 'test_negative': 6}},
#  'Florida': {'3-2-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '3-3-2020': {'cases': 3, 'deaths': 0, 'recovered': 0},
#   '3-4-2020': {'cases': 3,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 42,
#    'test_positive': 2,
#    'test_negative': 24},
#   '3-5-2020': {'cases': 4,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 109,
#    'test_positive': 9,
#    'test_negative': 31},
#   '3-6-2020': {'cases': 4,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 115,
#    'test_positive': 9,
#    'test_negative': 55},
#   '3-7-2020': {'cases': 8,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 202,
#    'test_positive': 14,
#    'test_negative': 100},
#   '3-8-2020': {'cases': 11,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 243,
#    'test_positive': 17,
#    'test_negative': 118},
#   '3-9-2020': {'cases': 14,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 273,
#    'test_positive': 18,
#    'test_negative': 140},
#   '3-10-2020': {'cases': 15,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 396,
#    'test_positive': 19,
#    'test_negative': 222},
#   '3-11-2020': {'cases': 28,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 476,
#    'test_positive': 28,
#    'test_negative': 301},
#   '3-12-2020': {'cases': 35,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 480,
#    'test_positive': 32,
#    'test_negative': 301},
#   '3-13-2020': {'cases': 50,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 749,
#    'test_positive': 50,
#    'test_negative': 478},
#   '3-14-2020': {'cases': 76,
#    'deaths': 3,
#    'recovered': 0,
#    'test_total': 776,
#    'test_positive': 77,
#    'test_negative': 478},
#   '3-15-2020': {'cases': 115,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 1248,
#    'test_positive': 116,
#    'test_negative': 678},
#   '3-16-2020': {'cases': 155,
#    'deaths': 5,
#    'recovered': 0,
#    'test_total': 1339,
#    'test_positive': 141,
#    'test_negative': 684},
#   '3-17-2020': {'cases': 216,
#    'deaths': 6,
#    'recovered': 0,
#    'test_total': 1998,
#    'test_positive': 186,
#    'test_negative': 940},
#   '3-18-2020': {'cases': 314,
#    'deaths': 7,
#    'recovered': 0,
#    'test_total': 2493,
#    'test_positive': 314,
#    'test_negative': 1225},
#   '3-19-2020': {'cases': 417,
#    'deaths': 9,
#    'recovered': 0,
#    'test_total': 2942,
#    'test_positive': 390,
#    'test_negative': 1533},
#   '3-20-2020': {'cases': 563,
#    'deaths': 10,
#    'recovered': 0,
#    'test_total': 3416,
#    'test_positive': 520,
#    'test_negative': 1870},
#   '3-21-2020': {'cases': 659,
#    'deaths': 13,
#    'recovered': 0,
#    'test_total': 8239,
#    'test_positive': 658,
#    'test_negative': 6579},
#   '3-22-2020': {'cases': 1004,
#    'deaths': 13,
#    'recovered': 0,
#    'test_total': 9783,
#    'test_positive': 830,
#    'test_negative': 7990},
#   '3-23-2020': {'cases': 1227,
#    'deaths': 18,
#    'recovered': 0,
#    'test_total': 13094,
#    'test_positive': 1171,
#    'test_negative': 11063},
#   '3-24-2020': {'cases': 1412,
#    'deaths': 18,
#    'recovered': 0,
#    'test_total': 15547,
#    'test_positive': 1412,
#    'test_negative': 13127},
#   '3-25-2020': {'cases': 1682,
#    'deaths': 23,
#    'recovered': 0,
#    'test_total': 18289,
#    'test_positive': 1682,
#    'test_negative': 15374},
#   '3-26-2020': {'cases': 2357,
#    'deaths': 29,
#    'recovered': 0,
#    'test_total': 27539,
#    'test_positive': 2355,
#    'test_negative': 23741},
#   '3-27-2020': {'cases': 2900,
#    'deaths': 35,
#    'recovered': 0,
#    'test_total': 32468,
#    'test_positive': 2765,
#    'test_negative': 28186}},
#  'Georgia': {'3-3-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '3-4-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2,
#    'test_positive': 2,
#    'test_negative': None},
#   '3-5-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2,
#    'test_positive': 2,
#    'test_negative': None},
#   '3-6-2020': {'cases': 3,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2,
#    'test_positive': 2,
#    'test_negative': None},
#   '3-7-2020': {'cases': 6,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 6,
#    'test_positive': 6,
#    'test_negative': None},
#   '3-8-2020': {'cases': 5,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 7,
#    'test_positive': 7,
#    'test_negative': None},
#   '3-9-2020': {'cases': 10,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 12,
#    'test_positive': 12,
#    'test_negative': None},
#   '3-10-2020': {'cases': 17,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 17,
#    'test_positive': 17,
#    'test_negative': None},
#   '3-11-2020': {'cases': 23,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 22,
#    'test_positive': 22,
#    'test_negative': None},
#   '3-12-2020': {'cases': 31,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 31,
#    'test_positive': 31,
#    'test_negative': None},
#   '3-13-2020': {'cases': 42,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 42,
#    'test_positive': 42,
#    'test_negative': None},
#   '3-14-2020': {'cases': 66,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 66,
#    'test_positive': 66,
#    'test_negative': None},
#   '3-15-2020': {'cases': 99,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 99,
#    'test_positive': 99,
#    'test_negative': None},
#   '3-16-2020': {'cases': 121,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 121,
#    'test_positive': 121,
#    'test_negative': None},
#   '3-17-2020': {'cases': 146,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 146,
#    'test_positive': 146,
#    'test_negative': None},
#   '3-18-2020': {'cases': 199,
#    'deaths': 3,
#    'recovered': 0,
#    'test_total': 1508,
#    'test_positive': 197,
#    'test_negative': 1311},
#   '3-19-2020': {'cases': 287,
#    'deaths': 10,
#    'recovered': 0,
#    'test_total': 1831,
#    'test_positive': 287,
#    'test_negative': 1544},
#   '3-20-2020': {'cases': 420,
#    'deaths': 13,
#    'recovered': 0,
#    'test_total': 2386,
#    'test_positive': 420,
#    'test_negative': 1966},
#   '3-21-2020': {'cases': 507,
#    'deaths': 14,
#    'recovered': 0,
#    'test_total': 3064,
#    'test_positive': 507,
#    'test_negative': 2557},
#   '3-22-2020': {'cases': 621,
#    'deaths': 25,
#    'recovered': 0,
#    'test_total': 4020,
#    'test_positive': 600,
#    'test_negative': 3420},
#   '3-23-2020': {'cases': 772,
#    'deaths': 25,
#    'recovered': 0,
#    'test_total': 5069,
#    'test_positive': 772,
#    'test_negative': 4297},
#   '3-24-2020': {'cases': 1026,
#    'deaths': 32,
#    'recovered': 0,
#    'test_total': 5484,
#    'test_positive': 1026,
#    'test_negative': 4458},
#   '3-25-2020': {'cases': 1247,
#    'deaths': 40,
#    'recovered': 0,
#    'test_total': 6179,
#    'test_positive': 1247,
#    'test_negative': 4932},
#   '3-26-2020': {'cases': 1525,
#    'deaths': 48,
#    'recovered': 0,
#    'test_total': 8926,
#    'test_positive': 1525,
#    'test_negative': 7401},
#   '3-27-2020': {'cases': 2000,
#    'deaths': 64,
#    'recovered': 0,
#    'test_total': 9865,
#    'test_positive': 2001,
#    'test_negative': 7864}},
#  'Hawaii': {'3-7-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1,
#    'test_positive': 1,
#    'test_negative': None},
#   '3-8-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1,
#    'test_positive': 1,
#    'test_negative': None},
#   '3-9-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2,
#    'test_positive': 2,
#    'test_negative': None},
#   '3-10-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2,
#    'test_positive': 2,
#    'test_negative': None},
#   '3-11-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2,
#    'test_positive': 2,
#    'test_negative': None},
#   '3-12-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2,
#    'test_positive': 2,
#    'test_negative': None},
#   '3-13-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2,
#    'test_positive': 2,
#    'test_negative': None},
#   '3-14-2020': {'cases': 4,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2,
#    'test_positive': 2,
#    'test_negative': None},
#   '3-15-2020': {'cases': 6,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2,
#    'test_positive': 2,
#    'test_negative': None},
#   '3-16-2020': {'cases': 7,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 7,
#    'test_positive': 7,
#    'test_negative': None},
#   '3-17-2020': {'cases': 10,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 10,
#    'test_positive': 10,
#    'test_negative': None},
#   '3-18-2020': {'cases': 14,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 119,
#    'test_positive': 14,
#    'test_negative': 93},
#   '3-19-2020': {'cases': 16,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 118,
#    'test_positive': 16,
#    'test_negative': 93},
#   '3-20-2020': {'cases': 26,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 159,
#    'test_positive': 26,
#    'test_negative': 124},
#   '3-21-2020': {'cases': 37,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 170,
#    'test_positive': 37,
#    'test_negative': 124},
#   '3-22-2020': {'cases': 53,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 311,
#    'test_positive': 48,
#    'test_negative': 263},
#   '3-23-2020': {'cases': 56,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 3011,
#    'test_positive': 56,
#    'test_negative': 2955},
#   '3-24-2020': {'cases': 90,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 3666,
#    'test_positive': 77,
#    'test_negative': 3589},
#   '3-25-2020': {'cases': 91,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 4447,
#    'test_positive': 90,
#    'test_negative': 4357},
#   '3-26-2020': {'cases': 95,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 4452,
#    'test_positive': 95,
#    'test_negative': 4357},
#   '3-27-2020': {'cases': 106,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 4466,
#    'test_positive': 106,
#    'test_negative': 4357}},
#  'Idaho': {'3-10-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 41,
#    'test_positive': 0,
#    'test_negative': 41},
#   '3-11-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 67,
#    'test_positive': 0,
#    'test_negative': 67},
#   '3-12-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 93,
#    'test_positive': 0,
#    'test_negative': 93},
#   '3-13-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 131,
#    'test_positive': 0,
#    'test_negative': 131},
#   '3-14-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 176,
#    'test_positive': 2,
#    'test_negative': 174},
#   '3-15-2020': {'cases': 5,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 179,
#    'test_positive': 5,
#    'test_negative': 174},
#   '3-16-2020': {'cases': 5,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 270,
#    'test_positive': 5,
#    'test_negative': 265},
#   '3-17-2020': {'cases': 8,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 353,
#    'test_positive': 7,
#    'test_negative': 346},
#   '3-18-2020': {'cases': 9,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 468,
#    'test_positive': 9,
#    'test_negative': 459},
#   '3-19-2020': {'cases': 11,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 468,
#    'test_positive': 11,
#    'test_negative': 457},
#   '3-20-2020': {'cases': 23,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 613,
#    'test_positive': 23,
#    'test_negative': 590},
#   '3-21-2020': {'cases': 36,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 911,
#    'test_positive': 31,
#    'test_negative': 880},
#   '3-22-2020': {'cases': 42,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1217,
#    'test_positive': 42,
#    'test_negative': 1175},
#   '3-23-2020': {'cases': 68,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1356,
#    'test_positive': 47,
#    'test_negative': 1309},
#   '3-24-2020': {'cases': 81,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1937,
#    'test_positive': 50,
#    'test_negative': 1887},
#   '3-25-2020': {'cases': 91,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1960,
#    'test_positive': 73,
#    'test_negative': 1887},
#   '3-26-2020': {'cases': 146,
#    'deaths': 3,
#    'recovered': 0,
#    'test_total': 2188,
#    'test_positive': 123,
#    'test_negative': 2065},
#   '3-27-2020': {'cases': 205,
#    'deaths': 3,
#    'recovered': 0,
#    'test_total': 2857,
#    'test_positive': 189,
#    'test_negative': 2668},
#   '3-9-2020': {'test_total': 41, 'test_positive': 0, 'test_negative': 41},
#   '3-8-2020': {'test_total': 27, 'test_positive': 0, 'test_negative': 27},
#   '3-7-2020': {'test_total': 27, 'test_positive': 0, 'test_negative': 27}},
#  'Illinois': {'1-24-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-25-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-26-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-27-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-28-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-29-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-30-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-31-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '2-1-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '2-2-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '2-3-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '2-4-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '2-5-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '2-6-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '2-7-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '2-8-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '2-9-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-10-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-11-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-12-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-13-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-14-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-15-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-16-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-17-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-18-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-19-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-20-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-21-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-22-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-23-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-24-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-25-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-26-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-27-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-28-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '2-29-2020': {'cases': 2, 'deaths': 0, 'recovered': 2},
#   '3-1-2020': {'cases': 3, 'deaths': 0, 'recovered': 2},
#   '3-2-2020': {'cases': 4, 'deaths': 0, 'recovered': 2},
#   '3-3-2020': {'cases': 4, 'deaths': 0, 'recovered': 2},
#   '3-4-2020': {'cases': 4,
#    'deaths': 0,
#    'recovered': 2,
#    'test_total': 155,
#    'test_positive': 4,
#    'test_negative': 124},
#   '3-5-2020': {'cases': 5,
#    'deaths': 0,
#    'recovered': 2,
#    'test_total': 197,
#    'test_positive': 5,
#    'test_negative': 165},
#   '3-6-2020': {'cases': 5,
#    'deaths': 0,
#    'recovered': 2,
#    'test_total': 220,
#    'test_positive': 5,
#    'test_negative': 180},
#   '3-7-2020': {'cases': 6,
#    'deaths': 0,
#    'recovered': 2,
#    'test_total': 241,
#    'test_positive': 6,
#    'test_negative': 191},
#   '3-8-2020': {'cases': 7,
#    'deaths': 0,
#    'recovered': 2,
#    'test_total': 241,
#    'test_positive': 6,
#    'test_negative': 191},
#   '3-9-2020': {'cases': 7,
#    'deaths': 0,
#    'recovered': 2,
#    'test_total': 242,
#    'test_positive': 7,
#    'test_negative': 191},
#   '3-10-2020': {'cases': 12,
#    'deaths': 0,
#    'recovered': 2,
#    'test_total': 326,
#    'test_positive': 19,
#    'test_negative': 244},
#   '3-11-2020': {'cases': 25,
#    'deaths': 0,
#    'recovered': 2,
#    'test_total': 326,
#    'test_positive': 19,
#    'test_negative': 244},
#   '3-12-2020': {'cases': 32,
#    'deaths': 0,
#    'recovered': 2,
#    'test_total': 367,
#    'test_positive': 25,
#    'test_negative': 266},
#   '3-13-2020': {'cases': 46,
#    'deaths': 0,
#    'recovered': 2,
#    'test_total': 418,
#    'test_positive': 32,
#    'test_negative': 294},
#   '3-14-2020': {'cases': 64,
#    'deaths': 0,
#    'recovered': 2,
#    'test_total': 444,
#    'test_positive': 46,
#    'test_negative': 316},
#   '3-15-2020': {'cases': 93,
#    'deaths': 0,
#    'recovered': 2,
#    'test_total': 708,
#    'test_positive': 64,
#    'test_negative': 449},
#   '3-16-2020': {'cases': 105,
#    'deaths': 0,
#    'recovered': 2,
#    'test_total': 1025,
#    'test_positive': 93,
#    'test_negative': 932},
#   '3-17-2020': {'cases': 161,
#    'deaths': 1,
#    'recovered': 2,
#    'test_total': 1500,
#    'test_positive': 160,
#    'test_negative': 1340},
#   '3-18-2020': {'cases': 162,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 2051,
#    'test_positive': 288,
#    'test_negative': 1763},
#   '3-19-2020': {'cases': 422,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 3147,
#    'test_positive': 422,
#    'test_negative': 2725},
#   '3-20-2020': {'cases': 585,
#    'deaths': 5,
#    'recovered': 0,
#    'test_total': 4281,
#    'test_positive': 585,
#    'test_negative': 3696},
#   '3-21-2020': {'cases': 753,
#    'deaths': 6,
#    'recovered': 0,
#    'test_total': 6241,
#    'test_positive': 753,
#    'test_negative': 5488},
#   '3-22-2020': {'cases': 1049,
#    'deaths': 9,
#    'recovered': 0,
#    'test_total': 8320,
#    'test_positive': 1049,
#    'test_negative': 7271},
#   '3-23-2020': {'cases': 1285,
#    'deaths': 12,
#    'recovered': 0,
# ...
#   '1-25-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-26-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-27-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-28-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-29-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-30-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-31-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-1-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-2-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-3-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-4-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-5-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-6-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-7-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-8-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-9-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-10-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-11-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-12-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-13-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-14-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-15-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-16-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-17-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-18-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-19-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-20-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-21-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-22-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-23-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-24-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-25-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-26-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-27-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-28-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-29-2020': {'cases': 7, 'deaths': 1, 'recovered': 1},
#   '3-1-2020': {'cases': 11, 'deaths': 1, 'recovered': 1},
#   '3-2-2020': {'cases': 18, 'deaths': 6, 'recovered': 1},
#   '3-3-2020': {'cases': 27, 'deaths': 7, 'recovered': 1},
#   '3-4-2020': {'cases': 39,
#    'deaths': 10,
#    'recovered': 1,
#    'test_total': 39,
#    'test_positive': 39,
#    'test_negative': None},
#   '3-5-2020': {'cases': 70,
#    'deaths': 11,
#    'recovered': 1,
#    'test_total': 70,
#    'test_positive': 70,
#    'test_negative': None},
#   '3-6-2020': {'cases': 83,
#    'deaths': 13,
#    'recovered': 1,
#    'test_total': 449,
#    'test_positive': 79,
#    'test_negative': 370},
#   '3-7-2020': {'cases': 107,
#    'deaths': 16,
#    'recovered': 1,
#    'test_total': 538,
#    'test_positive': 102,
#    'test_negative': 370},
#   '3-8-2020': {'cases': 128,
#    'deaths': 18,
#    'recovered': 1,
#    'test_total': 802,
#    'test_positive': 102,
#    'test_negative': 640},
#   '3-9-2020': {'cases': 128,
#    'deaths': 19,
#    'recovered': 1,
#    'test_total': 1246,
#    'test_positive': 136,
#    'test_negative': 1110},
#   '3-10-2020': {'cases': 267,
#    'deaths': 23,
#    'recovered': 1,
#    'test_total': 1272,
#    'test_positive': 162,
#    'test_negative': 1110},
#   '3-11-2020': {'cases': 366,
#    'deaths': 29,
#    'recovered': 1,
#    'test_total': 2442,
#    'test_positive': 267,
#    'test_negative': 2175},
#   '3-12-2020': {'cases': 442,
#    'deaths': 31,
#    'recovered': 1,
#    'test_total': 3374,
#    'test_positive': 337,
#    'test_negative': 3037},
#   '3-13-2020': {'cases': 568,
#    'deaths': 37,
#    'recovered': 1,
#    'test_total': 4807,
#    'test_positive': 457,
#    'test_negative': 4350},
#   '3-14-2020': {'cases': 572,
#    'deaths': 37,
#    'recovered': 1,
#    'test_total': 6569,
#    'test_positive': 568,
#    'test_negative': 6001},
#   '3-15-2020': {'cases': 643,
#    'deaths': 40,
#    'recovered': 1,
#    'test_total': 7764,
#    'test_positive': 642,
#    'test_negative': 7122},
#   '3-16-2020': {'cases': 904,
#    'deaths': 48,
#    'recovered': 1,
#    'test_total': 10220,
#    'test_positive': 769,
#    'test_negative': 9451},
#   '3-17-2020': {'cases': 1076,
#    'deaths': 55,
#    'recovered': 1,
#    'test_total': 12486,
#    'test_positive': 904,
#    'test_negative': 11582},
#   '3-18-2020': {'cases': 1014,
#    'deaths': 55,
#    'recovered': 0,
#    'test_total': 14129,
#    'test_positive': 1012,
#    'test_negative': 13117},
#   '3-19-2020': {'cases': 1376,
#    'deaths': 74,
#    'recovered': 0,
#    'test_total': 17105,
#    'test_positive': 1187,
#    'test_negative': 15918},
#   '3-20-2020': {'cases': 1524,
#    'deaths': 83,
#    'recovered': 0,
#    'test_total': 20712,
#    'test_positive': 1376,
#    'test_negative': 19336},
#   '3-21-2020': {'cases': 1793,
#    'deaths': 94,
#    'recovered': 0,
#    'test_total': 23243,
#    'test_positive': 1524,
#    'test_negative': 21719},
#   '3-22-2020': {'cases': 1997,
#    'deaths': 97,
#    'recovered': 0,
#    'test_total': 27121,
#    'test_positive': 1793,
#    'test_negative': 25328},
#   '3-23-2020': {'cases': 2221,
#    'deaths': 109,
#    'recovered': 0,
#    'test_total': 30875,
#    'test_positive': 1996,
#    'test_negative': 28879},
#   '3-24-2020': {'cases': 2328,
#    'deaths': 116,
#    'recovered': 0,
#    'test_total': 33933,
#    'test_positive': 2221,
#    'test_negative': 31712},
#   '3-25-2020': {'cases': 2591,
#    'deaths': 133,
#    'recovered': 0,
#    'test_total': 34181,
#    'test_positive': 2469,
#    'test_negative': 31712},
#   '3-26-2020': {'cases': 3207,
#    'deaths': 150,
#    'recovered': 0,
#    'test_total': 34292,
#    'test_positive': 2580,
#    'test_negative': 31712},
#   '3-27-2020': {'cases': 3477,
#    'deaths': 157,
#    'recovered': 0,
#    'test_total': 46380,
#    'test_positive': 3207,
#    'test_negative': 43173}},
#  'West Virginia': {'3-10-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 5,
#    'test_positive': 0,
#    'test_negative': 2},
#   '3-11-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 5,
#    'test_positive': 0,
#    'test_negative': 3},
#   '3-12-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 8,
#    'test_positive': 0,
#    'test_negative': 7},
#   '3-13-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 21,
#    'test_positive': 0,
#    'test_negative': 17},
#   '3-14-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 31,
#    'test_positive': 0,
#    'test_negative': 26},
#   '3-15-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 39,
#    'test_positive': 0,
#    'test_negative': 38},
#   '3-16-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 84,
#    'test_positive': 0,
#    'test_negative': 80},
#   '3-17-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 84,
#    'test_positive': 0,
#    'test_negative': 80},
#   '3-18-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 137,
#    'test_positive': 1,
#    'test_negative': 122},
#   '3-19-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 148,
#    'test_positive': 2,
#    'test_negative': 143},
#   '3-20-2020': {'cases': 7,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 239,
#    'test_positive': 7,
#    'test_negative': 219},
#   '3-21-2020': {'cases': 8,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 343,
#    'test_positive': 11,
#    'test_negative': 330},
#   '3-22-2020': {'cases': 16,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 398,
#    'test_positive': 12,
#    'test_negative': 385},
#   '3-23-2020': {'cases': 16,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 464,
#    'test_positive': 16,
#    'test_negative': 444},
#   '3-24-2020': {'cases': 22,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 630,
#    'test_positive': 20,
#    'test_negative': 610},
#   '3-25-2020': {'cases': 39,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 804,
#    'test_positive': 39,
#    'test_negative': 759},
#   '3-26-2020': {'cases': 52,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1101,
#    'test_positive': 51,
#    'test_negative': 1031},
#   '3-27-2020': {'cases': 76,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1898,
#    'test_positive': 76,
#    'test_negative': 1779},
#   '3-9-2020': {'test_total': 5, 'test_positive': 0, 'test_negative': 2},
#   '3-8-2020': {'test_total': 5, 'test_positive': 0, 'test_negative': 2},
#   '3-7-2020': {'test_total': 5, 'test_positive': 0, 'test_negative': 2},
#   '3-6-2020': {'test_total': 5, 'test_positive': 0, 'test_negative': 1}},
#  'Wisconsin': {'2-5-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-6-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-7-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-8-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-9-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-10-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-11-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-12-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-13-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-14-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-15-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-16-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-17-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-18-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-19-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-20-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-21-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-22-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-23-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-24-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-25-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-26-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-27-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-28-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-29-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '3-1-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '3-2-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '3-3-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '3-4-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 26,
#    'test_positive': 1,
#    'test_negative': 19},
#   '3-5-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 26,
#    'test_positive': 1,
#    'test_negative': 19},
#   '3-6-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 44,
#    'test_positive': 1,
#    'test_negative': 31},
#   '3-7-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 44,
#    'test_positive': 1,
#    'test_negative': 31},
#   '3-8-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 44,
#    'test_positive': 1,
#    'test_negative': 31},
#   '3-9-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 37,
#    'test_positive': 1,
#    'test_negative': 36},
#   '3-10-2020': {'cases': 3,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 38,
#    'test_positive': 2,
#    'test_negative': 36},
#   '3-11-2020': {'cases': 6,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 46,
#    'test_positive': 3,
#    'test_negative': 43},
#   '3-12-2020': {'cases': 8,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 92,
#    'test_positive': 8,
#    'test_negative': 84},
#   '3-13-2020': {'cases': 19,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 188,
#    'test_positive': 19,
#    'test_negative': 169},
#   '3-14-2020': {'cases': 27,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 188,
#    'test_positive': 19,
#    'test_negative': 169},
#   '3-15-2020': {'cases': 32,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 346,
#    'test_positive': 33,
#    'test_negative': 313},
#   '3-16-2020': {'cases': 47,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 551,
#    'test_positive': 47,
#    'test_negative': 504},
#   '3-17-2020': {'cases': 72,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 1110,
#    'test_positive': 72,
#    'test_negative': 1038},
#   '3-18-2020': {'cases': 92,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1683,
#    'test_positive': 106,
#    'test_negative': 1577},
#   '3-19-2020': {'cases': 159,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2347,
#    'test_positive': 155,
#    'test_negative': 2192},
#   '3-20-2020': {'cases': 207,
#    'deaths': 3,
#    'recovered': 0,
#    'test_total': 3661,
#    'test_positive': 206,
#    'test_negative': 3455},
#   '3-21-2020': {'cases': 282,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 4909,
#    'test_positive': 281,
#    'test_negative': 4628},
#   '3-22-2020': {'cases': 381,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 6615,
#    'test_positive': 385,
#    'test_negative': 6230},
#   '3-23-2020': {'cases': 425,
#    'deaths': 5,
#    'recovered': 0,
#    'test_total': 7466,
#    'test_positive': 416,
#    'test_negative': 7050},
#   '3-24-2020': {'cases': 481,
#    'deaths': 5,
#    'recovered': 0,
#    'test_total': 8694,
#    'test_positive': 457,
#    'test_negative': 8237},
#   '3-25-2020': {'cases': 621,
#    'deaths': 7,
#    'recovered': 0,
#    'test_total': 10674,
#    'test_positive': 585,
#    'test_negative': 10089},
#   '3-26-2020': {'cases': 728,
#    'deaths': 10,
#    'recovered': 0,
#    'test_total': 12290,
#    'test_positive': 707,
#    'test_negative': 11583},
#   '3-27-2020': {'cases': 926,
#    'deaths': 14,
#    'recovered': 0,
#    'test_total': 13982,
#    'test_positive': 842,
#    'test_negative': 13140}},
#  'Wyoming': {'3-10-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 0,
#    'test_positive': 0,
#    'test_negative': 0},
#   '3-11-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 0,
#    'test_positive': 0,
#    'test_negative': None},
#   '3-12-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1,
#    'test_positive': 1,
#    'test_negative': None},
#   '3-13-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1,
#    'test_positive': 1,
#    'test_negative': None},
#   '3-14-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2,
#    'test_positive': 2,
#    'test_negative': None},
#   '3-15-2020': {'cases': 3,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 3,
#    'test_positive': 3,
#    'test_negative': None},
#   '3-16-2020': {'cases': 3,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 3,
#    'test_positive': 3,
#    'test_negative': None},
#   '3-17-2020': {'cases': 11,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 105,
#    'test_positive': 10,
#    'test_negative': 95},
#   '3-18-2020': {'cases': 15,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 193,
#    'test_positive': 15,
#    'test_negative': 178},
#   '3-19-2020': {'cases': 18,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 289,
#    'test_positive': 18,
#    'test_negative': 271},
#   '3-20-2020': {'cases': 19,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 350,
#    'test_positive': 19,
#    'test_negative': 331},
#   '3-21-2020': {'cases': 23,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 461,
#    'test_positive': 23,
#    'test_negative': 438},
#   '3-22-2020': {'cases': 26,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 462,
#    'test_positive': 24,
#    'test_negative': 438},
#   '3-23-2020': {'cases': 26,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 618,
#    'test_positive': 26,
#    'test_negative': 592},
#   '3-24-2020': {'cases': 29,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 739,
#    'test_positive': 29,
#    'test_negative': 710},
#   '3-25-2020': {'cases': 44,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 998,
#    'test_positive': 44,
#    'test_negative': 954},
#   '3-26-2020': {'cases': 53,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1105,
#    'test_positive': 53,
#    'test_negative': 1052},
#   '3-27-2020': {'cases': 70,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1281,
#    'test_positive': 70,
#    'test_negative': 1211},
#   '3-9-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': None},
#   '3-8-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': None},
#   '3-7-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': None}}}

# %% [markdown]
# #### Add today's data to state time series

# %% [markdown]
# This makes it look like curve is flattening, so we adding it now, but dont display it until the next day

# %%
for cur_state in state_json["features"]:
    props = cur_state["properties"]
    statename = props["statename"]
    state_time_data[statename][todays_date] = {
        "cases":props["cases"], 
        "deaths":props["deaths"],
        "recovered":props["recovered"],
        "test_total":props["test_total"],
        "test_negative":props["test_negative"],
        "test_positive":props["test_positive"],
    }

# %% [markdown]
# #### Add old state date to state time series

# %%
for state in state_json["features"]:
    statename = state["properties"]["statename"]
    if statename in state_time_data.keys():
        state["properties"]["time_series"] = state_time_data[statename]

# %% [markdown]
# #### Save latest state time series data to file

# %%
state_json["features"][0]
# Out:
# {'type': 'Feature',
#  'id': '01',
#  'properties': {'population': 4903185,
#   'beds': 19000,
#   'density': 94.65,
#   'statename': 'Alabama',
#   'lat': 32.78990682135675,
#   'long': -86.82778271419518,
#   'abbr': 'AL',
#   'cases': 638,
#   'deaths': 4,
#   'active': 634,
#   'recovered': 0,
#   'time_cases_update': '3/28 12:15PM',
#   'time_tests_updated': '3/28 0:00AM',
#   'test_grade': 'B',
#   'test_positive': 644,
#   'test_negative': 4184,
#   'test_total': 4828,
#   'pc_cases': 13.011950395508226,
#   'pc_active': 12.9303707692041,
#   'pc_deaths': 0.08157962630412681,
#   'pc_tests': 98.46660894908106,
#   'time_series': {'3-13-2020': {'cases': 5,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 12,
#     'test_positive': 1,
#     'test_negative': 11},
#    '3-14-2020': {'cases': 6,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 74,
#     'test_positive': 6,
#     'test_negative': 22},
#    '3-15-2020': {'cases': 12,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 86,
#     'test_positive': 12,
#     'test_negative': 28},
#    '3-16-2020': {'cases': 29,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 96,
#     'test_positive': 28,
#     'test_negative': 28},
#    '3-17-2020': {'cases': 39,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 64,
#     'test_positive': 36,
#     'test_negative': 28},
#    '3-18-2020': {'cases': 46,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 74,
#     'test_positive': 46,
#     'test_negative': 28},
#    '3-19-2020': {'cases': 78,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 96,
#     'test_positive': 68,
#     'test_negative': 28},
#    '3-20-2020': {'cases': 83,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 109,
#     'test_positive': 81,
#     'test_negative': 28},
#    '3-21-2020': {'cases': 131,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 152,
#     'test_positive': 124,
#     'test_negative': 28},
#    '3-22-2020': {'cases': 157,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 1602,
#     'test_positive': 138,
#     'test_negative': 1464},
#    '3-23-2020': {'cases': 196,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 1832,
#     'test_positive': 167,
#     'test_negative': 1665},
#    '3-24-2020': {'cases': 242,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 2321,
#     'test_positive': 215,
#     'test_negative': 2106},
#    '3-25-2020': {'cases': 381,
#     'deaths': 1,
#     'recovered': 0,
#     'test_total': 2812,
#     'test_positive': 283,
#     'test_negative': 2529},
#    '3-26-2020': {'cases': 517,
#     'deaths': 1,
#     'recovered': 0,
#     'test_total': 4099,
#     'test_positive': 506,
#     'test_negative': 3593},
#    '3-27-2020': {'cases': 587,
#     'deaths': 4,
#     'recovered': 0,
#     'test_total': 4771,
#     'test_positive': 587,
#     'test_negative': 4184},
#    '3-12-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#    '3-11-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#    '3-10-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#    '3-9-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': None},
#    '3-8-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': None},
#    '3-7-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': None},
#    '3-28-2020': {'cases': 638,
#     'deaths': 4,
#     'recovered': 0,
#     'test_total': 4828,
#     'test_negative': 4184,
#     'test_positive': 644}}},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-87.359296, 35.00118],
#     [-85.606675, 34.984749],
#     [-85.431413, 34.124869],
#     [-85.184951, 32.859696],
#     [-85.069935, 32.580372],
#     [-84.960397, 32.421541],
#     [-85.004212, 32.322956],
#     [-84.889196, 32.262709],
#     [-85.058981, 32.13674],
#     [-85.053504, 32.01077],
#     [-85.141136, 31.840985],
#     [-85.042551, 31.539753],
#     [-85.113751, 31.27686],
#     [-85.004212, 31.003013],
#     [-85.497137, 30.997536],
#     [-87.600282, 30.997536],
#     [-87.633143, 30.86609],
#     [-87.408589, 30.674397],
#     [-87.446927, 30.510088],
#     [-87.37025, 30.427934],
#     [-87.518128, 30.280057],
#     [-87.655051, 30.247195],
#     [-87.90699, 30.411504],
#     [-87.934375, 30.657966],
#     [-88.011052, 30.685351],
#     [-88.10416, 30.499135],
#     [-88.137022, 30.318396],
#     [-88.394438, 30.367688],
#     [-88.471115, 31.895754],
#     [-88.241084, 33.796253],
#     [-88.098683, 34.891641],
#     [-88.202745, 34.995703],
#     [-87.359296, 35.00118]]]}}

# %%
with open(county_data_folder/"stateTimeData.json", 'w') as f:
    json.dump(county_time_data, f)

# %% [markdown]
# ## Calculate Risk

# %% [markdown]
# ### Add in county risk

# %%
#111 is to convert degrees to kilometers
def get_distance(c0, c1):
    lat_dist = abs(c0[0])-abs(c1[0])
    lng_dist = abs(c0[1])-abs(c1[1])
    distance = 111 * math.sqrt(lat_dist**2 + lng_dist**2)
    return float(distance)

# %% [markdown]
# #### County Local Risk

# %%
def calc_county_local_risk(props):
    cases = props["cases"]
    try:
        population = props["population"]
    except KeyError:
        print_and_log(f"{props['name']}, {props['statename']}")
        raise KeyError
    if cases == 'NaN': 
        print_and_log('NaN cases found')
        cases = 0
    return cases/(population/100000) if population != -1 else -1

# %%
print_and_log("\nCalculating local county risk")
for county in counties:
    county["properties"]["risk_local"] = calc_county_local_risk(county["properties"])
# Out:
# Calculating local county risk

# %% [markdown]
# #### County Neighbor Risk

# %%
def calc_county_neighbor_risk(risks):
    total_neighbor_risk = 0
    num_risks = len(risks)
    if(num_risks == 0): return 0
    total_cases = 0
    total_pop = 0
    for risk in risks.values():
        distance, neighbor_cases, neighbor_pop = risk.values()
        #total_neighbor_risk += (float(neighbor_cases)*(2**((-distance-50)/50)))
        exp = 2**((-distance-50)/50)
        total_cases += float(neighbor_cases)*(2**((-distance-50)/50))
        total_pop += (float(neighbor_pop)*(2**((-distance-50)/50)))/100000
    total_neighbor_risk = total_cases/total_pop
    return total_neighbor_risk

# %%
def get_county_all_neighbor_risk(props):
    risk_details = {}
    for county in counties:
        neighbor_props = county["properties"]
        neighbor_risk = get_county_neighbor_risk(props, neighbor_props)
        if(neighbor_risk != {}): risk_details[neighbor_props["geo_id"]] = neighbor_risk
    props["risk_nearby"] = calc_county_neighbor_risk(risk_details)
    props["risk_total"] = props["risk_nearby"] + props["risk_local"]

# %%
MAX_DISTANCE = 100
def get_county_neighbor_risk(props, neighbor_props):
    geoID1 = props["geo_id"]
    geoID2 = neighbor_props["geo_id"]
    centroid = [props["lat"], props["long"]]
    centroid_neighbor = [neighbor_props["lat"], neighbor_props["long"]]
    distance = get_distance(centroid, centroid_neighbor)
    neighbor_cases = neighbor_props["cases"]
    neighbor_population = neighbor_props["population"]
    if(geoID1 == geoID2 or distance > MAX_DISTANCE or neighbor_cases == "NaN"): 
        return {}
    else:
        return {"distance":distance, "cases":neighbor_cases, "pop":neighbor_population}

# %%
print_and_log("\nCalculating local county risk")
for county in counties:
    get_county_all_neighbor_risk(county["properties"])
# Out:
# Calculating local county risk

# %% [markdown]
# ### Add in state risk

# %% [markdown]
# ####  Local State Risk

# %%
#111 is to convert degrees to kilometers
def get_distance(c0, c1):
    lat_dist = abs(c0[0])-abs(c1[0])
    lng_dist = abs(c0[1])-abs(c1[1])
    distance = 111 * math.sqrt(lat_dist**2 + lng_dist**2)
    return distance

# %%
def calc_state_local_risk(props):
    #changed from props["active"] change back when possible
    cases = props["cases"]
    population = props.get("population", -1)
    if cases == 'NaN': cases = 0
    return cases/(population/100000) if population != -1 else -1

# %%
print_and_log("Calculating local state risk")
for state in state_json["features"]:
    state["properties"]["risk_local"] = calc_state_local_risk(state["properties"])
# Out:
# Calculating local state risk

# %% [markdown]
# #### Neighbor State Risk

# %%
def get_state_all_neighbor_risk(props):
    risk_details = {}
    for state in state_json["features"]:
        neighbor_props = state["properties"]
        neighbor_risk = get_state_neighbor_risk(props, neighbor_props)
        if(neighbor_risk != {}): 
            risk_details[neighbor_props["abbr"]] = neighbor_risk
    props["risk_nearby"] = calc_state_neighbor_risk(risk_details)
    props["risk_total"] = props["risk_nearby"] + props["risk_local"]

# %%
def calc_state_neighbor_risk(risks):
    num_risks = len(risks)
    total_neighbor_risk = 0
    for risk in risks.values():
        distance, neighbor_cases, neighbor_pop = risk.values()
        total_neighbor_risk += (neighbor_cases*(2**((-distance-150)/50)))
    return total_neighbor_risk

# %%
def get_state_neighbor_risk(props, neighbor_props):
    neighbor_centroid = [neighbor_props["lat"], neighbor_props["long"]]
    #changed from props["active"] change back when possible
    neighbor_cases = neighbor_props["cases"]
    neighbor_pop = neighbor_props["population"]
    centroid = [props["lat"], props["long"]]
    distance = get_distance(centroid, neighbor_centroid)
    if(props["abbr"] == neighbor_props["abbr"] or neighbor_cases == "NaN"):
        return {}
    else:
        return {"DISTANCE":distance, "CASES":neighbor_cases, "POP":neighbor_pop}

# %%
print_and_log("Calculating neighbor state risk\n")
for state in state_json["features"]:
    get_state_all_neighbor_risk(state["properties"])
# Out:
# Calculating neighbor state risk

# %% [markdown]
# ## View Output

# %%
county_json["features"][408]
# Out:
# {'type': 'Feature',
#  'properties': {'geo_id': '0500000US39089',
#   'county': '089',
#   'name': 'Licking',
#   'lsad': 'County',
#   'censusarea': 682.5,
#   'state': '39',
#   'statename': 'Ohio',
#   'stateabbr': 'OH',
#   'population': 175769,
#   'land_area': '682.50',
#   'housing_units': '69291',
#   'population_density': 257.5369963369963,
#   'lat': -82.48315238695075,
#   'long': 40.09160968135006,
#   'cases': 10,
#   'deaths': 0,
#   'active': 10,
#   'recovered': 0,
#   'time_cases_update': '3/28 12:15PM',
#   'pc_cases': 5.689285368864817,
#   'pc_deaths': 0.0,
#   'time_series': {'3-15-2020': {'cases': 0, 'deaths': None},
#    '3-17-2020': {'cases': 0, 'deaths': None},
#    '3-18-2020': {'cases': 0, 'deaths': 0},
#    '3-19-2020': {'cases': 0, 'deaths': 0},
#    '3-20-2020': {'cases': 0, 'deaths': 0},
#    '3-22-2020': {'cases': 1, 'deaths': 0},
#    '3-23-2020': {'cases': 1, 'deaths': 0},
#    '3-24-2020': {'cases': 2, 'deaths': 0},
#    '3-25-2020': {'cases': 3, 'deaths': 0},
#    '3-26-2020': {'cases': 5, 'deaths': 0},
#    '3-27-2020': {'cases': 10, 'deaths': 0},
#    '3-28-2020': {'cases': 10, 'deaths': 0}},
#   'risk_local': 5.689285368864817,
#   'risk_nearby': 8.459764019092015,
#   'risk_total': 14.149049387956833},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-82.581813, 39.930156],
#     [-82.782495, 39.939662],
#     [-82.761827, 40.125855],
#     [-82.750747, 40.276996],
#     [-82.476114, 40.264703],
#     [-82.364344, 40.240957],
#     [-82.326025, 40.239725],
#     [-82.195911, 40.239071],
#     [-82.182823, 40.238624],
#     [-82.187105, 40.16688],
#     [-82.198772, 39.95014],
#     [-82.233974, 39.91326],
#     [-82.462813, 39.93038],
#     [-82.473423, 39.925065],
#     [-82.581813, 39.930156]]]}}

# %%
state_json["features"][0]
# Out:
# {'type': 'Feature',
#  'id': '01',
#  'properties': {'population': 4903185,
#   'beds': 19000,
#   'density': 94.65,
#   'statename': 'Alabama',
#   'lat': 32.78990682135675,
#   'long': -86.82778271419518,
#   'abbr': 'AL',
#   'cases': 638,
#   'deaths': 4,
#   'active': 634,
#   'recovered': 0,
#   'time_cases_update': '3/28 12:15PM',
#   'time_tests_updated': '3/28 0:00AM',
#   'test_grade': 'B',
#   'test_positive': 644,
#   'test_negative': 4184,
#   'test_total': 4828,
#   'pc_cases': 13.011950395508226,
#   'pc_active': 12.9303707692041,
#   'pc_deaths': 0.08157962630412681,
#   'pc_tests': 98.46660894908106,
#   'time_series': {'3-13-2020': {'cases': 5,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 12,
#     'test_positive': 1,
#     'test_negative': 11},
#    '3-14-2020': {'cases': 6,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 74,
#     'test_positive': 6,
#     'test_negative': 22},
#    '3-15-2020': {'cases': 12,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 86,
#     'test_positive': 12,
#     'test_negative': 28},
#    '3-16-2020': {'cases': 29,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 96,
#     'test_positive': 28,
#     'test_negative': 28},
#    '3-17-2020': {'cases': 39,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 64,
#     'test_positive': 36,
#     'test_negative': 28},
#    '3-18-2020': {'cases': 46,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 74,
#     'test_positive': 46,
#     'test_negative': 28},
#    '3-19-2020': {'cases': 78,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 96,
#     'test_positive': 68,
#     'test_negative': 28},
#    '3-20-2020': {'cases': 83,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 109,
#     'test_positive': 81,
#     'test_negative': 28},
#    '3-21-2020': {'cases': 131,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 152,
#     'test_positive': 124,
#     'test_negative': 28},
#    '3-22-2020': {'cases': 157,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 1602,
#     'test_positive': 138,
#     'test_negative': 1464},
#    '3-23-2020': {'cases': 196,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 1832,
#     'test_positive': 167,
#     'test_negative': 1665},
#    '3-24-2020': {'cases': 242,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 2321,
#     'test_positive': 215,
#     'test_negative': 2106},
#    '3-25-2020': {'cases': 381,
#     'deaths': 1,
#     'recovered': 0,
#     'test_total': 2812,
#     'test_positive': 283,
#     'test_negative': 2529},
#    '3-26-2020': {'cases': 517,
#     'deaths': 1,
#     'recovered': 0,
#     'test_total': 4099,
#     'test_positive': 506,
#     'test_negative': 3593},
#    '3-27-2020': {'cases': 587,
#     'deaths': 4,
#     'recovered': 0,
#     'test_total': 4771,
#     'test_positive': 587,
#     'test_negative': 4184},
#    '3-12-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#    '3-11-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#    '3-10-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#    '3-9-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': None},
#    '3-8-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': None},
#    '3-7-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': None},
#    '3-28-2020': {'cases': 638,
#     'deaths': 4,
#     'recovered': 0,
#     'test_total': 4828,
#     'test_negative': 4184,
#     'test_positive': 644}},
#   'risk_local': 13.011950395508226,
#   'risk_nearby': 3.9971386987489397,
#   'risk_total': 17.009089094257167},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-87.359296, 35.00118],
#     [-85.606675, 34.984749],
#     [-85.431413, 34.124869],
#     [-85.184951, 32.859696],
#     [-85.069935, 32.580372],
#     [-84.960397, 32.421541],
#     [-85.004212, 32.322956],
#     [-84.889196, 32.262709],
#     [-85.058981, 32.13674],
#     [-85.053504, 32.01077],
#     [-85.141136, 31.840985],
#     [-85.042551, 31.539753],
#     [-85.113751, 31.27686],
#     [-85.004212, 31.003013],
#     [-85.497137, 30.997536],
#     [-87.600282, 30.997536],
#     [-87.633143, 30.86609],
#     [-87.408589, 30.674397],
#     [-87.446927, 30.510088],
#     [-87.37025, 30.427934],
#     [-87.518128, 30.280057],
#     [-87.655051, 30.247195],
#     [-87.90699, 30.411504],
#     [-87.934375, 30.657966],
#     [-88.011052, 30.685351],
#     [-88.10416, 30.499135],
#     [-88.137022, 30.318396],
#     [-88.394438, 30.367688],
#     [-88.471115, 31.895754],
#     [-88.241084, 33.796253],
#     [-88.098683, 34.891641],
#     [-88.202745, 34.995703],
#     [-87.359296, 35.00118]]]}}

# %% [markdown]
# ## Export

# %%
print_and_log("Exporting Files")
# this just makes sure we dont have any encoding problems, taken from stackoverflow
class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(NpEncoder, self).default(obj)

with open("states.json", 'w') as f:
    json.dump(state_json, f, cls=NpEncoder)

with open("stateData.js", 'w') as f:
    f.write("let stateData = ")
    json.dump(state_json, f, cls=NpEncoder)
    
with open("counties.json", 'w') as f:
    json.dump(county_json, f, cls=NpEncoder)

with open("countyData.js", 'w') as f:
    f.write("let countyData = ")
    json.dump(county_json, f, cls=NpEncoder)
# Out:
# Exporting Files

# %%
live_path = Path("/var/www/html/data")
test_path = Path("../covid19/data")
if(live_path.exists()):
    print_and_log("Copying data to the /var/www/html")
    shutil.copy("stateData.js", live_path/"stateData.js")
    shutil.copy("countyData.js", live_path/"countyData.js")
    print_and_log("Data successfully copied to live path")
else:
    print_and_log(f"{live_path} not found, NOT COPYING DATA")
    if(test_path.exists()):
        print_and_log("Copying data to the test path")
        shutil.copy("stateData.js", test_path/"stateData.js")
        shutil.copy("countyData.js", test_path/"countyData.js")
        print_and_log("Data successfully copied to test path")
# Out:
# \var\www\html\data not found, NOT COPYING DATA

# %% [markdown]
# ### Keep a record of each update for future time series use

# %%
with open(f"logs/data_logs/state-{date_str}.json", 'w') as f:
    json.dump(state_json, f, cls=NpEncoder)

# %%
with open(f"logs/data_logs/county-{date_str}.json", 'w') as f:
    json.dump(county_json, f, cls=NpEncoder)
