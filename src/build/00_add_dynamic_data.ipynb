# %%
import pandas as pd
import json, requests
import math
import numpy as np
from pathlib import Path
from collections import defaultdict
import datetime
import shutil
import logging
import datetime

# %% [markdown]
# ## General Setup

# %% [markdown]
# ### Read in static data

# %%
county_data_folder = Path('static_data/county')
with open(county_data_folder/"staticCounties.json", 'r') as f:
    county_json = json.load(f)

# %%
state_data_folder = Path('static_data/state')
with open(state_data_folder/"staticStates.json", 'r') as f:
    state_json = json.load(f)

# %% [markdown]
# #### Convert decimal to percent for state hypertension

# %%
for state in state_json["features"]:
    state["properties"]["comorbid_hypertension"] *= 100

# %% [markdown]
# We make one request that will be parsed once for State Data and once for county

# %%
def request_multiple_attempts(url):
    #print_and_log(f"Requesting data from {url}")
    num_requests = 0
    max_requests = 5
    req = requests.get(api_url)
    if(not req.status_code == 200):
        num_requests += 1 
        if(num_requests >= max_requests): req.raise_for_status()
        req = requests.get(api_url)
    #print_and_log("Data Received\n")
    return req

# %% [markdown]
# ### Go through the county_json records and index by geo_id

# %%
geo_id_index_dict = {}
counties = county_json["features"]
for idx, county in enumerate(counties):
    geo_id = county["properties"]["geo_id"]
    geo_id_index_dict[geo_id] = idx

# %% [markdown]
# ### Setup logging

# %%
now = datetime.datetime.now()
date_str = f"{now.month}-{now.day}-{now.year}-{now.hour}{now.minute}"

# %%
logging.basicConfig(filename=f'logs/message_logs/{date_str}.log',level=logging.DEBUG)

# %%
def print_and_log(message):
    logging.info(message)
    print(message)

# %% [markdown]
# ## Add new data from APIs

# %% [markdown]
# ### Add State Covid19 data from John's Hopkins

# %%
#data from John Hopkins CSSE
api_url = "https://covid19.mathdro.id/api/countries/USA/confirmed"
covid_jh = request_multiple_attempts(api_url).json()

# %% [markdown]
# #### Test that data appears to be valid

# %%
# there should be at least 1700 counties
num_counties = len(covid_jh)
if (num_counties < 1700): raise ValueError("Only", num_counties, " counties found in Johns Hopkins data")
mandatory_keys = ['fips', 'confirmed', 'recovered', 'deaths', 'active', 'combinedKey', 'provinceState']
for key in mandatory_keys:
    if not key in covid_jh[120]: raise ValueError("John's Hopkins Record missing key: ", key)

# %%
covid_jh[0].keys()
# Out:
# dict_keys(['provinceState', 'countryRegion', 'lastUpdate', 'lat', 'long', 'confirmed', 'recovered', 'deaths', 'active', 'admin2', 'fips', 'combinedKey', 'incidentRate', 'peopleTested', 'peopleHospitalized', 'uid', 'iso3'])

# %%
#includes ms which fromtimestamp doesnt accept so we cut it off
def get_str_from_timestamp(timestamp):
    timestamp = int(str(timestamp)[:-3])
    cur = datetime.datetime.fromtimestamp(timestamp)
    return cur.strftime('%#m/%d %#I:%M%p')

# %%
#initialize all state case data to 0
null_dict = {"cases":0, "deaths":0, "active":0, "recovered":0}
for state in state_json["features"]:
    state["properties"].update(null_dict)

# %%
keys = ["deaths", "recovered", "active"]
def add_record_to_state(record):
    for state in state_json["features"]:
        if(record["provinceState"] == state["properties"]["statename"]):
            for key in keys:
                state["properties"][key] += int(record[key])
            state["properties"]["cases"] += int(record["confirmed"])
            state["properties"]["time_cases_update"] = get_str_from_timestamp(record["lastUpdate"])
            return
    print_and_log(f"{record} unmatched")

# %%
def add_unassigned_to_state(statename, record):
    for state in state_json["features"]:
        props = state["properties"]
        if(props["statename"].lower() == statename.lower()):
            print_and_log(f'{record["confirmed"]} unassigned cases added to {statename}')
            print_and_log(f'{record["deaths"]} unassigned deaths added to {statename}')
            props["unassigned_cases"] = record["confirmed"]

# %%
skips = ["Diamond Princess, US", "Guam, US", "Grand Princess, US", "Puerto Rico, US", "Virgin Islands, US", 
         'Northern Mariana Islands, US', 'Unassigned, Northern Mariana Islands, US']
for record in covid_jh:
    if(record == {}): continue
    if record["combinedKey"] in skips: continue
    try:
        county, state, _ = map(str.strip, record["combinedKey"].split(','))
    except ValueError:
        print("Skipping record", record)
    if county == "Unassigned":
        add_unassigned_to_state(state, record)
    add_record_to_state(record)
# Out:
# 1276 unassigned cases added to Rhode Island
# 70 unassigned deaths added to Rhode Island
# 1203 unassigned cases added to New Jersey
# 2 unassigned deaths added to New Jersey
# 560 unassigned cases added to Georgia
# 1 unassigned deaths added to Georgia
# 491 unassigned cases added to Connecticut
# 4 unassigned deaths added to Connecticut
# 484 unassigned cases added to Washington
# 0 unassigned deaths added to Washington
# 447 unassigned cases added to Massachusetts
# 100 unassigned deaths added to Massachusetts
# 145 unassigned cases added to Colorado
# 0 unassigned deaths added to Colorado
# 78 unassigned cases added to Michigan
# 4 unassigned deaths added to Michigan
# 65 unassigned cases added to Illinois
# 1 unassigned deaths added to Illinois
# 56 unassigned cases added to Louisiana
# 0 unassigned deaths added to Louisiana
# 46 unassigned cases added to Tennessee
# 0 unassigned deaths added to Tennessee
# 42 unassigned cases added to Arkansas
# 0 unassigned deaths added to Arkansas
# 39 unassigned cases added to Vermont
# 0 unassigned deaths added to Vermont
# 34 unassigned cases added to Minnesota
# 0 unassigned deaths added to Minnesota
# 23 unassigned cases added to Kentucky
# 0 unassigned deaths added to Kentucky
# 18 unassigned cases added to Nebraska
# 3 unassigned deaths added to Nebraska
# 5 unassigned cases added to Maine
# 0 unassigned deaths added to Maine
# 3 unassigned cases added to Delaware
# 0 unassigned deaths added to Delaware
# 3 unassigned cases added to Hawaii
# 0 unassigned deaths added to Hawaii
# 2 unassigned cases added to Florida
# 0 unassigned deaths added to Florida
# 1 unassigned cases added to Missouri
# 0 unassigned deaths added to Missouri
# 1 unassigned cases added to New Hampshire
# 20 unassigned deaths added to New Hampshire

# %% [markdown]
# ### Add County Covid Data19 from John's Hopkins

# %%
#initialize all county case data to 0
for county in counties:
    county["properties"].update(null_dict)

# %%
skips = ["Diamond Princess, US", "Guam, US", "Grand Princess, US", "Puerto Rico, US", "Virgin Islands, US"]
missing_fips = {
    "Dona Ana,New Mexico,US":"35013", 
    "Kansas City,Missouri,US":"29095", 
    "Dukes and Nantucket,Massachusetts,US":"25007"
}

# %%
def add_record_to_county(record):
    if("Unassigned" in record["combinedKey"]): return
    #sub in countyid for counties that have missing county id
    if(record["combinedKey"] in missing_fips): 
        record["fips"] = missing_fips[record["combinedKey"]]
    #skip anything without a countyID
    if(record['fips'] is None or record['fips'] in ['00078', '80015', '80040', '46102', '80013']):
        print_and_log(f'No geo_id, skipping {record["combinedKey"]}')
        return
    #skip anything in the skip list
    if(record["combinedKey"] in skips): return
    geo_id = '0500000US' + record["fips"]
    
    county = counties[geo_id_index_dict[geo_id]]
    #Add the contents of record to the county
    for key in keys:
        county["properties"][key] += int(record[key])
    county["properties"]["cases"] += int(record["confirmed"])
    county["properties"]["time_cases_update"] = get_str_from_timestamp(record["lastUpdate"])

# %%
for record in covid_jh:
    add_record_to_county(record)
# Out:
# No geo_id, skipping Out of GA, Georgia, US
# No geo_id, skipping Michigan Department of Corrections (MDOC), Michigan, US
# No geo_id, skipping Kansas City, Missouri, US
# No geo_id, skipping Out of TN, Tennessee, US
# No geo_id, skipping Out of MI, Michigan, US
# No geo_id, skipping Weber, Utah, US
# No geo_id, skipping Virgin Islands, US
# No geo_id, skipping Manassas, Virginia, US
# No geo_id, skipping McDuffie, Georgia, US
# No geo_id, skipping Dukes and Nantucket, Massachusetts, US
# No geo_id, skipping Federal Correctional Institution (FCI), Michigan, US
# No geo_id, skipping LaSalle, Illinois, US
# No geo_id, skipping LaSalle, Louisiana, US
# No geo_id, skipping DeKalb, Tennessee, US
# No geo_id, skipping Fillmore, Minnesota, US
# No geo_id, skipping Northern Mariana Islands, US
# No geo_id, skipping McIntosh, Georgia, US
# No geo_id, skipping Out of HI, Hawaii, US
# No geo_id, skipping Lac qui Parle, Minnesota, US
# No geo_id, skipping Oglala Lakota, South Dakota, US

# %% [markdown]
# #### Reassign NYC to the proper counties

# %%
new_york_county = counties[geo_id_index_dict['0500000US36061']]
queens_county = counties[geo_id_index_dict['0500000US36081']]
ny_cases = new_york_county["properties"]["cases"]
ny_deaths = new_york_county["properties"]["deaths"]
ny_time_updated = new_york_county["properties"]["time_cases_update"]
queens_cases = queens_county["properties"]["cases"]
nyc_reassignment_needed = ny_cases > 0 and queens_cases == 0
if(ny_cases <= 0 or not isinstance(ny_cases, int)): raise ValueError("Problem with NYCases, value:", ny_cases)
print_and_log(f"{ny_cases} cases initially in New York County")
print_and_log(f"{queens_cases} in queens.")
print_and_log(f"Reassign needed: {nyc_reassignment_needed}")
# Out:
# 106763 cases initially in New York County
# 0 in queens.
# Reassign needed: True

# %%
# This is based on an estimate on 3/21/20 in which NYC had 5687 cases broken down as follows
# this has since been updated on 3/26/20 for data from here: 
# https://www1.nyc.gov/assets/doh/downloads/pdf/imm/covid-19-daily-data-summary.pdf
# https://www1.nyc.gov/assets/doh/downloads/pdf/imm/covid-19-daily-data-summary-deaths.pdf
# # Kings - 1750, Queens - 1514, New York 1402, Bronx 736, Richmond 285
cases_proportion_dict = {
    #code:proportion of NYC cases
    #queens
    '0500000US36081':.335515,
    #kings
    '0500000US36047':.269878,
    #Bronx
    '0500000US36005': .196217,
    #Richmond (Staten Island)
    '0500000US36085':.055885,
    #New York (Manhattan)
    '0500000US36061':.142502,
}
deaths_proportion_dict = {
    #code:proportion of NYC cases
    #queens
    '0500000US36081':.311893,
    #kings
    '0500000US36047':.270226,
    #Bronx
    '0500000US36005':.253640,
    #Richmond (Staten Island)
    '0500000US36085':.051779,
    #New York (Manhattan)
    '0500000US36061':.112055,
}
# #get cases that were all aggregated in NY county

# %%
ny_county_names = {
    '0500000US36081':'Queens County',
    '0500000US36047':'Kings County',
    '0500000US36005':'Bronx County',
    '0500000US36085':'Richmond County',
    '0500000US36061':'Manhattan',
}

# %%
print_and_log(f"\nTotal Cases listed for New York County {ny_cases}")
if(nyc_reassignment_needed):
    print_and_log("Reassigning NYC with proportional estimates")
    for county in counties:
        county_id = county["properties"]["geo_id"]
        if county_id in cases_proportion_dict.keys():
            county["properties"]["cases"] = int(ny_cases*cases_proportion_dict[county_id])
            county["properties"]["deaths"] = int(ny_deaths*deaths_proportion_dict[county_id])
            county["properties"]["time_cases_update"] = ny_time_updated
            county["properties"]["notes"] = "Data for this county is estimated"
else:
    print_and_log("\nQueens County found, not estimating NYC")
# Out:
# Total Cases listed for New York County 106763
# Reassigning NYC with proportional estimates

# %% [markdown]
# ### Add Covid Test Data from Covid Tracking Project

# %%
def format_test_time(test_time):
    d, h = test_time.split(' ')
    h, m = h.split(":")
    h = int(h)
    am_pm = "AM" if h <= 12 else "PM"
    if(am_pm) == "pm": h-=12
    return f"{d} {h}:{m}{am_pm}"

# %%
#https://covidtracking.com/api/states/info <- this api has info about where the data comes from
api_url = 'https://covidtracking.com/api/states'
state_tests = request_multiple_attempts(api_url).json()

# %% [markdown]
# #### Test that data appears to be valid

# %%
# there should be at least 50 entries
num_states = len(state_tests)
if (num_states < 50): raise ValueError("Only", num_states, " states found in covidtracking testing data")
mandatory_keys = ['state', 'lastUpdateEt', 'positive', 'negative', 'total']
for key in mandatory_keys:
    if not key in state_tests[20]: raise ValueError("CovidTracking testing missing key: ", key)

# %%
state_tests[20]
# Out:
# {'state': 'MD',
#  'positive': 9472,
#  'positiveScore': 1,
#  'negativeScore': 1,
#  'negativeRegularScore': 1,
#  'commercialScore': 1,
#  'grade': 'A',
#  'score': 4,
#  'negative': 44261,
#  'pending': None,
#  'hospitalizedCurrently': None,
#  'hospitalizedCumulative': 2122,
#  'inIcuCurrently': None,
#  'inIcuCumulative': None,
#  'onVentilatorCurrently': None,
#  'onVentilatorCumulative': None,
#  'recovered': 607,
#  'lastUpdateEt': '4/14 10:00',
#  'checkTimeEt': '4/14 10:48',
#  'death': 302,
#  'hospitalized': 2122,
#  'total': 53733,
#  'totalTestResults': 53733,
#  'posNeg': 53733,
#  'fips': '24',
#  'dateModified': '2020-04-14T14:00:00Z',
#  'dateChecked': '2020-04-14T14:48:00Z',
#  'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#  'hash': 'aa1708fc4ce3106c70be39410594bb20302b8e5d'}

# %%
for state1 in state_tests:
    if(state1 == {}): continue
    for state2 in state_json["features"]:
        if(state1["state"] == state2["properties"]["abbr"]):
            state2["properties"]["time_tests_updated"] = format_test_time(state1["lastUpdateEt"])
            state2["properties"]["test_grade"] = state1["grade"]
            testing_keys = ["test_positive", "test_negative", "test_total"]
            for key in testing_keys:
                state2["properties"][key] = state1[key.split('_')[1]]

# %% [markdown]
# ## Per Capita Calculations and Data

# %%
print_and_log("\nAdding per capita stats for county")
for county in counties:
    props = county["properties"]
    per_cap = props["population"]/100000
    props["pc_cases"] = props["cases"]/per_cap
    props["pc_deaths"] = props["deaths"]/per_cap
# Out:
# Adding per capita stats for county

# %%
print_and_log("Adding per capita stats for states")
for state in state_json["features"]:
    props = state["properties"]
    per_cap = props["population"]/100000
    props["pc_cases"] = props["cases"]/per_cap
    props["pc_active"] = props["active"]/per_cap
    props["pc_deaths"] = props["deaths"]/per_cap
    props["pc_tests"] = props["test_total"]/per_cap
# Out:
# Adding per capita stats for states

# %% [markdown]
# ## Time Series Data

# %% [markdown]
# ### Add County time series

# %%
with open(county_data_folder/'countyTimeData.json', 'r') as f:
    county_time_data = json.load(f)

# %% [markdown]
# #### Add today's data to time series

# %% [markdown]
# Note we wont display this in time series until tomorrow becauseit makes it look like curve is flattening

# %%
today = datetime.datetime.today()
todays_date = f"{today.month}-{today.day}-{today.year}"
print_and_log(f"Adding time series for today: {todays_date}")
# Out:
# Adding time series for today: 4-14-2020

# %%
for county in counties:
    props = county["properties"]
    geo_id = props["geo_id"]
    cases = props["cases"]
    deaths = props["deaths"]
    county_time_data[geo_id][todays_date] = {"cases":cases, "deaths":deaths}

# %% [markdown]
# #### Add time series to county geojson

# %%
for county in counties:
    geo_id = county["properties"]["geo_id"]
    county["properties"]["time_series"] = county_time_data[geo_id]

# %%
counties[0]
# Out:
# {'type': 'Feature',
#  'properties': {'geo_id': '0500000US01001',
#   'county': '001',
#   'name': 'Autauga',
#   'lsad': 'County',
#   'censusarea': 594.436,
#   'state': '01',
#   'statename': 'Alabama',
#   'stateabbr': 'AL',
#   'population': 55601,
#   'land_area': '594.44',
#   'housing_units': '22135',
#   'population_density': 93.53509185115402,
#   'comorbid_diabetes': 15.45,
#   'comorbid_smoking': 18.41,
#   'comorbid_cancer': 0.4956,
#   'comorbid_obesity': 37.945,
#   'comorbid_hypertension': 40.335,
#   'lat': -86.64274644826507,
#   'long': 32.53492681419619,
#   'age0-19': 14424,
#   'age20-44': 17583,
#   'age45-54': 7777,
#   'age55-64': 7164,
#   'age65-74': 4900,
#   'age75-84': 2882,
#   'age85+': 871,
#   'cases': 19,
#   'deaths': 1,
#   'active': 18,
#   'recovered': 0,
#   'time_cases_update': '4/14 11:43AM',
#   'pc_cases': 34.17204726533696,
#   'pc_deaths': 1.798528803438787,
#   'time_series': {'3-15-2020': {'cases': 0, 'deaths': None},
#    '3-17-2020': {'cases': 0, 'deaths': None},
#    '3-18-2020': {'cases': 0, 'deaths': 0},
#    '3-19-2020': {'cases': 0, 'deaths': 0},
#    '3-20-2020': {'cases': 0, 'deaths': 0},
#    '3-23-2020': {'cases': 0, 'deaths': 0},
#    '3-24-2020': {'cases': 1, 'deaths': 0},
#    '3-25-2020': {'cases': 4, 'deaths': 0},
#    '3-26-2020': {'cases': 6, 'deaths': 0},
#    '3-27-2020': {'cases': 6, 'deaths': 0},
#    '3-31-2020': {'cases': 7, 'deaths': 0},
#    '4-1-2020': {'cases': 8, 'deaths': 0},
#    '4-3-2020': {'cases': 12, 'deaths': 0},
#    '4-5-2020': {'cases': 12, 'deaths': 0},
#    '4-7-2020': {'cases': 12, 'deaths': 1},
#    '4-8-2020': {'cases': 12, 'deaths': 1},
#    '4-9-2020': {'cases': 15, 'deaths': 1},
#    '4-10-2020': {'cases': 17, 'deaths': 1},
#    '4-11-2020': {'cases': 19, 'deaths': 1},
#    '4-12-2020': {'cases': 19, 'deaths': 1},
#    '4-14-2020': {'cases': 19, 'deaths': 1}}},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-86.496774, 32.344437],
#     [-86.717897, 32.402814],
#     [-86.814912, 32.340803],
#     [-86.890581, 32.502974],
#     [-86.917595, 32.664169],
#     [-86.71339, 32.661732],
#     [-86.714219, 32.705694],
#     [-86.413116, 32.707386],
#     [-86.411172, 32.409937],
#     [-86.496774, 32.344437]]]}}

# %% [markdown]
# #### Save latest county time series data to file

# %%
with open(county_data_folder/"countyTimeData.json", 'w') as f:
    json.dump(county_time_data, f)

# %% [markdown]
# ### Add State time series

# %%
with open(state_data_folder/'stateTimeData.json', 'r') as f:
    state_time_data = json.load(f)

# %%
state_time_data
# Out:
# {'Alabama': {'3-13-2020': {'cases': 5,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 12,
#    'test_positive': 1,
#    'test_negative': 11},
#   '3-14-2020': {'cases': 6,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 74,
#    'test_positive': 6,
#    'test_negative': 22},
#   '3-15-2020': {'cases': 12,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 86,
#    'test_positive': 12,
#    'test_negative': 28},
#   '3-16-2020': {'cases': 29,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 96,
#    'test_positive': 28,
#    'test_negative': 28},
#   '3-17-2020': {'cases': 39,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 64,
#    'test_positive': 36,
#    'test_negative': 28},
#   '3-18-2020': {'cases': 46,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 74,
#    'test_positive': 46,
#    'test_negative': 28},
#   '3-19-2020': {'cases': 78,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 96,
#    'test_positive': 68,
#    'test_negative': 28},
#   '3-20-2020': {'cases': 83,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 109,
#    'test_positive': 81,
#    'test_negative': 28},
#   '3-21-2020': {'cases': 131,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 152,
#    'test_positive': 124,
#    'test_negative': 28},
#   '3-22-2020': {'cases': 157,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1602,
#    'test_positive': 138,
#    'test_negative': 1464},
#   '3-23-2020': {'cases': 196,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1832,
#    'test_positive': 167,
#    'test_negative': 1665},
#   '3-24-2020': {'cases': 242,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2321,
#    'test_positive': 215,
#    'test_negative': 2106},
#   '3-25-2020': {'cases': 381,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 2812,
#    'test_positive': 283,
#    'test_negative': 2529},
#   '3-26-2020': {'cases': 517,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 4099,
#    'test_positive': 506,
#    'test_negative': 3593},
#   '3-27-2020': {'cases': 587,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 4771,
#    'test_positive': 587,
#    'test_negative': 4184},
#   '3-28-2020': {'cases': 694,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 4880,
#    'test_positive': 696,
#    'test_negative': 4184},
#   '3-29-2020': {'cases': 825,
#    'deaths': 10,
#    'recovered': 0,
#    'test_total': 4990,
#    'test_positive': 806,
#    'test_negative': 4184},
#   '3-30-2020': {'cases': 899,
#    'deaths': 10,
#    'recovered': 0,
#    'test_total': 6553,
#    'test_positive': 859,
#    'test_negative': 5694},
#   '3-31-2020': {'cases': 987,
#    'deaths': 23,
#    'recovered': 0,
#    'test_total': 7279,
#    'test_positive': 981,
#    'test_negative': 6298},
#   '4-1-2020': {'cases': 1060,
#    'deaths': 27,
#    'recovered': 0,
#    'test_total': 7774,
#    'test_positive': 1077,
#    'test_negative': 6697},
#   '4-2-2020': {'cases': 1233,
#    'deaths': 32,
#    'recovered': 0,
#    'test_total': 8736,
#    'test_positive': 1233,
#    'test_negative': 7503},
#   '4-3-2020': {'cases': 1495,
#    'deaths': 38,
#    'recovered': 0,
#    'test_total': 9619,
#    'test_positive': 1432,
#    'test_negative': 8187},
#   '4-4-2020': {'cases': 1614,
#    'deaths': 44,
#    'recovered': 0,
#    'test_total': 10853,
#    'test_positive': 1580,
#    'test_negative': 9273},
#   '4-5-2020': {'cases': 1765,
#    'deaths': 45,
#    'recovered': 0,
#    'test_total': 13078,
#    'test_positive': 1796,
#    'test_negative': 11282},
#   '4-6-2020': {'cases': 1952,
#    'deaths': 49,
#    'recovered': 0,
#    'test_total': 14765,
#    'test_positive': 1968,
#    'test_negative': 12797},
#   '4-7-2020': {'cases': 2169,
#    'deaths': 64,
#    'recovered': 0,
#    'test_total': 14916,
#    'test_positive': 2119,
#    'test_negative': 12797},
#   '4-8-2020': {'cases': 2328,
#    'deaths': 66,
#    'recovered': 0,
#    'test_total': 19122,
#    'test_positive': 2369,
#    'test_negative': 16753},
#   '4-9-2020': {'cases': 2703,
#    'deaths': 70,
#    'recovered': 0,
#    'test_total': 20827,
#    'test_positive': 2769,
#    'test_negative': 18058},
#   '4-10-2020': {'cases': 2947,
#    'deaths': 80,
#    'recovered': 0,
#    'test_total': 21026,
#    'test_positive': 2968,
#    'test_negative': 18058},
#   '4-11-2020': {'cases': 3217,
#    'deaths': 92,
#    'recovered': 0,
#    'test_total': 21249,
#    'test_positive': 3191,
#    'test_negative': 18058},
#   '4-12-2020': {'cases': 3563,
#    'deaths': 93,
#    'recovered': 0,
#    'test_total': 21583,
#    'test_positive': 3525,
#    'test_negative': 18058},
#   '4-13-2020': {'cases': 3734,
#    'deaths': 99,
#    'recovered': 0,
#    'test_total': 29182,
#    'test_positive': 3734,
#    'test_negative': 25448},
#   '3-12-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#   '3-11-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#   '3-10-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#   '3-9-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#   '3-8-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#   '3-7-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0}},
#  'Alaska': {'3-10-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 32,
#    'test_positive': 0,
#    'test_negative': 23},
#   '3-11-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 60,
#    'test_positive': 0,
#    'test_negative': 46},
#   '3-12-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 60,
#    'test_positive': 0,
#    'test_negative': 46},
#   '3-13-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 60,
#    'test_positive': 1,
#    'test_negative': 59},
#   '3-15-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 144,
#    'test_positive': 1,
#    'test_negative': 143},
#   '3-16-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 144,
#    'test_positive': 1,
#    'test_negative': 143},
#   '3-17-2020': {'cases': 3,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 337,
#    'test_positive': 3,
#    'test_negative': 334},
#   '3-18-2020': {'cases': 6,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 412,
#    'test_positive': 6,
#    'test_negative': 406},
#   '3-19-2020': {'cases': 9,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 438,
#    'test_positive': 6,
#    'test_negative': 432},
#   '3-20-2020': {'cases': 12,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 698,
#    'test_positive': 12,
#    'test_negative': 686},
#   '3-21-2020': {'cases': 15,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 772,
#    'test_positive': 14,
#    'test_negative': 758},
#   '3-22-2020': {'cases': 20,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 968,
#    'test_positive': 22,
#    'test_negative': 946},
#   '3-23-2020': {'cases': 30,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 968,
#    'test_positive': 22,
#    'test_negative': 946},
#   '3-24-2020': {'cases': 34,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1022,
#    'test_positive': 36,
#    'test_negative': 986},
#   '3-25-2020': {'cases': 41,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 1691,
#    'test_positive': 42,
#    'test_negative': 1649},
#   '3-26-2020': {'cases': 56,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 1860,
#    'test_positive': 59,
#    'test_negative': 1801},
#   '3-27-2020': {'cases': 58,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 2401,
#    'test_positive': 69,
#    'test_negative': 2319},
#   '3-28-2020': {'cases': 85,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 2921,
#    'test_positive': 85,
#    'test_negative': 2836},
#   '3-29-2020': {'cases': 102,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 3334,
#    'test_positive': 102,
#    'test_negative': 3232},
#   '3-30-2020': {'cases': 114,
#    'deaths': 3,
#    'recovered': 0,
#    'test_total': 3654,
#    'test_positive': 114,
#    'test_negative': 3540},
#   '3-31-2020': {'cases': 119,
#    'deaths': 3,
#    'recovered': 0,
#    'test_total': 3713,
#    'test_positive': 119,
#    'test_negative': 3594},
#   '4-1-2020': {'cases': 132,
#    'deaths': 3,
#    'recovered': 0,
#    'test_total': 4603,
#    'test_positive': 133,
#    'test_negative': 4470},
#   '4-2-2020': {'cases': 143,
#    'deaths': 3,
#    'recovered': 0,
#    'test_total': 5022,
#    'test_positive': 143,
#    'test_negative': 4879},
#   '4-3-2020': {'cases': 157,
#    'deaths': 3,
#    'recovered': 0,
#    'test_total': 6016,
#    'test_positive': 157,
#    'test_negative': 5859},
#   '4-4-2020': {'cases': 171,
#    'deaths': 5,
#    'recovered': 0,
#    'test_total': 6040,
#    'test_positive': 171,
#    'test_negative': 5869},
#   '4-5-2020': {'cases': 185,
#    'deaths': 6,
#    'recovered': 0,
#    'test_total': 6284,
#    'test_positive': 185,
#    'test_negative': 6099},
#   '4-6-2020': {'cases': 190,
#    'deaths': 6,
#    'recovered': 0,
#    'test_total': 6883,
#    'test_positive': 191,
#    'test_negative': 6692},
#   '4-7-2020': {'cases': 213,
#    'deaths': 6,
#    'recovered': 0,
#    'test_total': 6913,
#    'test_positive': 213,
#    'test_negative': 6700},
#   '4-8-2020': {'cases': 226,
#    'deaths': 7,
#    'recovered': 0,
#    'test_total': 7068,
#    'test_positive': 226,
#    'test_negative': 6842},
#   '4-9-2020': {'cases': 235,
#    'deaths': 7,
#    'recovered': 0,
#    'test_total': 7223,
#    'test_positive': 235,
#    'test_negative': 6988},
#   '4-10-2020': {'cases': 246,
#    'deaths': 7,
#    'recovered': 0,
#    'test_total': 7432,
#    'test_positive': 246,
#    'test_negative': 7186},
#   '4-11-2020': {'cases': 257,
#    'deaths': 8,
#    'recovered': 0,
#    'test_total': 7732,
#    'test_positive': 257,
#    'test_negative': 7475},
#   '4-12-2020': {'cases': 272,
#    'deaths': 8,
#    'recovered': 0,
#    'test_total': 8038,
#    'test_positive': 272,
#    'test_negative': 7766},
#   '4-13-2020': {'cases': 277,
#    'deaths': 8,
#    'recovered': 0,
#    'test_total': 7830,
#    'test_positive': 277,
#    'test_negative': 7553},
#   '3-14-2020': {'test_total': 144, 'test_positive': 1, 'test_negative': 143},
#   '3-9-2020': {'test_total': 32, 'test_positive': 0, 'test_negative': 23},
#   '3-8-2020': {'test_total': 20, 'test_positive': 0, 'test_negative': 14},
#   '3-7-2020': {'test_total': 14, 'test_positive': 0, 'test_negative': 12},
#   '3-6-2020': {'test_total': 9, 'test_positive': 0, 'test_negative': 8}},
#  'Arizona': {'1-26-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-27-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-28-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-29-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-30-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '1-31-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-1-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-2-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-3-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-4-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-5-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-6-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-7-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-8-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-9-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-10-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-11-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-12-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-13-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-14-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-15-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-16-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-17-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-18-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-19-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-20-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-21-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-22-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-23-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-24-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-25-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-26-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-27-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-28-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '2-29-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '3-1-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '3-2-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '3-3-2020': {'cases': 2, 'deaths': 0, 'recovered': 1},
#   '3-4-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 34,
#    'test_positive': 2,
#    'test_negative': 27},
#   '3-5-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 36,
#    'test_positive': 2,
#    'test_negative': 28},
#   '3-6-2020': {'cases': 3,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 51,
#    'test_positive': 3,
#    'test_negative': 33},
#   '3-7-2020': {'cases': 5,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 56,
#    'test_positive': 5,
#    'test_negative': 44},
#   '3-8-2020': {'cases': 5,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 56,
#    'test_positive': 5,
#    'test_negative': 44},
#   '3-9-2020': {'cases': 5,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 56,
#    'test_positive': 5,
#    'test_negative': 44},
#   '3-10-2020': {'cases': 6,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 84,
#    'test_positive': 6,
#    'test_negative': 51},
#   '3-11-2020': {'cases': 9,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 100,
#    'test_positive': 9,
#    'test_negative': 59},
#   '3-12-2020': {'cases': 9,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 115,
#    'test_positive': 9,
#    'test_negative': 82},
#   '3-13-2020': {'cases': 9,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 143,
#    'test_positive': 9,
#    'test_negative': 94},
#   '3-14-2020': {'cases': 12,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 183,
#    'test_positive': 12,
#    'test_negative': 121},
#   '3-15-2020': {'cases': 13,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 183,
#    'test_positive': 12,
#    'test_negative': 121},
#   '3-16-2020': {'cases': 18,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 206,
#    'test_positive': 18,
#    'test_negative': 125},
#   '3-17-2020': {'cases': 20,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 228,
#    'test_positive': 20,
#    'test_negative': 142},
#   '3-18-2020': {'cases': 27,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 278,
#    'test_positive': 28,
#    'test_negative': 148},
#   '3-19-2020': {'cases': 45,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 349,
#    'test_positive': 44,
#    'test_negative': 175},
#   '3-20-2020': {'cases': 78,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 377,
#    'test_positive': 65,
#    'test_negative': 211},
#   '3-21-2020': {'cases': 118,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 466,
#    'test_positive': 104,
#    'test_negative': 240},
#   '3-22-2020': {'cases': 152,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 521,
#    'test_positive': 152,
#    'test_negative': 282},
#   '3-23-2020': {'cases': 235,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 580,
#    'test_positive': 265,
#    'test_negative': 309},
#   '3-24-2020': {'cases': 326,
#    'deaths': 5,
#    'recovered': 0,
#    'test_total': 692,
#    'test_positive': 357,
#    'test_negative': 313},
#   '3-25-2020': {'cases': 401,
#    'deaths': 6,
#    'recovered': 0,
#    'test_total': 826,
#    'test_positive': 450,
#    'test_negative': 323},
#   '3-26-2020': {'cases': 508,
#    'deaths': 8,
#    'recovered': 0,
#    'test_total': 957,
#    'test_positive': 577,
#    'test_negative': 347},
#   '3-27-2020': {'cases': 665,
#    'deaths': 13,
#    'recovered': 0,
#    'test_total': 8221,
#    'test_positive': 736,
#    'test_negative': 7455},
#   '3-28-2020': {'cases': 773,
#    'deaths': 15,
#    'recovered': 0,
#    'test_total': 8349,
#    'test_positive': 873,
#    'test_negative': 7455},
#   '3-29-2020': {'cases': 919,
#    'deaths': 17,
#    'recovered': 0,
#    'test_total': 13872,
#    'test_positive': 919,
#    'test_negative': 12953},
#   '3-30-2020': {'cases': 1157,
#    'deaths': 20,
#    'recovered': 0,
#    'test_total': 16759,
#    'test_positive': 1157,
#    'test_negative': 15602},
#   '3-31-2020': {'cases': 1289,
#    'deaths': 24,
#    'recovered': 0,
#    'test_total': 19371,
#    'test_positive': 1289,
#    'test_negative': 18082},
#   '4-1-2020': {'cases': 1530,
#    'deaths': 29,
#    'recovered': 0,
#    'test_total': 21058,
#    'test_positive': 1413,
#    'test_negative': 19645},
#   '4-2-2020': {'cases': 1715,
#    'deaths': 32,
#    'recovered': 0,
#    'test_total': 22709,
#    'test_positive': 1598,
#    'test_negative': 21111},
#   '4-3-2020': {'cases': 1937,
#    'deaths': 41,
#    'recovered': 0,
#    'test_total': 24673,
#    'test_positive': 1769,
#    'test_negative': 22904},
#   '4-4-2020': {'cases': 2187,
#    'deaths': 52,
#    'recovered': 0,
#    'test_total': 27160,
#    'test_positive': 2019,
#    'test_negative': 25141},
#   '4-5-2020': {'cases': 2486,
#    'deaths': 64,
#    'recovered': 0,
#    'test_total': 27410,
#    'test_positive': 2269,
#    'test_negative': 25141},
#   '4-6-2020': {'cases': 2732,
#    'deaths': 65,
#    'recovered': 0,
#    'test_total': 32534,
#    'test_positive': 2456,
#    'test_negative': 30078},
#   '4-7-2020': {'cases': 2870,
#    'deaths': 73,
#    'recovered': 0,
#    'test_total': 33375,
#    'test_positive': 2575,
#    'test_negative': 30800},
#   '4-8-2020': {'cases': 3036,
#    'deaths': 80,
#    'recovered': 0,
#    'test_total': 34564,
#    'test_positive': 2726,
#    'test_negative': 31838},
#   '4-9-2020': {'cases': 3018,
#    'deaths': 89,
#    'recovered': 0,
#    'test_total': 37178,
#    'test_positive': 3018,
#    'test_negative': 34160},
#   '4-10-2020': {'cases': 3112,
#    'deaths': 97,
#    'recovered': 0,
#    'test_total': 37734,
#    'test_positive': 3112,
#    'test_negative': 34622},
#   '4-11-2020': {'cases': 3393,
#    'deaths': 108,
#    'recovered': 0,
#    'test_total': 40530,
#    'test_positive': 3393,
#    'test_negative': 37137},
#   '4-12-2020': {'cases': 3542,
#    'deaths': 115,
#    'recovered': 0,
#    'test_total': 42109,
#    'test_positive': 3539,
#    'test_negative': 38570},
#   '4-13-2020': {'cases': 3705,
#    'deaths': 122,
#    'recovered': 0,
#    'test_total': 43347,
#    'test_positive': 3702,
#    'test_negative': 39645}},
#  'Arkansas': {'3-10-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 15,
#    'test_positive': 0,
#    'test_negative': 12},
#   '3-11-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 26,
#    'test_positive': 0,
#    'test_negative': 12},
#   '3-12-2020': {'cases': 6,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 50,
#    'test_positive': 6,
#    'test_negative': 24},
#   '3-13-2020': {'cases': 6,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 61,
#    'test_positive': 9,
#    'test_negative': 30},
#   '3-14-2020': {'cases': 12,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 103,
#    'test_positive': 12,
#    'test_negative': 65},
#   '3-15-2020': {'cases': 16,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 149,
#    'test_positive': 16,
#    'test_negative': 103},
#   '3-16-2020': {'cases': 22,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 168,
#    'test_positive': 22,
#    'test_negative': 132},
#   '3-17-2020': {'cases': 22,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 260,
#    'test_positive': 22,
#    'test_negative': 197},
#   '3-18-2020': {'cases': 33,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 319,
#    'test_positive': 33,
#    'test_negative': 236},
#   '3-19-2020': {'cases': 62,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 469,
#    'test_positive': 46,
#    'test_negative': 310},
#   '3-20-2020': {'cases': 96,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 650,
#    'test_positive': 96,
#    'test_negative': 351},
#   '3-21-2020': {'cases': 122,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 839,
#    'test_positive': 118,
#    'test_negative': 567},
#   '3-22-2020': {'cases': 165,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 995,
#    'test_positive': 165,
#    'test_negative': 711},
#   '3-23-2020': {'cases': 192,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1080,
#    'test_positive': 174,
#    'test_negative': 906},
#   '3-24-2020': {'cases': 219,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 1165,
#    'test_positive': 218,
#    'test_negative': 947},
#   '3-25-2020': {'cases': 280,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 1717,
#    'test_positive': 280,
#    'test_negative': 1437},
#   '3-26-2020': {'cases': 335,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 1839,
#    'test_positive': 335,
#    'test_negative': 1504},
#   '3-27-2020': {'cases': 381,
#    'deaths': 3,
#    'recovered': 0,
#    'test_total': 1926,
#    'test_positive': 381,
#    'test_negative': 1545},
#   '3-28-2020': {'cases': 409,
#    'deaths': 5,
#    'recovered': 0,
#    'test_total': 3342,
#    'test_positive': 404,
#    'test_negative': 2938},
#   '3-29-2020': {'cases': 426,
#    'deaths': 6,
#    'recovered': 0,
#    'test_total': 3453,
#    'test_positive': 426,
#    'test_negative': 3027},
#   '3-30-2020': {'cases': 473,
#    'deaths': 7,
#    'recovered': 0,
#    'test_total': 5735,
#    'test_positive': 473,
#    'test_negative': 5262},
#   '3-31-2020': {'cases': 523,
#    'deaths': 8,
#    'recovered': 0,
#    'test_total': 6482,
#    'test_positive': 523,
#    'test_negative': 5959},
#   '4-1-2020': {'cases': 584,
#    'deaths': 10,
#    'recovered': 0,
#    'test_total': 7938,
#    'test_positive': 584,
#    'test_negative': 7354},
#   '4-2-2020': {'cases': 643,
#    'deaths': 12,
#    'recovered': 0,
#    'test_total': 8523,
#    'test_positive': 643,
#    'test_negative': 7880},
#   '4-3-2020': {'cases': 704,
#    'deaths': 12,
#    'recovered': 0,
#    'test_total': 9699,
#    'test_positive': 704,
#    'test_negative': 8995},
#   '4-4-2020': {'cases': 743,
#    'deaths': 14,
#    'recovered': 0,
#    'test_total': 10370,
#    'test_positive': 743,
#    'test_negative': 9627},
#   '4-5-2020': {'cases': 837,
#    'deaths': 16,
#    'recovered': 0,
#    'test_total': 11242,
#    'test_positive': 830,
#    'test_negative': 10412},
#   '4-6-2020': {'cases': 875,
#    'deaths': 16,
#    'recovered': 0,
#    'test_total': 12845,
#    'test_positive': 875,
#    'test_negative': 11970},
#   '4-7-2020': {'cases': 946,
#    'deaths': 18,
#    'recovered': 0,
#    'test_total': 13638,
#    'test_positive': 946,
#    'test_negative': 12692},
#   '4-8-2020': {'cases': 1000,
#    'deaths': 18,
#    'recovered': 0,
#    'test_total': 14530,
#    'test_positive': 1000,
#    'test_negative': 13530},
#   '4-9-2020': {'cases': 1119,
#    'deaths': 21,
#    'recovered': 0,
#    'test_total': 14951,
#    'test_positive': 1119,
#    'test_negative': 13832},
#   '4-10-2020': {'cases': 1171,
#    'deaths': 21,
#    'recovered': 0,
#    'test_total': 17120,
#    'test_positive': 1171,
#    'test_negative': 15949},
#   '4-11-2020': {'cases': 1228,
#    'deaths': 25,
#    'recovered': 0,
#    'test_total': 18578,
#    'test_positive': 1226,
#    'test_negative': 17352},
#   '4-12-2020': {'cases': 1280,
#    'deaths': 27,
#    'recovered': 0,
#    'test_total': 19722,
#    'test_positive': 1280,
#    'test_negative': 18442},
#   '4-13-2020': {'cases': 1410,
#    'deaths': 29,
#    'recovered': 0,
#    'test_total': 20804,
#    'test_positive': 1410,
#    'test_negative': 19394},
#   '3-9-2020': {'test_total': 12, 'test_positive': 0, 'test_negative': 12},
#   '3-8-2020': {'test_total': 6, 'test_positive': 0, 'test_negative': 6},
#   '3-7-2020': {'test_total': 6, 'test_positive': 0, 'test_negative': 6},
#   '3-6-2020': {'test_total': 6, 'test_positive': 0, 'test_negative': 6}},
#  'California': {'1-26-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '1-27-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '1-28-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '1-29-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '1-30-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '1-31-2020': {'cases': 2, 'deaths': 0, 'recovered': 0},
#   '2-1-2020': {'cases': 3, 'deaths': 0, 'recovered': 0},
#   '2-2-2020': {'cases': 3, 'deaths': 0, 'recovered': 0},
#   '2-3-2020': {'cases': 6, 'deaths': 0, 'recovered': 0},
#   '2-4-2020': {'cases': 6, 'deaths': 0, 'recovered': 0},
#   '2-5-2020': {'cases': 6, 'deaths': 0, 'recovered': 0},
#   '2-6-2020': {'cases': 6, 'deaths': 0, 'recovered': 0},
#   '2-7-2020': {'cases': 6, 'deaths': 0, 'recovered': 0},
#   '2-8-2020': {'cases': 6, 'deaths': 0, 'recovered': 0},
#   '2-9-2020': {'cases': 6, 'deaths': 0, 'recovered': 0},
#   '2-10-2020': {'cases': 6, 'deaths': 0, 'recovered': 0},
#   '2-11-2020': {'cases': 7, 'deaths': 0, 'recovered': 0},
#   '2-12-2020': {'cases': 7, 'deaths': 0, 'recovered': 0},
#   '2-13-2020': {'cases': 8, 'deaths': 0, 'recovered': 0},
#   '2-14-2020': {'cases': 8, 'deaths': 0, 'recovered': 0},
#   '2-15-2020': {'cases': 8, 'deaths': 0, 'recovered': 0},
#   '2-16-2020': {'cases': 8, 'deaths': 0, 'recovered': 0},
#   '2-17-2020': {'cases': 8, 'deaths': 0, 'recovered': 0},
#   '2-18-2020': {'cases': 8, 'deaths': 0, 'recovered': 0},
#   '2-19-2020': {'cases': 8, 'deaths': 0, 'recovered': 0},
#   '2-20-2020': {'cases': 8, 'deaths': 0, 'recovered': 0},
#   '2-21-2020': {'cases': 15, 'deaths': 0, 'recovered': 2},
#   '2-22-2020': {'cases': 15, 'deaths': 0, 'recovered': 2},
#   '2-23-2020': {'cases': 15, 'deaths': 0, 'recovered': 2},
#   '2-24-2020': {'cases': 10, 'deaths': 0, 'recovered': 2},
#   '2-25-2020': {'cases': 10, 'deaths': 0, 'recovered': 2},
#   '2-26-2020': {'cases': 10, 'deaths': 0, 'recovered': 2},
#   '2-27-2020': {'cases': 11, 'deaths': 0, 'recovered': 2},
#   '2-28-2020': {'cases': 11, 'deaths': 0, 'recovered': 2},
#   '2-29-2020': {'cases': 12, 'deaths': 0, 'recovered': 2},
#   '3-1-2020': {'cases': 12, 'deaths': 0, 'recovered': 2},
#   '3-2-2020': {'cases': 21, 'deaths': 0, 'recovered': 2},
#   '3-3-2020': {'cases': 25, 'deaths': 0, 'recovered': 2},
#   '3-4-2020': {'cases': 35,
#    'deaths': 1,
#    'recovered': 2,
#    'test_total': 515,
#    'test_positive': 53,
#    'test_negative': 462},
#   '3-5-2020': {'cases': 51,
#    'deaths': 1,
#    'recovered': 2,
#    'test_total': 515,
#    'test_positive': 53,
#    'test_negative': 462},
#   '3-6-2020': {'cases': 59,
#    'deaths': 1,
#    'recovered': 2,
#    'test_total': 522,
#    'test_positive': 60,
#    'test_negative': 462},
#   '3-7-2020': {'cases': 82,
#    'deaths': 1,
#    'recovered': 2,
#    'test_total': 531,
#    'test_positive': 69,
#    'test_negative': 462},
#   '3-8-2020': {'cases': 98,
#    'deaths': 1,
#    'recovered': 2,
#    'test_total': 550,
#    'test_positive': 88,
#    'test_negative': 462},
#   '3-9-2020': {'cases': 104,
#    'deaths': 1,
#    'recovered': 2,
#    'test_total': 804,
#    'test_positive': 114,
#    'test_negative': 690},
#   '3-10-2020': {'cases': 144,
#    'deaths': 2,
#    'recovered': 2,
#    'test_total': 823,
#    'test_positive': 133,
#    'test_negative': 690},
#   '3-11-2020': {'cases': 177,
#    'deaths': 3,
#    'recovered': 2,
#    'test_total': 1073,
#    'test_positive': 157,
#    'test_negative': 916},
#   '3-12-2020': {'cases': 221,
#    'deaths': 4,
#    'recovered': 6,
#    'test_total': 1118,
#    'test_positive': 202,
#    'test_negative': 916},
#   '3-13-2020': {'cases': 282,
#    'deaths': 4,
#    'recovered': 6,
#    'test_total': 1118,
#    'test_positive': 202,
#    'test_negative': 916},
#   '3-14-2020': {'cases': 340,
#    'deaths': 5,
#    'recovered': 6,
#    'test_total': 1168,
#    'test_positive': 252,
#    'test_negative': 916},
#   '3-15-2020': {'cases': 426,
#    'deaths': 6,
#    'recovered': 6,
#    'test_total': 1209,
#    'test_positive': 293,
#    'test_negative': 916},
#   '3-16-2020': {'cases': 557,
#    'deaths': 7,
#    'recovered': 6,
#    'test_total': 8316,
#    'test_positive': 335,
#    'test_negative': 7981},
#   '3-17-2020': {'cases': 698,
#    'deaths': 12,
#    'recovered': 6,
#    'test_total': 8464,
#    'test_positive': 483,
#    'test_negative': 7981},
#   '3-18-2020': {'cases': 751,
#    'deaths': 13,
#    'recovered': 0,
#    'test_total': 8592,
#    'test_positive': 611,
#    'test_negative': 7981},
#   '3-19-2020': {'cases': 952,
#    'deaths': 18,
#    'recovered': 0,
#    'test_total': 9711,
#    'test_positive': 924,
#    'test_negative': 8787},
#   '3-20-2020': {'cases': 1177,
#    'deaths': 23,
#    'recovered': 0,
#    'test_total': 11487,
#    'test_positive': 1063,
#    'test_negative': 10424},
#   '3-21-2020': {'cases': 1364,
#    'deaths': 24,
#    'recovered': 0,
#    'test_total': 12528,
#    'test_positive': 1279,
#    'test_negative': 11249},
#   '3-22-2020': {'cases': 1646,
#    'deaths': 30,
#    'recovered': 0,
#    'test_total': 12840,
#    'test_positive': 1536,
#    'test_negative': 11304},
#   '3-23-2020': {'cases': 2108,
#    'deaths': 39,
#    'recovered': 0,
#    'test_total': 26400,
#    'test_positive': 1733,
#    'test_negative': 12567},
#   '3-24-2020': {'cases': 2538,
#    'deaths': 50,
#    'recovered': 0,
#    'test_total': 27654,
#    'test_positive': 2102,
#    'test_negative': 13452},
#   '3-25-2020': {'cases': 2998,
#    'deaths': 65,
#    'recovered': 0,
#    'test_total': 66876,
#    'test_positive': 2355,
#    'test_negative': 15921},
#   '3-26-2020': {'cases': 3899,
#    'deaths': 81,
#    'recovered': 0,
#    'test_total': 77786,
#    'test_positive': 3006,
#    'test_negative': 17380},
#   '3-27-2020': {'cases': 4657,
#    'deaths': 94,
#    'recovered': 0,
#    'test_total': 78659,
#    'test_positive': 3879,
#    'test_negative': 17380},
#   '3-28-2020': {'cases': 5095,
#    'deaths': 110,
#    'recovered': 0,
#    'test_total': 89592,
#    'test_positive': 4643,
#    'test_negative': 20549},
#   '3-29-2020': {'cases': 5852,
#    'deaths': 124,
#    'recovered': 0,
#    'test_total': 90657,
#    'test_positive': 5708,
#    'test_negative': 20549},
#   '3-30-2020': {'cases': 7138,
#    'deaths': 146,
#    'recovered': 0,
#    'test_total': 91396,
#    'test_positive': 6447,
#    'test_negative': 20549},
#   '3-31-2020': {'cases': 8210,
#    'deaths': 173,
#    'recovered': 0,
#    'test_total': 86654,
#    'test_positive': 7482,
#    'test_negative': 21772},
#   '4-1-2020': {'cases': 9399,
#    'deaths': 199,
#    'recovered': 0,
#    'test_total': 87327,
#    'test_positive': 8155,
#    'test_negative': 21772},
#   '4-2-2020': {'cases': 10773,
#    'deaths': 238,
#    'recovered': 0,
#    'test_total': 92500,
#    'test_positive': 9191,
#    'test_negative': 23809},
#   '4-3-2020': {'cases': 12004,
#    'deaths': 265,
#    'recovered': 0,
#    'test_total': 94800,
#    'test_positive': 10701,
#    'test_negative': 24599},
#   '4-4-2020': {'cases': 12837,
#    'deaths': 289,
#    'recovered': 0,
#    'test_total': 126700,
#    'test_positive': 12026,
#    'test_negative': 101674},
#   '4-5-2020': {'cases': 15034,
#    'deaths': 348,
#    'recovered': 0,
#    'test_total': 131533,
#    'test_positive': 13438,
#    'test_negative': 103095},
#   '4-6-2020': {'cases': 16019,
#    'deaths': 380,
#    'recovered': 0,
#    'test_total': 132431,
#    'test_positive': 14336,
#    'test_negative': 103095},
#   '4-7-2020': {'cases': 17351,
#    'deaths': 432,
#    'recovered': 0,
#    'test_total': 145329,
#    'test_positive': 15865,
#    'test_negative': 115364},
#   '4-8-2020': {'cases': 18897,
#    'deaths': 495,
#    'recovered': 0,
#    'test_total': 158864,
#    'test_positive': 16957,
#    'test_negative': 127307},
#   '4-9-2020': {'cases': 19710,
#    'deaths': 544,
#    'recovered': 0,
#    'test_total': 177600,
#    'test_positive': 18309,
#    'test_negative': 145191},
#   '4-10-2020': {'cases': 21081,
#    'deaths': 583,
#    'recovered': 0,
#    'test_total': 178763,
#    'test_positive': 19472,
#    'test_negative': 145391},
#   '4-11-2020': {'cases': 21706,
#    'deaths': 605,
#    'recovered': 0,
#    'test_total': 185276,
#    'test_positive': 19472,
#    'test_negative': 152604},
#   '4-12-2020': {'cases': 22795,
#    'deaths': 641,
#    'recovered': 0,
#    'test_total': 203528,
#    'test_positive': 21794,
#    'test_negative': 168534},
#   '4-13-2020': {'cases': 23931,
#    'deaths': 715,
#    'recovered': 0,
#    'test_total': 204082,
#    'test_positive': 22348,
#    'test_negative': 168534}},
#  'Colorado': {'3-6-2020': {'cases': 4,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 78,
#    'test_positive': 2,
#    'test_negative': 46},
#   '3-7-2020': {'cases': 8,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 132,
#    'test_positive': 8,
#    'test_negative': 55},
#   '3-8-2020': {'cases': 8,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 112,
#    'test_positive': 8,
#    'test_negative': 104},
#   '3-9-2020': {'cases': 8,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 142,
#    'test_positive': 9,
#    'test_negative': 133},
#   '3-10-2020': {'cases': 15,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 155,
#    'test_positive': 12,
#    'test_negative': 142},
#   '3-11-2020': {'cases': 34,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 279,
#    'test_positive': 28,
#    'test_negative': 251},
#   '3-12-2020': {'cases': 45,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 343,
#    'test_positive': 45,
#    'test_negative': 298},
#   '3-13-2020': {'cases': 49,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 596,
#    'test_positive': 72,
#    'test_negative': 524},
#   '3-14-2020': {'cases': 101,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 711,
#    'test_positive': 101,
#    'test_negative': 610},
#   '3-15-2020': {'cases': 131,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 758,
#    'test_positive': 131,
#    'test_negative': 627},
#   '3-16-2020': {'cases': 160,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 758,
#    'test_positive': 131,
#    'test_negative': 627},
#   '3-17-2020': {'cases': 160,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 1216,
#    'test_positive': 160,
#    'test_negative': 1056},
#   '3-18-2020': {'cases': 184,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 1800,
#    'test_positive': 183,
#    'test_negative': 1617},
#   '3-19-2020': {'cases': 277,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 2328,
#    'test_positive': 216,
#    'test_negative': 2112},
#   '3-20-2020': {'cases': 363,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 2952,
#    'test_positive': 277,
#    'test_negative': 2675},
#   '3-21-2020': {'cases': 390,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 3680,
#    'test_positive': 363,
#    'test_negative': 3317},
#   '3-22-2020': {'cases': 591,
#    'deaths': 6,
#    'recovered': 0,
#    'test_total': 4550,
#    'test_positive': 475,
#    'test_negative': 4075},
#   '3-23-2020': {'cases': 704,
#    'deaths': 7,
#    'recovered': 0,
#    'test_total': 5436,
#    'test_positive': 591,
#    'test_negative': 4845},
#   '3-24-2020': {'cases': 723,
#    'deaths': 8,
#    'recovered': 0,
#    'test_total': 6224,
#    'test_positive': 720,
#    'test_negative': 5504},
#   '3-25-2020': {'cases': 1021,
#    'deaths': 16,
#    'recovered': 0,
#    'test_total': 7701,
#    'test_positive': 912,
#    'test_negative': 6789},
#   '3-26-2020': {'cases': 1430,
#    'deaths': 19,
#    'recovered': 0,
#    'test_total': 8064,
#    'test_positive': 1086,
#    'test_negative': 6978},
#   '3-27-2020': {'cases': 1433,
#    'deaths': 27,
#    'recovered': 0,
#    'test_total': 10122,
#    'test_positive': 1430,
#    'test_negative': 8692},
#   '3-28-2020': {'cases': 1740,
#    'deaths': 31,
#    'recovered': 0,
#    'test_total': 11676,
#    'test_positive': 1734,
#    'test_negative': 9942},
#   '3-29-2020': {'cases': 2307,
#    'deaths': 47,
#    'recovered': 0,
#    'test_total': 13276,
#    'test_positive': 2061,
#    'test_negative': 11215},
#   '3-30-2020': {'cases': 2311,
#    'deaths': 47,
#    'recovered': 0,
#    'test_total': 15364,
#    'test_positive': 2627,
#    'test_negative': 12737},
#   '3-31-2020': {'cases': 2966,
#    'deaths': 69,
#    'recovered': 0,
#    'test_total': 15364,
#    'test_positive': 2627,
#    'test_negative': 12737},
#   '4-1-2020': {'cases': 2982,
#    'deaths': 69,
#    'recovered': 0,
#    'test_total': 16849,
#    'test_positive': 2966,
#    'test_negative': 13883},
#   '4-2-2020': {'cases': 3342,
#    'deaths': 80,
#    'recovered': 0,
#    'test_total': 18645,
#    'test_positive': 3342,
#    'test_negative': 15303},
#   '4-3-2020': {'cases': 3742,
#    'deaths': 97,
#    'recovered': 0,
#    'test_total': 20411,
#    'test_positive': 3728,
#    'test_negative': 16683},
#   '4-4-2020': {'cases': 4188,
#    'deaths': 111,
#    'recovered': 0,
#    'test_total': 22071,
#    'test_positive': 4173,
#    'test_negative': 17898},
#   '4-5-2020': {'cases': 4950,
#    'deaths': 140,
#    'recovered': 0,
#    'test_total': 23900,
#    'test_positive': 4565,
#    'test_negative': 19335},
#   '4-6-2020': {'cases': 5183,
#    'deaths': 150,
#    'recovered': 0,
#    'test_total': 25773,
#    'test_positive': 4950,
#    'test_negative': 20823},
#   '4-7-2020': {'cases': 5429,
#    'deaths': 179,
#    'recovered': 0,
#    'test_total': 26875,
#    'test_positive': 5172,
#    'test_negative': 21703},
#   '4-8-2020': {'cases': 5655,
#    'deaths': 193,
#    'recovered': 0,
#    'test_total': 28094,
#    'test_positive': 5429,
#    'test_negative': 22665},
#   '4-9-2020': {'cases': 5655,
#    'deaths': 193,
#    'recovered': 0,
#    'test_total': 29199,
#    'test_positive': 5655,
#    'test_negative': 23544},
#   '4-10-2020': {'cases': 6202,
#    'deaths': 226,
#    'recovered': 0,
#    'test_total': 32653,
#    'test_positive': 6510,
#    'test_negative': 26143},
#   '4-11-2020': {'cases': 6513,
#    'deaths': 250,
#    'recovered': 0,
#    'test_total': 32653,
#    'test_positive': 6510,
#    'test_negative': 26143},
#   '4-12-2020': {'cases': 7307,
#    'deaths': 289,
#    'recovered': 0,
#    'test_total': 34873,
#    'test_positive': 6893,
#    'test_negative': 27980},
#   '4-13-2020': {'cases': 7691,
#    'deaths': 306,
#    'recovered': 0,
#    'test_total': 37534,
#    'test_positive': 7684,
#    'test_negative': 29850},
#   '3-5-2020': {'test_total': 40, 'test_positive': 0, 'test_negative': 19}},
#  'Connecticut': {'3-7-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 0,
#    'test_positive': 0,
#    'test_negative': 0},
#   '3-8-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 38,
#    'test_positive': 1,
#    'test_negative': 29},
#   '3-9-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 47,
#    'test_positive': 1,
#    'test_negative': 46},
#   '3-10-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 56,
#    'test_positive': 2,
#    'test_negative': 54},
#   '3-11-2020': {'cases': 3,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 74,
#    'test_positive': 3,
#    'test_negative': 71},
#   '3-12-2020': {'cases': 5,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 95,
#    'test_positive': 6,
#    'test_negative': 89},
#   '3-13-2020': {'cases': 11,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 105,
#    'test_positive': 6,
#    'test_negative': 99},
#   '3-14-2020': {'cases': 22,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 136,
#    'test_positive': 11,
#    'test_negative': 125},
#   '3-15-2020': {'cases': 24,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 145,
#    'test_positive': 20,
#    'test_negative': 125},
#   '3-16-2020': {'cases': 30,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 151,
#    'test_positive': 26,
#    'test_negative': 125},
#   '3-17-2020': {'cases': 68,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 166,
#    'test_positive': 41,
#    'test_negative': 125},
#   '3-18-2020': {'cases': 68,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 193,
#    'test_positive': 68,
#    'test_negative': 125},
#   '3-19-2020': {'cases': 159,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 700,
#    'test_positive': 96,
#    'test_negative': 604},
#   '3-20-2020': {'cases': 194,
#    'deaths': 3,
#    'recovered': 0,
#    'test_total': 798,
#    'test_positive': 194,
#    'test_negative': 604},
#   '3-21-2020': {'cases': 194,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 2300,
#    'test_positive': 194,
#    'test_negative': 2106},
#   '3-22-2020': {'cases': 327,
#    'deaths': 8,
#    'recovered': 0,
#    'test_total': 3100,
#    'test_positive': 223,
#    'test_negative': 2877},
#   '3-23-2020': {'cases': 415,
#    'deaths': 10,
#    'recovered': 0,
#    'test_total': 4500,
#    'test_positive': 415,
#    'test_negative': 4085},
#   '3-24-2020': {'cases': 618,
#    'deaths': 12,
#    'recovered': 0,
#    'test_total': 5300,
#    'test_positive': 618,
#    'test_negative': 4682},
#   '3-25-2020': {'cases': 875,
#    'deaths': 19,
#    'recovered': 0,
#    'test_total': 5898,
#    'test_positive': 875,
#    'test_negative': 5023},
#   '3-26-2020': {'cases': 1012,
#    'deaths': 21,
#    'recovered': 0,
#    'test_total': 6637,
#    'test_positive': 1012,
#    'test_negative': 5625},
#   '3-27-2020': {'cases': 1291,
#    'deaths': 27,
#    'recovered': 0,
#    'test_total': 8400,
#    'test_positive': 1291,
#    'test_negative': 7109},
#   '3-28-2020': {'cases': 1524,
#    'deaths': 33,
#    'recovered': 0,
#    'test_total': 8400,
#    'test_positive': 1291,
#    'test_negative': 7109},
#   '3-29-2020': {'cases': 1993,
#    'deaths': 34,
#    'recovered': 0,
#    'test_total': 11900,
#    'test_positive': 1993,
#    'test_negative': 9907},
#   '3-30-2020': {'cases': 2571,
#    'deaths': 36,
#    'recovered': 0,
#    'test_total': 14600,
#    'test_positive': 2571,
#    'test_negative': 12029},
#   '3-31-2020': {'cases': 3128,
#    'deaths': 69,
#    'recovered': 0,
#    'test_total': 16157,
#    'test_positive': 3128,
#    'test_negative': 13029},
#   '4-1-2020': {'cases': 3557,
#    'deaths': 85,
#    'recovered': 0,
#    'test_total': 16600,
#    'test_positive': 3557,
#    'test_negative': 13043},
#   '4-2-2020': {'cases': 3824,
#    'deaths': 112,
#    'recovered': 0,
#    'test_total': 18300,
#    'test_positive': 3824,
#    'test_negative': 14476},
#   '4-3-2020': {'cases': 4914,
#    'deaths': 131,
#    'recovered': 0,
#    'test_total': 20015,
#    'test_positive': 4914,
#    'test_negative': 15101},
#   '4-4-2020': {'cases': 5276,
#    'deaths': 165,
#    'recovered': 0,
#    'test_total': 22029,
#    'test_positive': 5276,
#    'test_negative': 16753},
#   '4-5-2020': {'cases': 5675,
#    'deaths': 189,
#    'recovered': 0,
#    'test_total': 23270,
#    'test_positive': 5675,
#    'test_negative': 17595},
#   '4-6-2020': {'cases': 6906,
#    'deaths': 206,
#    'recovered': 0,
#    'test_total': 26686,
#    'test_positive': 6906,
#    'test_negative': 19780},
#   '4-7-2020': {'cases': 7781,
#    'deaths': 277,
#    'recovered': 0,
#    'test_total': 29036,
#    'test_positive': 7781,
#    'test_negative': 21255},
#   '4-8-2020': {'cases': 7781,
#    'deaths': 326,
#    'recovered': 0,
#    'test_total': 29036,
#    'test_positive': 7781,
#    'test_negative': 21255},
#   '4-9-2020': {'cases': 9784,
#    'deaths': 380,
#    'recovered': 0,
#    'test_total': 33502,
#    'test_positive': 9784,
#    'test_negative': 23718},
#   '4-10-2020': {'cases': 10538,
#    'deaths': 448,
#    'recovered': 0,
#    'test_total': 36288,
#    'test_positive': 10538,
#    'test_negative': 25750},
#   '4-11-2020': {'cases': 11510,
#    'deaths': 494,
#    'recovered': 0,
#    'test_total': 39831,
#    'test_positive': 11510,
#    'test_negative': 28321},
#   '4-12-2020': {'cases': 12035,
#    'deaths': 554,
#    'recovered': 0,
#    'test_total': 41220,
#    'test_positive': 12035,
#    'test_negative': 29185},
#   '4-13-2020': {'cases': 13381,
#    'deaths': 602,
#    'recovered': 0,
#    'test_total': 44309,
#    'test_positive': 13381,
#    'test_negative': 30928}},
#  'Delaware': {'3-10-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 20,
#    'test_positive': 0,
#    'test_negative': 17},
#   '3-11-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 20,
#    'test_positive': 1,
#    'test_negative': 17},
#   '3-12-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 41,
#    'test_positive': 4,
#    'test_negative': 23},
#   '3-13-2020': {'cases': 4,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 44,
#    'test_positive': 4,
#    'test_negative': 30},
#   '3-14-2020': {'cases': 6,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 74,
#    'test_positive': 6,
#    'test_negative': 36},
#   '3-15-2020': {'cases': 7,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 74,
#    'test_positive': 6,
#    'test_negative': 36},
#   '3-16-2020': {'cases': 8,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 76,
#    'test_positive': 8,
#    'test_negative': 36},
#   '3-17-2020': {'cases': 16,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 52,
#    'test_positive': 16,
#    'test_negative': 36},
#   '3-18-2020': {'cases': 19,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 61,
#    'test_positive': 25,
#    'test_negative': 36},
#   '3-19-2020': {'cases': 30,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 66,
#    'test_positive': 30,
#    'test_negative': 36},
#   '3-20-2020': {'cases': 38,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 74,
#    'test_positive': 38,
#    'test_negative': 36},
#   '3-21-2020': {'cases': 45,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 81,
#    'test_positive': 45,
#    'test_negative': 36},
#   '3-22-2020': {'cases': 56,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 92,
#    'test_positive': 56,
#    'test_negative': 36},
#   '3-23-2020': {'cases': 68,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 104,
#    'test_positive': 68,
#    'test_negative': 36},
#   '3-24-2020': {'cases': 104,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 127,
#    'test_positive': 91,
#    'test_negative': 36},
#   '3-25-2020': {'cases': 119,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 151,
#    'test_positive': 115,
#    'test_negative': 36},
#   '3-26-2020': {'cases': 130,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 166,
#    'test_positive': 130,
#    'test_negative': 36},
#   '3-27-2020': {'cases': 163,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 199,
#    'test_positive': 163,
#    'test_negative': 36},
#   '3-28-2020': {'cases': 214,
#    'deaths': 5,
#    'recovered': 0,
#    'test_total': 250,
#    'test_positive': 214,
#    'test_negative': 36},
#   '3-29-2020': {'cases': 232,
#    'deaths': 6,
#    'recovered': 0,
#    'test_total': 268,
#    'test_positive': 232,
#    'test_negative': 36},
#   '3-30-2020': {'cases': 264,
#    'deaths': 6,
#    'recovered': 0,
#    'test_total': 2480,
#    'test_positive': 264,
#    'test_negative': 2216},
#   '3-31-2020': {'cases': 319,
#    'deaths': 10,
#    'recovered': 0,
#    'test_total': 4015,
#    'test_positive': 319,
#    'test_negative': 3696},
#   '4-1-2020': {'cases': 368,
#    'deaths': 11,
#    'recovered': 0,
#    'test_total': 4383,
#    'test_positive': 368,
#    'test_negative': 4015},
#   '4-2-2020': {'cases': 393,
#    'deaths': 12,
#    'recovered': 0,
#    'test_total': 4959,
#    'test_positive': 393,
#    'test_negative': 4566},
#   '4-3-2020': {'cases': 450,
#    'deaths': 14,
#    'recovered': 0,
#    'test_total': 5445,
#    'test_positive': 450,
#    'test_negative': 4995},
#   '4-4-2020': {'cases': 593,
#    'deaths': 14,
#    'recovered': 0,
#    'test_total': 6467,
#    'test_positive': 593,
#    'test_negative': 5874},
#   '4-5-2020': {'cases': 673,
#    'deaths': 14,
#    'recovered': 0,
#    'test_total': 6994,
#    'test_positive': 673,
#    'test_negative': 6321},
#   '4-6-2020': {'cases': 783,
#    'deaths': 15,
#    'recovered': 0,
#    'test_total': 6994,
#    'test_positive': 673,
#    'test_negative': 6321},
#   '4-7-2020': {'cases': 928,
#    'deaths': 16,
#    'recovered': 0,
#    'test_total': 8556,
#    'test_positive': 928,
#    'test_negative': 7628},
#   '4-8-2020': {'cases': 1116,
#    'deaths': 19,
#    'recovered': 0,
#    'test_total': 8556,
#    'test_positive': 928,
#    'test_negative': 7628},
#   '4-9-2020': {'cases': 1209,
#    'deaths': 23,
#    'recovered': 0,
#    'test_total': 9890,
#    'test_positive': 1207,
#    'test_negative': 8683},
#   '4-10-2020': {'cases': 1326,
#    'deaths': 32,
#    'recovered': 0,
#    'test_total': 11741,
#    'test_positive': 1326,
#    'test_negative': 10415},
#   '4-11-2020': {'cases': 1479,
#    'deaths': 33,
#    'recovered': 0,
#    'test_total': 11103,
#    'test_positive': 1479,
#    'test_negative': 9624},
#   '4-12-2020': {'cases': 1625,
#    'deaths': 35,
#    'recovered': 0,
#    'test_total': 11103,
#    'test_positive': 1479,
#    'test_negative': 9624},
#   '4-13-2020': {'cases': 1758,
#    'deaths': 41,
#    'recovered': 0,
#    'test_total': 11820,
#    'test_positive': 1625,
#    'test_negative': 10195},
#   '3-9-2020': {'test_total': 18, 'test_positive': 0, 'test_negative': 15},
#   '3-8-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#   '3-7-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#   '3-6-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10}},
#  'District of Columbia': {'3-8-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 11,
#    'test_positive': 1,
#    'test_negative': 10},
#   '3-9-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 18,
#    'test_positive': 1,
#    'test_negative': 14},
#   '3-10-2020': {'cases': 5,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 24,
#    'test_positive': 5,
#    'test_negative': 17},
#   '3-11-2020': {'cases': 10,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 40,
#    'test_positive': 5,
#    'test_negative': 20},
#   '3-12-2020': {'cases': 10,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 30,
#    'test_positive': 10,
#    'test_negative': 20},
#   '3-13-2020': {'cases': 10,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 30,
# ...
#   '3-21-2020': {'cases': 8,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 343,
#    'test_positive': 11,
#    'test_negative': 330},
#   '3-22-2020': {'cases': 16,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 398,
#    'test_positive': 12,
#    'test_negative': 385},
#   '3-23-2020': {'cases': 16,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 464,
#    'test_positive': 16,
#    'test_negative': 444},
#   '3-24-2020': {'cases': 22,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 630,
#    'test_positive': 20,
#    'test_negative': 610},
#   '3-25-2020': {'cases': 39,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 804,
#    'test_positive': 39,
#    'test_negative': 759},
#   '3-26-2020': {'cases': 52,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1101,
#    'test_positive': 51,
#    'test_negative': 1031},
#   '3-27-2020': {'cases': 76,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1898,
#    'test_positive': 76,
#    'test_negative': 1779},
#   '3-28-2020': {'cases': 96,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2433,
#    'test_positive': 96,
#    'test_negative': 2331},
#   '3-29-2020': {'cases': 113,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2818,
#    'test_positive': 113,
#    'test_negative': 2705},
#   '3-30-2020': {'cases': 145,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 3110,
#    'test_positive': 126,
#    'test_negative': 2984},
#   '3-31-2020': {'cases': 162,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 4143,
#    'test_positive': 162,
#    'test_negative': 3981},
#   '4-1-2020': {'cases': 191,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 4575,
#    'test_positive': 191,
#    'test_negative': 4384},
#   '4-2-2020': {'cases': 216,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 5493,
#    'test_positive': 217,
#    'test_negative': 5276},
#   '4-3-2020': {'cases': 237,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 6367,
#    'test_positive': 237,
#    'test_negative': 6130},
#   '4-4-2020': {'cases': 282,
#    'deaths': 2,
#    'recovered': 0,
#    'test_total': 7686,
#    'test_positive': 282,
#    'test_negative': 7404},
#   '4-5-2020': {'cases': 324,
#    'deaths': 3,
#    'recovered': 0,
#    'test_total': 8838,
#    'test_positive': 324,
#    'test_negative': 8514},
#   '4-6-2020': {'cases': 345,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 9940,
#    'test_positive': 345,
#    'test_negative': 9595},
#   '4-7-2020': {'cases': 412,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 12059,
#    'test_positive': 412,
#    'test_negative': 11647},
#   '4-8-2020': {'cases': 483,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 12545,
#    'test_positive': 462,
#    'test_negative': 12083},
#   '4-9-2020': {'cases': 514,
#    'deaths': 5,
#    'recovered': 0,
#    'test_total': 13863,
#    'test_positive': 523,
#    'test_negative': 13340},
#   '4-10-2020': {'cases': 574,
#    'deaths': 5,
#    'recovered': 0,
#    'test_total': 14555,
#    'test_positive': 554,
#    'test_negative': 14001},
#   '4-11-2020': {'cases': 577,
#    'deaths': 5,
#    'recovered': 0,
#    'test_total': 15452,
#    'test_positive': 577,
#    'test_negative': 14875},
#   '4-12-2020': {'cases': 593,
#    'deaths': 6,
#    'recovered': 0,
#    'test_total': 16257,
#    'test_positive': 611,
#    'test_negative': 15646},
#   '4-13-2020': {'cases': 611,
#    'deaths': 8,
#    'recovered': 0,
#    'test_total': 16655,
#    'test_positive': 626,
#    'test_negative': 16029},
#   '3-9-2020': {'test_total': 5, 'test_positive': 0, 'test_negative': 2},
#   '3-8-2020': {'test_total': 5, 'test_positive': 0, 'test_negative': 2},
#   '3-7-2020': {'test_total': 5, 'test_positive': 0, 'test_negative': 2},
#   '3-6-2020': {'test_total': 5, 'test_positive': 0, 'test_negative': 1}},
#  'Wisconsin': {'2-5-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-6-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-7-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-8-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-9-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-10-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-11-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-12-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-13-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-14-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-15-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-16-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-17-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-18-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-19-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-20-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-21-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-22-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-23-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-24-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-25-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-26-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-27-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-28-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '2-29-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '3-1-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '3-2-2020': {'cases': 1, 'deaths': 0, 'recovered': 0},
#   '3-3-2020': {'cases': 1, 'deaths': 0, 'recovered': 1},
#   '3-4-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 26,
#    'test_positive': 1,
#    'test_negative': 19},
#   '3-5-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 26,
#    'test_positive': 1,
#    'test_negative': 19},
#   '3-6-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 44,
#    'test_positive': 1,
#    'test_negative': 31},
#   '3-7-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 44,
#    'test_positive': 1,
#    'test_negative': 31},
#   '3-8-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 44,
#    'test_positive': 1,
#    'test_negative': 31},
#   '3-9-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 37,
#    'test_positive': 1,
#    'test_negative': 36},
#   '3-10-2020': {'cases': 3,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 38,
#    'test_positive': 2,
#    'test_negative': 36},
#   '3-11-2020': {'cases': 6,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 46,
#    'test_positive': 3,
#    'test_negative': 43},
#   '3-12-2020': {'cases': 8,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 92,
#    'test_positive': 8,
#    'test_negative': 84},
#   '3-13-2020': {'cases': 19,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 188,
#    'test_positive': 19,
#    'test_negative': 169},
#   '3-14-2020': {'cases': 27,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 188,
#    'test_positive': 19,
#    'test_negative': 169},
#   '3-15-2020': {'cases': 32,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 346,
#    'test_positive': 33,
#    'test_negative': 313},
#   '3-16-2020': {'cases': 47,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 551,
#    'test_positive': 47,
#    'test_negative': 504},
#   '3-17-2020': {'cases': 72,
#    'deaths': 0,
#    'recovered': 1,
#    'test_total': 1110,
#    'test_positive': 72,
#    'test_negative': 1038},
#   '3-18-2020': {'cases': 92,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1683,
#    'test_positive': 106,
#    'test_negative': 1577},
#   '3-19-2020': {'cases': 159,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2347,
#    'test_positive': 155,
#    'test_negative': 2192},
#   '3-20-2020': {'cases': 207,
#    'deaths': 3,
#    'recovered': 0,
#    'test_total': 3661,
#    'test_positive': 206,
#    'test_negative': 3455},
#   '3-21-2020': {'cases': 282,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 4909,
#    'test_positive': 281,
#    'test_negative': 4628},
#   '3-22-2020': {'cases': 381,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 6615,
#    'test_positive': 385,
#    'test_negative': 6230},
#   '3-23-2020': {'cases': 425,
#    'deaths': 5,
#    'recovered': 0,
#    'test_total': 7466,
#    'test_positive': 416,
#    'test_negative': 7050},
#   '3-24-2020': {'cases': 481,
#    'deaths': 5,
#    'recovered': 0,
#    'test_total': 8694,
#    'test_positive': 457,
#    'test_negative': 8237},
#   '3-25-2020': {'cases': 621,
#    'deaths': 7,
#    'recovered': 0,
#    'test_total': 10674,
#    'test_positive': 585,
#    'test_negative': 10089},
#   '3-26-2020': {'cases': 728,
#    'deaths': 10,
#    'recovered': 0,
#    'test_total': 12290,
#    'test_positive': 707,
#    'test_negative': 11583},
#   '3-27-2020': {'cases': 926,
#    'deaths': 14,
#    'recovered': 0,
#    'test_total': 13982,
#    'test_positive': 842,
#    'test_negative': 13140},
#   '3-28-2020': {'cases': 1055,
#    'deaths': 17,
#    'recovered': 0,
#    'test_total': 16221,
#    'test_positive': 989,
#    'test_negative': 15232},
#   '3-29-2020': {'cases': 1164,
#    'deaths': 18,
#    'recovered': 0,
#    'test_total': 17662,
#    'test_positive': 1112,
#    'test_negative': 16550},
#   '3-30-2020': {'cases': 1230,
#    'deaths': 20,
#    'recovered': 0,
#    'test_total': 17077,
#    'test_positive': 1221,
#    'test_negative': 15856},
#   '3-31-2020': {'cases': 1412,
#    'deaths': 25,
#    'recovered': 0,
#    'test_total': 18726,
#    'test_positive': 1351,
#    'test_negative': 17375},
#   '4-1-2020': {'cases': 1556,
#    'deaths': 27,
#    'recovered': 0,
#    'test_total': 20369,
#    'test_positive': 1550,
#    'test_negative': 18819},
#   '4-2-2020': {'cases': 1748,
#    'deaths': 38,
#    'recovered': 0,
#    'test_total': 22047,
#    'test_positive': 1730,
#    'test_negative': 20317},
#   '4-3-2020': {'cases': 2012,
#    'deaths': 51,
#    'recovered': 0,
#    'test_total': 24289,
#    'test_positive': 1912,
#    'test_negative': 22377},
#   '4-4-2020': {'cases': 2030,
#    'deaths': 54,
#    'recovered': 0,
#    'test_total': 25971,
#    'test_positive': 2112,
#    'test_negative': 23859},
#   '4-5-2020': {'cases': 2320,
#    'deaths': 74,
#    'recovered': 0,
#    'test_total': 27436,
#    'test_positive': 2267,
#    'test_negative': 25169},
#   '4-6-2020': {'cases': 2449,
#    'deaths': 78,
#    'recovered': 0,
#    'test_total': 29014,
#    'test_positive': 2440,
#    'test_negative': 26574},
#   '4-7-2020': {'cases': 2578,
#    'deaths': 92,
#    'recovered': 0,
#    'test_total': 31090,
#    'test_positive': 2578,
#    'test_negative': 28512},
#   '4-8-2020': {'cases': 2710,
#    'deaths': 100,
#    'recovered': 0,
#    'test_total': 32871,
#    'test_positive': 2756,
#    'test_negative': 30115},
#   '4-9-2020': {'cases': 2886,
#    'deaths': 111,
#    'recovered': 0,
#    'test_total': 34309,
#    'test_positive': 2885,
#    'test_negative': 31424},
#   '4-10-2020': {'cases': 3068,
#    'deaths': 128,
#    'recovered': 0,
#    'test_total': 36293,
#    'test_positive': 3068,
#    'test_negative': 33225},
#   '4-11-2020': {'cases': 3213,
#    'deaths': 137,
#    'recovered': 0,
#    'test_total': 37893,
#    'test_positive': 3213,
#    'test_negative': 34680},
#   '4-12-2020': {'cases': 3341,
#    'deaths': 144,
#    'recovered': 0,
#    'test_total': 39257,
#    'test_positive': 3341,
#    'test_negative': 35916},
#   '4-13-2020': {'cases': 3428,
#    'deaths': 154,
#    'recovered': 0,
#    'test_total': 40470,
#    'test_positive': 3428,
#    'test_negative': 36769}},
#  'Wyoming': {'3-10-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 0,
#    'test_positive': 0,
#    'test_negative': 0},
#   '3-11-2020': {'cases': 0,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 0,
#    'test_positive': 0,
#    'test_negative': 0},
#   '3-12-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1,
#    'test_positive': 1,
#    'test_negative': 0},
#   '3-13-2020': {'cases': 1,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1,
#    'test_positive': 1,
#    'test_negative': 0},
#   '3-14-2020': {'cases': 2,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2,
#    'test_positive': 2,
#    'test_negative': 0},
#   '3-15-2020': {'cases': 3,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 3,
#    'test_positive': 3,
#    'test_negative': 0},
#   '3-16-2020': {'cases': 3,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 3,
#    'test_positive': 3,
#    'test_negative': 0},
#   '3-17-2020': {'cases': 11,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 105,
#    'test_positive': 10,
#    'test_negative': 95},
#   '3-18-2020': {'cases': 15,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 193,
#    'test_positive': 15,
#    'test_negative': 178},
#   '3-19-2020': {'cases': 18,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 289,
#    'test_positive': 18,
#    'test_negative': 271},
#   '3-20-2020': {'cases': 19,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 350,
#    'test_positive': 19,
#    'test_negative': 331},
#   '3-21-2020': {'cases': 23,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 461,
#    'test_positive': 23,
#    'test_negative': 438},
#   '3-22-2020': {'cases': 26,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 462,
#    'test_positive': 24,
#    'test_negative': 438},
#   '3-23-2020': {'cases': 26,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 618,
#    'test_positive': 26,
#    'test_negative': 592},
#   '3-24-2020': {'cases': 29,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 739,
#    'test_positive': 29,
#    'test_negative': 710},
#   '3-25-2020': {'cases': 44,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 998,
#    'test_positive': 44,
#    'test_negative': 954},
#   '3-26-2020': {'cases': 53,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1105,
#    'test_positive': 53,
#    'test_negative': 1052},
#   '3-27-2020': {'cases': 70,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1281,
#    'test_positive': 70,
#    'test_negative': 1211},
#   '3-28-2020': {'cases': 82,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1557,
#    'test_positive': 82,
#    'test_negative': 1475},
#   '3-29-2020': {'cases': 86,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1640,
#    'test_positive': 86,
#    'test_negative': 1554},
#   '3-30-2020': {'cases': 94,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1934,
#    'test_positive': 94,
#    'test_negative': 1840},
#   '3-31-2020': {'cases': 109,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2108,
#    'test_positive': 109,
#    'test_negative': 1999},
#   '4-1-2020': {'cases': 130,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2348,
#    'test_positive': 130,
#    'test_negative': 2218},
#   '4-2-2020': {'cases': 150,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2589,
#    'test_positive': 150,
#    'test_negative': 2439},
#   '4-3-2020': {'cases': 162,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2866,
#    'test_positive': 162,
#    'test_negative': 2704},
#   '4-4-2020': {'cases': 187,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 3132,
#    'test_positive': 187,
#    'test_negative': 2945},
#   '4-5-2020': {'cases': 197,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 3237,
#    'test_positive': 197,
#    'test_negative': 3040},
#   '4-6-2020': {'cases': 210,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 3929,
#    'test_positive': 210,
#    'test_negative': 3719},
#   '4-7-2020': {'cases': 216,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 4005,
#    'test_positive': 216,
#    'test_negative': 3789},
#   '4-8-2020': {'cases': 221,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 4064,
#    'test_positive': 221,
#    'test_negative': 3843},
#   '4-9-2020': {'cases': 230,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 4150,
#    'test_positive': 230,
#    'test_negative': 3920},
#   '4-10-2020': {'cases': 239,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 5056,
#    'test_positive': 320,
#    'test_negative': 4736},
#   '4-11-2020': {'cases': 261,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 5459,
#    'test_positive': 261,
#    'test_negative': 5198},
#   '4-12-2020': {'cases': 270,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 5459,
#    'test_positive': 261,
#    'test_negative': 5198},
#   '4-13-2020': {'cases': 275,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 5964,
#    'test_positive': 275,
#    'test_negative': 5689},
#   '3-9-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#   '3-8-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#   '3-7-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0}}}

# %% [markdown]
# #### Add today's data to state time series

# %% [markdown]
# This makes it look like curve is flattening, so we adding it now, but dont display it until the next day

# %%
for cur_state in state_json["features"]:
    props = cur_state["properties"]
    statename = props["statename"]
    state_time_data[statename][todays_date] = {
        "cases":props["cases"], 
        "deaths":props["deaths"],
        "recovered":props["recovered"],
        "test_total":props["test_total"],
        "test_negative":props["test_negative"],
        "test_positive":props["test_positive"],
    }

# %% [markdown]
# #### Add old state date to state time series

# %%
state_time_data["Alabama"]
# Out:
# {'3-13-2020': {'cases': 5,
#   'deaths': 0,
#   'recovered': 0,
#   'test_total': 12,
#   'test_positive': 1,
#   'test_negative': 11},
#  '3-14-2020': {'cases': 6,
#   'deaths': 0,
#   'recovered': 0,
#   'test_total': 74,
#   'test_positive': 6,
#   'test_negative': 22},
#  '3-15-2020': {'cases': 12,
#   'deaths': 0,
#   'recovered': 0,
#   'test_total': 86,
#   'test_positive': 12,
#   'test_negative': 28},
#  '3-16-2020': {'cases': 29,
#   'deaths': 0,
#   'recovered': 0,
#   'test_total': 96,
#   'test_positive': 28,
#   'test_negative': 28},
#  '3-17-2020': {'cases': 39,
#   'deaths': 0,
#   'recovered': 0,
#   'test_total': 64,
#   'test_positive': 36,
#   'test_negative': 28},
#  '3-18-2020': {'cases': 46,
#   'deaths': 0,
#   'recovered': 0,
#   'test_total': 74,
#   'test_positive': 46,
#   'test_negative': 28},
#  '3-19-2020': {'cases': 78,
#   'deaths': 0,
#   'recovered': 0,
#   'test_total': 96,
#   'test_positive': 68,
#   'test_negative': 28},
#  '3-20-2020': {'cases': 83,
#   'deaths': 0,
#   'recovered': 0,
#   'test_total': 109,
#   'test_positive': 81,
#   'test_negative': 28},
#  '3-21-2020': {'cases': 131,
#   'deaths': 0,
#   'recovered': 0,
#   'test_total': 152,
#   'test_positive': 124,
#   'test_negative': 28},
#  '3-22-2020': {'cases': 157,
#   'deaths': 0,
#   'recovered': 0,
#   'test_total': 1602,
#   'test_positive': 138,
#   'test_negative': 1464},
#  '3-23-2020': {'cases': 196,
#   'deaths': 0,
#   'recovered': 0,
#   'test_total': 1832,
#   'test_positive': 167,
#   'test_negative': 1665},
#  '3-24-2020': {'cases': 242,
#   'deaths': 0,
#   'recovered': 0,
#   'test_total': 2321,
#   'test_positive': 215,
#   'test_negative': 2106},
#  '3-25-2020': {'cases': 381,
#   'deaths': 1,
#   'recovered': 0,
#   'test_total': 2812,
#   'test_positive': 283,
#   'test_negative': 2529},
#  '3-26-2020': {'cases': 517,
#   'deaths': 1,
#   'recovered': 0,
#   'test_total': 4099,
#   'test_positive': 506,
#   'test_negative': 3593},
#  '3-27-2020': {'cases': 587,
#   'deaths': 4,
#   'recovered': 0,
#   'test_total': 4771,
#   'test_positive': 587,
#   'test_negative': 4184},
#  '3-28-2020': {'cases': 694,
#   'deaths': 4,
#   'recovered': 0,
#   'test_total': 4880,
#   'test_positive': 696,
#   'test_negative': 4184},
#  '3-29-2020': {'cases': 825,
#   'deaths': 10,
#   'recovered': 0,
#   'test_total': 4990,
#   'test_positive': 806,
#   'test_negative': 4184},
#  '3-30-2020': {'cases': 899,
#   'deaths': 10,
#   'recovered': 0,
#   'test_total': 6553,
#   'test_positive': 859,
#   'test_negative': 5694},
#  '3-31-2020': {'cases': 987,
#   'deaths': 23,
#   'recovered': 0,
#   'test_total': 7279,
#   'test_positive': 981,
#   'test_negative': 6298},
#  '4-1-2020': {'cases': 1060,
#   'deaths': 27,
#   'recovered': 0,
#   'test_total': 7774,
#   'test_positive': 1077,
#   'test_negative': 6697},
#  '4-2-2020': {'cases': 1233,
#   'deaths': 32,
#   'recovered': 0,
#   'test_total': 8736,
#   'test_positive': 1233,
#   'test_negative': 7503},
#  '4-3-2020': {'cases': 1495,
#   'deaths': 38,
#   'recovered': 0,
#   'test_total': 9619,
#   'test_positive': 1432,
#   'test_negative': 8187},
#  '4-4-2020': {'cases': 1614,
#   'deaths': 44,
#   'recovered': 0,
#   'test_total': 10853,
#   'test_positive': 1580,
#   'test_negative': 9273},
#  '4-5-2020': {'cases': 1765,
#   'deaths': 45,
#   'recovered': 0,
#   'test_total': 13078,
#   'test_positive': 1796,
#   'test_negative': 11282},
#  '4-6-2020': {'cases': 1952,
#   'deaths': 49,
#   'recovered': 0,
#   'test_total': 14765,
#   'test_positive': 1968,
#   'test_negative': 12797},
#  '4-7-2020': {'cases': 2169,
#   'deaths': 64,
#   'recovered': 0,
#   'test_total': 14916,
#   'test_positive': 2119,
#   'test_negative': 12797},
#  '4-8-2020': {'cases': 2328,
#   'deaths': 66,
#   'recovered': 0,
#   'test_total': 19122,
#   'test_positive': 2369,
#   'test_negative': 16753},
#  '4-9-2020': {'cases': 2703,
#   'deaths': 70,
#   'recovered': 0,
#   'test_total': 20827,
#   'test_positive': 2769,
#   'test_negative': 18058},
#  '4-10-2020': {'cases': 2947,
#   'deaths': 80,
#   'recovered': 0,
#   'test_total': 21026,
#   'test_positive': 2968,
#   'test_negative': 18058},
#  '4-11-2020': {'cases': 3217,
#   'deaths': 92,
#   'recovered': 0,
#   'test_total': 21249,
#   'test_positive': 3191,
#   'test_negative': 18058},
#  '4-12-2020': {'cases': 3563,
#   'deaths': 93,
#   'recovered': 0,
#   'test_total': 21583,
#   'test_positive': 3525,
#   'test_negative': 18058},
#  '4-13-2020': {'cases': 3734,
#   'deaths': 99,
#   'recovered': 0,
#   'test_total': 29182,
#   'test_positive': 3734,
#   'test_negative': 25448},
#  '3-12-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#  '3-11-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#  '3-10-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#  '3-9-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#  '3-8-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#  '3-7-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#  '4-14-2020': {'cases': 3809,
#   'deaths': 103,
#   'recovered': 0,
#   'test_total': 33050,
#   'test_negative': 29241,
#   'test_positive': 3809}}

# %%
for state in state_json["features"]:
    statename = state["properties"]["statename"]
    if statename in state_time_data.keys():
        state["properties"]["time_series"] = state_time_data[statename]

# %% [markdown]
# #### Save latest state time series data to file

# %%
state_json["features"][0]
# Out:
# {'type': 'Feature',
#  'id': '01',
#  'properties': {'population': 4903185,
#   'beds': 19000,
#   'statename': 'Alabama',
#   'population_density': 94.65,
#   'lat': 32.78990682135675,
#   'long': -86.82778271419518,
#   'abbr': 'AL',
#   'age0-19': 1217278,
#   'age20-44': 1561062,
#   'age45-54': 627458,
#   'age55-64': 655179,
#   'age65-74': 487721,
#   'age75-84': 249308,
#   'age85+': 89865,
#   'comorbid_obesity': 36.2,
#   'comorbid_diabetes': 16.19,
#   'comorbid_cancer': 0.4578,
#   'comorbid_smoking': 17.48,
#   'comorbid_hypertension': 42.297682294263836,
#   'cases': 3809,
#   'deaths': 103,
#   'active': 3706,
#   'recovered': 0,
#   'time_cases_update': '4/14 11:43AM',
#   'time_tests_updated': '4/14 0:00AM',
#   'test_grade': 'B',
#   'test_positive': 3809,
#   'test_negative': 29241,
#   'test_total': 33050,
#   'pc_cases': 77.68419914810475,
#   'pc_active': 75.5835237707735,
#   'pc_deaths': 2.100675377331265,
#   'pc_tests': 674.0516623378478,
#   'time_series': {'3-13-2020': {'cases': 5,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 12,
#     'test_positive': 1,
#     'test_negative': 11},
#    '3-14-2020': {'cases': 6,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 74,
#     'test_positive': 6,
#     'test_negative': 22},
#    '3-15-2020': {'cases': 12,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 86,
#     'test_positive': 12,
#     'test_negative': 28},
#    '3-16-2020': {'cases': 29,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 96,
#     'test_positive': 28,
#     'test_negative': 28},
#    '3-17-2020': {'cases': 39,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 64,
#     'test_positive': 36,
#     'test_negative': 28},
#    '3-18-2020': {'cases': 46,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 74,
#     'test_positive': 46,
#     'test_negative': 28},
#    '3-19-2020': {'cases': 78,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 96,
#     'test_positive': 68,
#     'test_negative': 28},
#    '3-20-2020': {'cases': 83,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 109,
#     'test_positive': 81,
#     'test_negative': 28},
#    '3-21-2020': {'cases': 131,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 152,
#     'test_positive': 124,
#     'test_negative': 28},
#    '3-22-2020': {'cases': 157,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 1602,
#     'test_positive': 138,
#     'test_negative': 1464},
#    '3-23-2020': {'cases': 196,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 1832,
#     'test_positive': 167,
#     'test_negative': 1665},
#    '3-24-2020': {'cases': 242,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 2321,
#     'test_positive': 215,
#     'test_negative': 2106},
#    '3-25-2020': {'cases': 381,
#     'deaths': 1,
#     'recovered': 0,
#     'test_total': 2812,
#     'test_positive': 283,
#     'test_negative': 2529},
#    '3-26-2020': {'cases': 517,
#     'deaths': 1,
#     'recovered': 0,
#     'test_total': 4099,
#     'test_positive': 506,
#     'test_negative': 3593},
#    '3-27-2020': {'cases': 587,
#     'deaths': 4,
#     'recovered': 0,
#     'test_total': 4771,
#     'test_positive': 587,
#     'test_negative': 4184},
#    '3-28-2020': {'cases': 694,
#     'deaths': 4,
#     'recovered': 0,
#     'test_total': 4880,
#     'test_positive': 696,
#     'test_negative': 4184},
#    '3-29-2020': {'cases': 825,
#     'deaths': 10,
#     'recovered': 0,
#     'test_total': 4990,
#     'test_positive': 806,
#     'test_negative': 4184},
#    '3-30-2020': {'cases': 899,
#     'deaths': 10,
#     'recovered': 0,
#     'test_total': 6553,
#     'test_positive': 859,
#     'test_negative': 5694},
#    '3-31-2020': {'cases': 987,
#     'deaths': 23,
#     'recovered': 0,
#     'test_total': 7279,
#     'test_positive': 981,
#     'test_negative': 6298},
#    '4-1-2020': {'cases': 1060,
#     'deaths': 27,
#     'recovered': 0,
#     'test_total': 7774,
#     'test_positive': 1077,
#     'test_negative': 6697},
#    '4-2-2020': {'cases': 1233,
#     'deaths': 32,
#     'recovered': 0,
#     'test_total': 8736,
#     'test_positive': 1233,
#     'test_negative': 7503},
#    '4-3-2020': {'cases': 1495,
#     'deaths': 38,
#     'recovered': 0,
#     'test_total': 9619,
#     'test_positive': 1432,
#     'test_negative': 8187},
#    '4-4-2020': {'cases': 1614,
#     'deaths': 44,
#     'recovered': 0,
#     'test_total': 10853,
#     'test_positive': 1580,
#     'test_negative': 9273},
#    '4-5-2020': {'cases': 1765,
#     'deaths': 45,
#     'recovered': 0,
#     'test_total': 13078,
#     'test_positive': 1796,
#     'test_negative': 11282},
#    '4-6-2020': {'cases': 1952,
#     'deaths': 49,
#     'recovered': 0,
#     'test_total': 14765,
#     'test_positive': 1968,
#     'test_negative': 12797},
#    '4-7-2020': {'cases': 2169,
#     'deaths': 64,
#     'recovered': 0,
#     'test_total': 14916,
#     'test_positive': 2119,
#     'test_negative': 12797},
#    '4-8-2020': {'cases': 2328,
#     'deaths': 66,
#     'recovered': 0,
#     'test_total': 19122,
#     'test_positive': 2369,
#     'test_negative': 16753},
#    '4-9-2020': {'cases': 2703,
#     'deaths': 70,
#     'recovered': 0,
#     'test_total': 20827,
#     'test_positive': 2769,
#     'test_negative': 18058},
#    '4-10-2020': {'cases': 2947,
#     'deaths': 80,
#     'recovered': 0,
#     'test_total': 21026,
#     'test_positive': 2968,
#     'test_negative': 18058},
#    '4-11-2020': {'cases': 3217,
#     'deaths': 92,
#     'recovered': 0,
#     'test_total': 21249,
#     'test_positive': 3191,
#     'test_negative': 18058},
#    '4-12-2020': {'cases': 3563,
#     'deaths': 93,
#     'recovered': 0,
#     'test_total': 21583,
#     'test_positive': 3525,
#     'test_negative': 18058},
#    '4-13-2020': {'cases': 3734,
#     'deaths': 99,
#     'recovered': 0,
#     'test_total': 29182,
#     'test_positive': 3734,
#     'test_negative': 25448},
#    '3-12-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#    '3-11-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#    '3-10-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#    '3-9-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#    '3-8-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#    '3-7-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#    '4-14-2020': {'cases': 3809,
#     'deaths': 103,
#     'recovered': 0,
#     'test_total': 33050,
#     'test_negative': 29241,
#     'test_positive': 3809}}},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-87.359296, 35.00118],
#     [-85.606675, 34.984749],
#     [-85.431413, 34.124869],
#     [-85.184951, 32.859696],
#     [-85.069935, 32.580372],
#     [-84.960397, 32.421541],
#     [-85.004212, 32.322956],
#     [-84.889196, 32.262709],
#     [-85.058981, 32.13674],
#     [-85.053504, 32.01077],
#     [-85.141136, 31.840985],
#     [-85.042551, 31.539753],
#     [-85.113751, 31.27686],
#     [-85.004212, 31.003013],
#     [-85.497137, 30.997536],
#     [-87.600282, 30.997536],
#     [-87.633143, 30.86609],
#     [-87.408589, 30.674397],
#     [-87.446927, 30.510088],
#     [-87.37025, 30.427934],
#     [-87.518128, 30.280057],
#     [-87.655051, 30.247195],
#     [-87.90699, 30.411504],
#     [-87.934375, 30.657966],
#     [-88.011052, 30.685351],
#     [-88.10416, 30.499135],
#     [-88.137022, 30.318396],
#     [-88.394438, 30.367688],
#     [-88.471115, 31.895754],
#     [-88.241084, 33.796253],
#     [-88.098683, 34.891641],
#     [-88.202745, 34.995703],
#     [-87.359296, 35.00118]]]}}

# %%
with open(state_data_folder/"stateTimeData.json", 'w') as f:
    json.dump(state_time_data, f)

# %% [markdown]
# ## Calculate Risk

# %% [markdown]
# ### Add in county risk

# %%
#111 is to convert degrees to kilometers
def get_distance(c0, c1):
    lat_dist = abs(c0[0])-abs(c1[0])
    lng_dist = abs(c0[1])-abs(c1[1])
    distance = 111 * math.sqrt(lat_dist**2 + lng_dist**2)
    return float(distance)

# %% [markdown]
# #### County Local Risk

# %%
def calc_county_local_risk(props):
    cases = props["cases"]
    try:
        population = props["population"]
    except KeyError:
        print_and_log(f"{props['name']}, {props['statename']}")
        raise KeyError
    if cases == 'NaN': 
        print_and_log('NaN cases found')
        cases = 0
    return cases/(population/100000) if population != -1 else -1

# %%
print_and_log("\nCalculating local county risk")
for county in counties:
    county["properties"]["risk_local"] = calc_county_local_risk(county["properties"])
# Out:
# Calculating local county risk

# %% [markdown]
# #### County Neighbor Risk

# %%
def calc_county_neighbor_risk(risks):
    total_neighbor_risk = 0
    num_risks = len(risks)
    if(num_risks == 0): return 0
    total_cases = 0
    total_pop = 0
    for risk in risks.values():
        distance, neighbor_cases, neighbor_pop = risk.values()
        #total_neighbor_risk += (float(neighbor_cases)*(2**((-distance-50)/50)))
        exp = 2**((-distance-50)/50)
        total_cases += float(neighbor_cases)*(2**((-distance-50)/50))
        total_pop += (float(neighbor_pop)*(2**((-distance-50)/50)))/100000
    total_neighbor_risk = total_cases/total_pop
    return total_neighbor_risk

# %%
def get_county_all_neighbor_risk(props):
    risk_details = {}
    for county in counties:
        neighbor_props = county["properties"]
        neighbor_risk = get_county_neighbor_risk(props, neighbor_props)
        if(neighbor_risk != {}): risk_details[neighbor_props["geo_id"]] = neighbor_risk
    props["risk_nearby"] = calc_county_neighbor_risk(risk_details)
    props["risk_total"] = props["risk_nearby"] + props["risk_local"]

# %%
MAX_DISTANCE = 100
def get_county_neighbor_risk(props, neighbor_props):
    geoID1 = props["geo_id"]
    geoID2 = neighbor_props["geo_id"]
    centroid = [props["lat"], props["long"]]
    centroid_neighbor = [neighbor_props["lat"], neighbor_props["long"]]
    distance = get_distance(centroid, centroid_neighbor)
    neighbor_cases = neighbor_props["cases"]
    neighbor_population = neighbor_props["population"]
    if(geoID1 == geoID2 or distance > MAX_DISTANCE or neighbor_cases == "NaN"): 
        return {}
    else:
        return {"distance":distance, "cases":neighbor_cases, "pop":neighbor_population}

# %%
print_and_log("\nCalculating local county risk")
for county in counties:
    get_county_all_neighbor_risk(county["properties"])
# Out:
# Calculating local county risk

# %% [markdown]
# ### Add in state risk

# %% [markdown]
# ####  Local State Risk

# %%
#111 is to convert degrees to kilometers
def get_distance(c0, c1):
    lat_dist = abs(c0[0])-abs(c1[0])
    lng_dist = abs(c0[1])-abs(c1[1])
    distance = 111 * math.sqrt(lat_dist**2 + lng_dist**2)
    return distance

# %%
def calc_state_local_risk(props):
    #changed from props["active"] change back when possible
    cases = props["cases"]
    population = props.get("population", -1)
    if cases == 'NaN': cases = 0
    return cases/(population/100000) if population != -1 else -1

# %%
print_and_log("Calculating local state risk")
for state in state_json["features"]:
    state["properties"]["risk_local"] = calc_state_local_risk(state["properties"])
# Out:
# Calculating local state risk

# %% [markdown]
# #### Neighbor State Risk

# %%
def get_state_all_neighbor_risk(props):
    risk_details = {}
    for state in state_json["features"]:
        neighbor_props = state["properties"]
        neighbor_risk = get_state_neighbor_risk(props, neighbor_props)
        if(neighbor_risk != {}): 
            risk_details[neighbor_props["abbr"]] = neighbor_risk
    props["risk_nearby"] = calc_state_neighbor_risk(risk_details)
    props["risk_total"] = props["risk_nearby"] + props["risk_local"]

# %%
def calc_state_neighbor_risk(risks):
    num_risks = len(risks)
    total_neighbor_risk = 0
    for risk in risks.values():
        distance, neighbor_cases, neighbor_pop = risk.values()
        total_neighbor_risk += (neighbor_cases*(2**((-distance-150)/50)))
    return total_neighbor_risk

# %%
def get_state_neighbor_risk(props, neighbor_props):
    neighbor_centroid = [neighbor_props["lat"], neighbor_props["long"]]
    #changed from props["active"] change back when possible
    neighbor_cases = neighbor_props["cases"]
    neighbor_pop = neighbor_props["population"]
    centroid = [props["lat"], props["long"]]
    distance = get_distance(centroid, neighbor_centroid)
    if(props["abbr"] == neighbor_props["abbr"] or neighbor_cases == "NaN"):
        return {}
    else:
        return {"DISTANCE":distance, "CASES":neighbor_cases, "POP":neighbor_pop}

# %%
print_and_log("Calculating neighbor state risk\n")
for state in state_json["features"]:
    get_state_all_neighbor_risk(state["properties"])
# Out:
# Calculating neighbor state risk

# %% [markdown]
# ## Add daily change to states

# %%
def get_date_string(d):
    return f"{d.month}-{d.day}-{d.year}"

# %%
today = datetime.datetime.today()
yesterday = today - datetime.timedelta(days=1)
back_0 = get_date_string(yesterday)
back_1 = get_date_string(yesterday - datetime.timedelta(days=1))
back_3 = get_date_string(yesterday - datetime.timedelta(days=3))
back_7 = get_date_string(yesterday - datetime.timedelta(days=7))

# %%
def add_change(state_or_county, feature_name, save_name):
    try:
        latest = state_or_county["properties"]["time_series"][back_0][feature_name]
    except KeyError:
        latest = 0
    try:
        minus1d = state_or_county["properties"]["time_series"][back_1][feature_name]
    except KeyError:
        minus1d = 0
    try:
        minus3d = state_or_county["properties"]["time_series"][back_3][feature_name]
    except KeyError:
        minus3d = 0 
    try:
        minus7d = state_or_county["properties"]["time_series"][back_7][feature_name]
    except KeyError:
        minus7d = 0 
        
    if(latest == 0): percent_growth1d = percent_growth3d = percent_growth7d = "N/A"
    else:
        percent_growth1d = (latest)/minus1d if minus1d != 0 else "N/A"
        percent_growth3d = ((latest)/minus3d)**(1/3) if minus3d != 0 else "N/A"
        percent_growth7d = ((latest)/minus7d)**(1/7) if minus7d != 0 else "N/A"
    state_or_county["properties"][save_name + "24hr"] = percent_growth1d
    state_or_county["properties"][save_name + "72hr"] = percent_growth3d
    state_or_county["properties"][save_name + "1w"] = percent_growth7d

# %%
for state in state_json["features"]:
    add_change(state, "cases", "growth_cases")
    add_change(state, "deaths", "growth_deaths")
    add_change(state, "test_total", "growth_tests")

# %%
for county in county_json["features"]:
    add_change(county, "cases", "growth_cases")
    add_change(county, "deaths", "growth_deaths")

# %%
county_json["features"][1441]
# Out:
# {'type': 'Feature',
#  'properties': {'geo_id': '0500000US27017',
#   'county': '017',
#   'name': 'Carlton',
#   'lsad': 'County',
#   'censusarea': 861.381,
#   'state': '27',
#   'statename': 'Minnesota',
#   'stateabbr': 'MN',
#   'population': 35837,
#   'land_area': '861.38',
#   'housing_units': '15656',
#   'population_density': 41.604170052706124,
#   'comorbid_diabetes': 12.16,
#   'comorbid_smoking': 17.27,
#   'comorbid_cancer': nan,
#   'comorbid_obesity': 35.915,
#   'comorbid_hypertension': 36.795,
#   'lat': -92.67703838784512,
#   'long': 46.592403871196595,
#   'age0-19': 8785,
#   'age20-44': 10863,
#   'age45-54': 4810,
#   'age55-64': 5243,
#   'age65-74': 3430,
#   'age75-84': 1900,
#   'age85+': 806,
#   'cases': 25,
#   'deaths': 0,
#   'active': 25,
#   'recovered': 0,
#   'time_cases_update': '4/14 11:43AM',
#   'pc_cases': 69.76030359684125,
#   'pc_deaths': 0.0,
#   'time_series': {'3-15-2020': {'cases': 0, 'deaths': None},
#    '3-17-2020': {'cases': 0, 'deaths': None},
#    '3-18-2020': {'cases': 0, 'deaths': 0},
#    '3-19-2020': {'cases': 0, 'deaths': 0},
#    '3-20-2020': {'cases': 0, 'deaths': 0},
#    '3-23-2020': {'cases': 0, 'deaths': 0},
#    '3-24-2020': {'cases': 0, 'deaths': 0},
#    '3-25-2020': {'cases': 0, 'deaths': 0},
#    '3-26-2020': {'cases': 0, 'deaths': 0},
#    '3-27-2020': {'cases': 0, 'deaths': 0},
#    '3-28-2020': {'cases': 0, 'deaths': 0},
#    '3-29-2020': {'cases': 0, 'deaths': 0},
#    '3-30-2020': {'cases': 0, 'deaths': 0},
#    '3-31-2020': {'cases': 1, 'deaths': 0},
#    '4-1-2020': {'cases': 2, 'deaths': 0},
#    '4-2-2020': {'cases': 3, 'deaths': 0},
#    '4-3-2020': {'cases': 5, 'deaths': 0},
#    '4-4-2020': {'cases': 8, 'deaths': 0},
#    '4-5-2020': {'cases': 8, 'deaths': 0},
#    '4-6-2020': {'cases': 10, 'deaths': 0},
#    '4-7-2020': {'cases': 13, 'deaths': 0},
#    '4-8-2020': {'cases': 14, 'deaths': 0},
#    '4-9-2020': {'cases': 15, 'deaths': 0},
#    '4-10-2020': {'cases': 18, 'deaths': 0},
#    '4-11-2020': {'cases': 19, 'deaths': 0},
#    '4-12-2020': {'cases': 25, 'deaths': 0},
#    '4-13-2020': {'cases': 25, 'deaths': 0},
#    '4-14-2020': {'cases': 25, 'deaths': 0}},
#   'risk_local': 69.76030359684125,
#   'risk_nearby': 11.028939074314014,
#   'risk_total': 80.78924267115526,
#   'growth_cases24hr': 1.0,
#   'growth_cases72hr': 1.1157215834702825,
#   'growth_cases1w': 1.1398522810475966,
#   'growth_deaths24hr': 'N/A',
#   'growth_deaths72hr': 'N/A',
#   'growth_deaths1w': 'N/A'},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-93.061529, 46.76655],
#     [-92.301676, 46.764134],
#     [-92.292192, 46.663242],
#     [-92.291597, 46.624941],
#     [-92.291647, 46.604649],
#     [-92.292371, 46.495585],
#     [-92.29251, 46.478761],
#     [-92.292727, 46.431993],
#     [-92.292847, 46.420876],
#     [-92.29286, 46.41722],
#     [-93.054847, 46.419269],
#     [-93.061529, 46.76655]]]}}

# %% [markdown]
# ## Add state rank data

# %%
def add_state_rank(feature_name, rank_name):
    case_num = []
    for state in state_json["features"]:
        case_num.append(state["properties"][feature_name])
    ordered = sorted(case_num, reverse=True)
    for state in state_json["features"]:
        state["properties"][rank_name] = ordered.index(state["properties"][feature_name]) + 1

# %%
add_state_rank("pc_cases", "rank_cases")
add_state_rank("pc_deaths", "rank_deaths")
add_state_rank("pc_tests", "rank_tests")
add_state_rank("risk_total", "rank_risk_total")

# %% [markdown]
# ## Add county rank data

# %%
def add_county_rank(feature_name, rank_name):
    case_num = []
    for county in county_json["features"]:
        case_num.append(county["properties"][feature_name])
    ordered = sorted(case_num, reverse=True)
    for county in county_json["features"]:
        county["properties"][rank_name] = ordered.index(county["properties"][feature_name]) + 1

# %%
def get_counties_in_state(statename):
    return list(filter(lambda x: is_in_state(x, statename), county_json["features"]))

def is_in_state(county, statename):
    return county["properties"]["statename"] == statename

# %%
def add_county_state_rank(feature_name, rank_name):
    for state in state_json["features"]:
        statename = state["properties"]["statename"]
        i = 0
        case_num = []
        counties_in_state = get_counties_in_state(statename)
        num_counties = len(counties_in_state)
        for county in counties_in_state:
            case_num.append(county["properties"][feature_name])
        ordered = sorted(case_num, reverse=True)
        for county in counties_in_state:
            county["properties"][rank_name] = ordered.index(county["properties"][feature_name]) + 1
            county["properties"]["num_counties_statewide"] = num_counties

# %%
add_county_rank("pc_cases", "rank_cases")
add_county_rank("pc_deaths", "rank_deaths")
add_county_rank("risk_total", "rank_risk_total")

# %%
add_county_state_rank("pc_cases", "rank_cases_state")
add_county_state_rank("pc_deaths", "rank_deaths_state")
add_county_state_rank("risk_total", "rank_risk_total_state")

# %%
state_json["features"][0]["properties"]
# Out:
# {'population': 4903185,
#  'beds': 19000,
#  'statename': 'Alabama',
#  'population_density': 94.65,
#  'lat': 32.78990682135675,
#  'long': -86.82778271419518,
#  'abbr': 'AL',
#  'age0-19': 1217278,
#  'age20-44': 1561062,
#  'age45-54': 627458,
#  'age55-64': 655179,
#  'age65-74': 487721,
#  'age75-84': 249308,
#  'age85+': 89865,
#  'comorbid_obesity': 36.2,
#  'comorbid_diabetes': 16.19,
#  'comorbid_cancer': 0.4578,
#  'comorbid_smoking': 17.48,
#  'comorbid_hypertension': 42.297682294263836,
#  'cases': 3809,
#  'deaths': 103,
#  'active': 3706,
#  'recovered': 0,
#  'time_cases_update': '4/14 11:43AM',
#  'time_tests_updated': '4/14 0:00AM',
#  'test_grade': 'B',
#  'test_positive': 3809,
#  'test_negative': 29241,
#  'test_total': 33050,
#  'pc_cases': 77.68419914810475,
#  'pc_active': 75.5835237707735,
#  'pc_deaths': 2.100675377331265,
#  'pc_tests': 674.0516623378478,
#  'time_series': {'3-13-2020': {'cases': 5,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 12,
#    'test_positive': 1,
#    'test_negative': 11},
#   '3-14-2020': {'cases': 6,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 74,
#    'test_positive': 6,
#    'test_negative': 22},
#   '3-15-2020': {'cases': 12,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 86,
#    'test_positive': 12,
#    'test_negative': 28},
#   '3-16-2020': {'cases': 29,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 96,
#    'test_positive': 28,
#    'test_negative': 28},
#   '3-17-2020': {'cases': 39,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 64,
#    'test_positive': 36,
#    'test_negative': 28},
#   '3-18-2020': {'cases': 46,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 74,
#    'test_positive': 46,
#    'test_negative': 28},
#   '3-19-2020': {'cases': 78,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 96,
#    'test_positive': 68,
#    'test_negative': 28},
#   '3-20-2020': {'cases': 83,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 109,
#    'test_positive': 81,
#    'test_negative': 28},
#   '3-21-2020': {'cases': 131,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 152,
#    'test_positive': 124,
#    'test_negative': 28},
#   '3-22-2020': {'cases': 157,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1602,
#    'test_positive': 138,
#    'test_negative': 1464},
#   '3-23-2020': {'cases': 196,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 1832,
#    'test_positive': 167,
#    'test_negative': 1665},
#   '3-24-2020': {'cases': 242,
#    'deaths': 0,
#    'recovered': 0,
#    'test_total': 2321,
#    'test_positive': 215,
#    'test_negative': 2106},
#   '3-25-2020': {'cases': 381,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 2812,
#    'test_positive': 283,
#    'test_negative': 2529},
#   '3-26-2020': {'cases': 517,
#    'deaths': 1,
#    'recovered': 0,
#    'test_total': 4099,
#    'test_positive': 506,
#    'test_negative': 3593},
#   '3-27-2020': {'cases': 587,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 4771,
#    'test_positive': 587,
#    'test_negative': 4184},
#   '3-28-2020': {'cases': 694,
#    'deaths': 4,
#    'recovered': 0,
#    'test_total': 4880,
#    'test_positive': 696,
#    'test_negative': 4184},
#   '3-29-2020': {'cases': 825,
#    'deaths': 10,
#    'recovered': 0,
#    'test_total': 4990,
#    'test_positive': 806,
#    'test_negative': 4184},
#   '3-30-2020': {'cases': 899,
#    'deaths': 10,
#    'recovered': 0,
#    'test_total': 6553,
#    'test_positive': 859,
#    'test_negative': 5694},
#   '3-31-2020': {'cases': 987,
#    'deaths': 23,
#    'recovered': 0,
#    'test_total': 7279,
#    'test_positive': 981,
#    'test_negative': 6298},
#   '4-1-2020': {'cases': 1060,
#    'deaths': 27,
#    'recovered': 0,
#    'test_total': 7774,
#    'test_positive': 1077,
#    'test_negative': 6697},
#   '4-2-2020': {'cases': 1233,
#    'deaths': 32,
#    'recovered': 0,
#    'test_total': 8736,
#    'test_positive': 1233,
#    'test_negative': 7503},
#   '4-3-2020': {'cases': 1495,
#    'deaths': 38,
#    'recovered': 0,
#    'test_total': 9619,
#    'test_positive': 1432,
#    'test_negative': 8187},
#   '4-4-2020': {'cases': 1614,
#    'deaths': 44,
#    'recovered': 0,
#    'test_total': 10853,
#    'test_positive': 1580,
#    'test_negative': 9273},
#   '4-5-2020': {'cases': 1765,
#    'deaths': 45,
#    'recovered': 0,
#    'test_total': 13078,
#    'test_positive': 1796,
#    'test_negative': 11282},
#   '4-6-2020': {'cases': 1952,
#    'deaths': 49,
#    'recovered': 0,
#    'test_total': 14765,
#    'test_positive': 1968,
#    'test_negative': 12797},
#   '4-7-2020': {'cases': 2169,
#    'deaths': 64,
#    'recovered': 0,
#    'test_total': 14916,
#    'test_positive': 2119,
#    'test_negative': 12797},
#   '4-8-2020': {'cases': 2328,
#    'deaths': 66,
#    'recovered': 0,
#    'test_total': 19122,
#    'test_positive': 2369,
#    'test_negative': 16753},
#   '4-9-2020': {'cases': 2703,
#    'deaths': 70,
#    'recovered': 0,
#    'test_total': 20827,
#    'test_positive': 2769,
#    'test_negative': 18058},
#   '4-10-2020': {'cases': 2947,
#    'deaths': 80,
#    'recovered': 0,
#    'test_total': 21026,
#    'test_positive': 2968,
#    'test_negative': 18058},
#   '4-11-2020': {'cases': 3217,
#    'deaths': 92,
#    'recovered': 0,
#    'test_total': 21249,
#    'test_positive': 3191,
#    'test_negative': 18058},
#   '4-12-2020': {'cases': 3563,
#    'deaths': 93,
#    'recovered': 0,
#    'test_total': 21583,
#    'test_positive': 3525,
#    'test_negative': 18058},
#   '4-13-2020': {'cases': 3734,
#    'deaths': 99,
#    'recovered': 0,
#    'test_total': 29182,
#    'test_positive': 3734,
#    'test_negative': 25448},
#   '3-12-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#   '3-11-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#   '3-10-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#   '3-9-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#   '3-8-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#   '3-7-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#   '4-14-2020': {'cases': 3809,
#    'deaths': 103,
#    'recovered': 0,
#    'test_total': 33050,
#    'test_negative': 29241,
#    'test_positive': 3809}},
#  'risk_local': 77.68419914810475,
#  'risk_nearby': 21.13386029769913,
#  'risk_total': 98.81805944580388,
#  'growth_cases24hr': 1.0479932641032836,
#  'growth_cases72hr': 1.0820933445923984,
#  'growth_cases1w': 1.0970895326563666,
#  'growth_deaths24hr': 1.064516129032258,
#  'growth_deaths72hr': 1.0736145845094707,
#  'growth_deaths1w': 1.1056919792908364,
#  'growth_tests24hr': 1.3520826576472222,
#  'growth_tests72hr': 1.1154569087017496,
#  'growth_tests1w': 1.1022213023271512,
#  'rank_cases': 24,
#  'rank_deaths': 26,
#  'rank_tests': 36,
#  'rank_risk_total': 28}

# %%
county_json["features"][0]["properties"]
# Out:
# {'geo_id': '0500000US01001',
#  'county': '001',
#  'name': 'Autauga',
#  'lsad': 'County',
#  'censusarea': 594.436,
#  'state': '01',
#  'statename': 'Alabama',
#  'stateabbr': 'AL',
#  'population': 55601,
#  'land_area': '594.44',
#  'housing_units': '22135',
#  'population_density': 93.53509185115402,
#  'comorbid_diabetes': 15.45,
#  'comorbid_smoking': 18.41,
#  'comorbid_cancer': 0.4956,
#  'comorbid_obesity': 37.945,
#  'comorbid_hypertension': 40.335,
#  'lat': -86.64274644826507,
#  'long': 32.53492681419619,
#  'age0-19': 14424,
#  'age20-44': 17583,
#  'age45-54': 7777,
#  'age55-64': 7164,
#  'age65-74': 4900,
#  'age75-84': 2882,
#  'age85+': 871,
#  'cases': 19,
#  'deaths': 1,
#  'active': 18,
#  'recovered': 0,
#  'time_cases_update': '4/14 11:43AM',
#  'pc_cases': 34.17204726533696,
#  'pc_deaths': 1.798528803438787,
#  'time_series': {'3-15-2020': {'cases': 0, 'deaths': None},
#   '3-17-2020': {'cases': 0, 'deaths': None},
#   '3-18-2020': {'cases': 0, 'deaths': 0},
#   '3-19-2020': {'cases': 0, 'deaths': 0},
#   '3-20-2020': {'cases': 0, 'deaths': 0},
#   '3-23-2020': {'cases': 0, 'deaths': 0},
#   '3-24-2020': {'cases': 1, 'deaths': 0},
#   '3-25-2020': {'cases': 4, 'deaths': 0},
#   '3-26-2020': {'cases': 6, 'deaths': 0},
#   '3-27-2020': {'cases': 6, 'deaths': 0},
#   '3-31-2020': {'cases': 7, 'deaths': 0},
#   '4-1-2020': {'cases': 8, 'deaths': 0},
#   '4-3-2020': {'cases': 12, 'deaths': 0},
#   '4-5-2020': {'cases': 12, 'deaths': 0},
#   '4-7-2020': {'cases': 12, 'deaths': 1},
#   '4-8-2020': {'cases': 12, 'deaths': 1},
#   '4-9-2020': {'cases': 15, 'deaths': 1},
#   '4-10-2020': {'cases': 17, 'deaths': 1},
#   '4-11-2020': {'cases': 19, 'deaths': 1},
#   '4-12-2020': {'cases': 19, 'deaths': 1},
#   '4-14-2020': {'cases': 19, 'deaths': 1}},
#  'risk_local': 34.17204726533696,
#  'risk_nearby': 77.10509428493054,
#  'risk_total': 111.2771415502675,
#  'growth_cases24hr': 'N/A',
#  'growth_cases72hr': 'N/A',
#  'growth_cases1w': 'N/A',
#  'growth_deaths24hr': 'N/A',
#  'growth_deaths72hr': 'N/A',
#  'growth_deaths1w': 'N/A',
#  'rank_cases': 1456,
#  'rank_deaths': 757,
#  'rank_risk_total': 1138,
#  'rank_cases_state': 55,
#  'num_counties_statewide': 67,
#  'rank_deaths_state': 20,
#  'rank_risk_total_state': 47}

# %% [markdown]
# ## View Output

# %%
county_json["features"][408]
# Out:
# {'type': 'Feature',
#  'properties': {'geo_id': '0500000US39089',
#   'county': '089',
#   'name': 'Licking',
#   'lsad': 'County',
#   'censusarea': 682.5,
#   'state': '39',
#   'statename': 'Ohio',
#   'stateabbr': 'OH',
#   'population': 175769,
#   'land_area': '682.50',
#   'housing_units': '69291',
#   'population_density': 257.5369963369963,
#   'comorbid_diabetes': 14.87,
#   'comorbid_smoking': 18.87,
#   'comorbid_cancer': 0.4763,
#   'comorbid_obesity': 38.625,
#   'comorbid_hypertension': 37.88500000000001,
#   'lat': -82.48315238695075,
#   'long': 40.09160968135006,
#   'age0-19': 45504,
#   'age20-44': 52992,
#   'age45-54': 23705,
#   'age55-64': 24662,
#   'age65-74': 17133,
#   'age75-84': 8713,
#   'age85+': 3060,
#   'cases': 86,
#   'deaths': 3,
#   'active': 83,
#   'recovered': 0,
#   'time_cases_update': '4/14 11:43AM',
#   'pc_cases': 48.927854172237424,
#   'pc_deaths': 1.706785610659445,
#   'time_series': {'3-15-2020': {'cases': 0, 'deaths': None},
#    '3-17-2020': {'cases': 0, 'deaths': None},
#    '3-18-2020': {'cases': 0, 'deaths': 0},
#    '3-19-2020': {'cases': 0, 'deaths': 0},
#    '3-20-2020': {'cases': 0, 'deaths': 0},
#    '3-23-2020': {'cases': 1, 'deaths': 0},
#    '3-24-2020': {'cases': 2, 'deaths': 0},
#    '3-25-2020': {'cases': 3, 'deaths': 0},
#    '3-26-2020': {'cases': 5, 'deaths': 0},
#    '3-27-2020': {'cases': 10, 'deaths': 0},
#    '3-28-2020': {'cases': 14, 'deaths': 0},
#    '3-29-2020': {'cases': 15, 'deaths': 0},
#    '3-30-2020': {'cases': 21, 'deaths': 0},
#    '3-31-2020': {'cases': 25, 'deaths': 0},
#    '4-1-2020': {'cases': 24, 'deaths': 0},
#    '4-2-2020': {'cases': 30, 'deaths': 0},
#    '4-3-2020': {'cases': 35, 'deaths': 1},
#    '4-4-2020': {'cases': 50, 'deaths': 1},
#    '4-5-2020': {'cases': 55, 'deaths': 2},
#    '4-6-2020': {'cases': 57, 'deaths': 2},
#    '4-7-2020': {'cases': 61, 'deaths': 3},
#    '4-8-2020': {'cases': 64, 'deaths': 3},
#    '4-9-2020': {'cases': 78, 'deaths': 3},
#    '4-10-2020': {'cases': 79, 'deaths': 3},
#    '4-11-2020': {'cases': 80, 'deaths': 3},
#    '4-12-2020': {'cases': 83, 'deaths': 3},
#    '4-13-2020': {'cases': 86, 'deaths': 3},
#    '4-14-2020': {'cases': 86, 'deaths': 3}},
#   'risk_local': 48.927854172237424,
#   'risk_nearby': 61.373145368834756,
#   'risk_total': 110.30099954107217,
#   'growth_cases24hr': 1.036144578313253,
#   'growth_cases72hr': 1.0287040586828013,
#   'growth_cases1w': 1.0605170534711181,
#   'growth_deaths24hr': 1.0,
#   'growth_deaths72hr': 1.0,
#   'growth_deaths1w': 1.0596340226670484,
#   'rank_cases': 1040,
#   'rank_deaths': 785,
#   'rank_risk_total': 1149,
#   'rank_cases_state': 24,
#   'num_counties_statewide': 88,
#   'rank_deaths_state': 32,
#   'rank_risk_total_state': 27},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-82.581813, 39.930156],
#     [-82.782495, 39.939662],
#     [-82.761827, 40.125855],
#     [-82.750747, 40.276996],
#     [-82.476114, 40.264703],
#     [-82.364344, 40.240957],
#     [-82.326025, 40.239725],
#     [-82.195911, 40.239071],
#     [-82.182823, 40.238624],
#     [-82.187105, 40.16688],
#     [-82.198772, 39.95014],
#     [-82.233974, 39.91326],
#     [-82.462813, 39.93038],
#     [-82.473423, 39.925065],
#     [-82.581813, 39.930156]]]}}

# %%
state_json["features"][0]
# Out:
# {'type': 'Feature',
#  'id': '01',
#  'properties': {'population': 4903185,
#   'beds': 19000,
#   'statename': 'Alabama',
#   'population_density': 94.65,
#   'lat': 32.78990682135675,
#   'long': -86.82778271419518,
#   'abbr': 'AL',
#   'age0-19': 1217278,
#   'age20-44': 1561062,
#   'age45-54': 627458,
#   'age55-64': 655179,
#   'age65-74': 487721,
#   'age75-84': 249308,
#   'age85+': 89865,
#   'comorbid_obesity': 36.2,
#   'comorbid_diabetes': 16.19,
#   'comorbid_cancer': 0.4578,
#   'comorbid_smoking': 17.48,
#   'comorbid_hypertension': 42.297682294263836,
#   'cases': 3809,
#   'deaths': 103,
#   'active': 3706,
#   'recovered': 0,
#   'time_cases_update': '4/14 11:43AM',
#   'time_tests_updated': '4/14 0:00AM',
#   'test_grade': 'B',
#   'test_positive': 3809,
#   'test_negative': 29241,
#   'test_total': 33050,
#   'pc_cases': 77.68419914810475,
#   'pc_active': 75.5835237707735,
#   'pc_deaths': 2.100675377331265,
#   'pc_tests': 674.0516623378478,
#   'time_series': {'3-13-2020': {'cases': 5,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 12,
#     'test_positive': 1,
#     'test_negative': 11},
#    '3-14-2020': {'cases': 6,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 74,
#     'test_positive': 6,
#     'test_negative': 22},
#    '3-15-2020': {'cases': 12,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 86,
#     'test_positive': 12,
#     'test_negative': 28},
#    '3-16-2020': {'cases': 29,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 96,
#     'test_positive': 28,
#     'test_negative': 28},
#    '3-17-2020': {'cases': 39,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 64,
#     'test_positive': 36,
#     'test_negative': 28},
#    '3-18-2020': {'cases': 46,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 74,
#     'test_positive': 46,
#     'test_negative': 28},
#    '3-19-2020': {'cases': 78,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 96,
#     'test_positive': 68,
#     'test_negative': 28},
#    '3-20-2020': {'cases': 83,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 109,
#     'test_positive': 81,
#     'test_negative': 28},
#    '3-21-2020': {'cases': 131,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 152,
#     'test_positive': 124,
#     'test_negative': 28},
#    '3-22-2020': {'cases': 157,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 1602,
#     'test_positive': 138,
#     'test_negative': 1464},
#    '3-23-2020': {'cases': 196,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 1832,
#     'test_positive': 167,
#     'test_negative': 1665},
#    '3-24-2020': {'cases': 242,
#     'deaths': 0,
#     'recovered': 0,
#     'test_total': 2321,
#     'test_positive': 215,
#     'test_negative': 2106},
#    '3-25-2020': {'cases': 381,
#     'deaths': 1,
#     'recovered': 0,
#     'test_total': 2812,
#     'test_positive': 283,
#     'test_negative': 2529},
#    '3-26-2020': {'cases': 517,
#     'deaths': 1,
#     'recovered': 0,
#     'test_total': 4099,
#     'test_positive': 506,
#     'test_negative': 3593},
#    '3-27-2020': {'cases': 587,
#     'deaths': 4,
#     'recovered': 0,
#     'test_total': 4771,
#     'test_positive': 587,
#     'test_negative': 4184},
#    '3-28-2020': {'cases': 694,
#     'deaths': 4,
#     'recovered': 0,
#     'test_total': 4880,
#     'test_positive': 696,
#     'test_negative': 4184},
#    '3-29-2020': {'cases': 825,
#     'deaths': 10,
#     'recovered': 0,
#     'test_total': 4990,
#     'test_positive': 806,
#     'test_negative': 4184},
#    '3-30-2020': {'cases': 899,
#     'deaths': 10,
#     'recovered': 0,
#     'test_total': 6553,
#     'test_positive': 859,
#     'test_negative': 5694},
#    '3-31-2020': {'cases': 987,
#     'deaths': 23,
#     'recovered': 0,
#     'test_total': 7279,
#     'test_positive': 981,
#     'test_negative': 6298},
#    '4-1-2020': {'cases': 1060,
#     'deaths': 27,
#     'recovered': 0,
#     'test_total': 7774,
#     'test_positive': 1077,
#     'test_negative': 6697},
#    '4-2-2020': {'cases': 1233,
#     'deaths': 32,
#     'recovered': 0,
#     'test_total': 8736,
#     'test_positive': 1233,
#     'test_negative': 7503},
#    '4-3-2020': {'cases': 1495,
#     'deaths': 38,
#     'recovered': 0,
#     'test_total': 9619,
#     'test_positive': 1432,
#     'test_negative': 8187},
#    '4-4-2020': {'cases': 1614,
#     'deaths': 44,
#     'recovered': 0,
#     'test_total': 10853,
#     'test_positive': 1580,
#     'test_negative': 9273},
#    '4-5-2020': {'cases': 1765,
#     'deaths': 45,
#     'recovered': 0,
#     'test_total': 13078,
#     'test_positive': 1796,
#     'test_negative': 11282},
#    '4-6-2020': {'cases': 1952,
#     'deaths': 49,
#     'recovered': 0,
#     'test_total': 14765,
#     'test_positive': 1968,
#     'test_negative': 12797},
#    '4-7-2020': {'cases': 2169,
#     'deaths': 64,
#     'recovered': 0,
#     'test_total': 14916,
#     'test_positive': 2119,
#     'test_negative': 12797},
#    '4-8-2020': {'cases': 2328,
#     'deaths': 66,
#     'recovered': 0,
#     'test_total': 19122,
#     'test_positive': 2369,
#     'test_negative': 16753},
#    '4-9-2020': {'cases': 2703,
#     'deaths': 70,
#     'recovered': 0,
#     'test_total': 20827,
#     'test_positive': 2769,
#     'test_negative': 18058},
#    '4-10-2020': {'cases': 2947,
#     'deaths': 80,
#     'recovered': 0,
#     'test_total': 21026,
#     'test_positive': 2968,
#     'test_negative': 18058},
#    '4-11-2020': {'cases': 3217,
#     'deaths': 92,
#     'recovered': 0,
#     'test_total': 21249,
#     'test_positive': 3191,
#     'test_negative': 18058},
#    '4-12-2020': {'cases': 3563,
#     'deaths': 93,
#     'recovered': 0,
#     'test_total': 21583,
#     'test_positive': 3525,
#     'test_negative': 18058},
#    '4-13-2020': {'cases': 3734,
#     'deaths': 99,
#     'recovered': 0,
#     'test_total': 29182,
#     'test_positive': 3734,
#     'test_negative': 25448},
#    '3-12-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#    '3-11-2020': {'test_total': 10, 'test_positive': 0, 'test_negative': 10},
#    '3-10-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#    '3-9-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#    '3-8-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#    '3-7-2020': {'test_total': 0, 'test_positive': 0, 'test_negative': 0},
#    '4-14-2020': {'cases': 3809,
#     'deaths': 103,
#     'recovered': 0,
#     'test_total': 33050,
#     'test_negative': 29241,
#     'test_positive': 3809}},
#   'risk_local': 77.68419914810475,
#   'risk_nearby': 21.13386029769913,
#   'risk_total': 98.81805944580388,
#   'growth_cases24hr': 1.0479932641032836,
#   'growth_cases72hr': 1.0820933445923984,
#   'growth_cases1w': 1.0970895326563666,
#   'growth_deaths24hr': 1.064516129032258,
#   'growth_deaths72hr': 1.0736145845094707,
#   'growth_deaths1w': 1.1056919792908364,
#   'growth_tests24hr': 1.3520826576472222,
#   'growth_tests72hr': 1.1154569087017496,
#   'growth_tests1w': 1.1022213023271512,
#   'rank_cases': 24,
#   'rank_deaths': 26,
#   'rank_tests': 36,
#   'rank_risk_total': 28},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-87.359296, 35.00118],
#     [-85.606675, 34.984749],
#     [-85.431413, 34.124869],
#     [-85.184951, 32.859696],
#     [-85.069935, 32.580372],
#     [-84.960397, 32.421541],
#     [-85.004212, 32.322956],
#     [-84.889196, 32.262709],
#     [-85.058981, 32.13674],
#     [-85.053504, 32.01077],
#     [-85.141136, 31.840985],
#     [-85.042551, 31.539753],
#     [-85.113751, 31.27686],
#     [-85.004212, 31.003013],
#     [-85.497137, 30.997536],
#     [-87.600282, 30.997536],
#     [-87.633143, 30.86609],
#     [-87.408589, 30.674397],
#     [-87.446927, 30.510088],
#     [-87.37025, 30.427934],
#     [-87.518128, 30.280057],
#     [-87.655051, 30.247195],
#     [-87.90699, 30.411504],
#     [-87.934375, 30.657966],
#     [-88.011052, 30.685351],
#     [-88.10416, 30.499135],
#     [-88.137022, 30.318396],
#     [-88.394438, 30.367688],
#     [-88.471115, 31.895754],
#     [-88.241084, 33.796253],
#     [-88.098683, 34.891641],
#     [-88.202745, 34.995703],
#     [-87.359296, 35.00118]]]}}

# %%
for county in county_json["features"]:
    if county["properties"]["geo_id"] == "0500000US36061": 
        for k, v in county["properties"]["time_series"].items():
            print(k,v)
# Out:
# 3-13-2020 {'cases': 38, 'deaths': 0}
# 3-14-2020 {'cases': 66, 'deaths': 1}
# 3-15-2020 {'cases': 81, 'deaths': 5}
# 3-17-2020 {'cases': 159, 'deaths': 10}
# 3-18-2020 {'cases': 330, 'deaths': 20}
# 3-19-2020 {'cases': 608, 'deaths': 22}
# 3-20-2020 {'cases': 1086, 'deaths': 26}
# 3-23-2020 {'cases': 2646, 'deaths': 17}
# 3-24-2020 {'cases': 3013, 'deaths': 19}
# 3-25-2020 {'cases': 3616, 'deaths': 30}
# 3-26-2020 {'cases': 4046, 'deaths': 43}
# 3-27-2020 {'cases': 4627, 'deaths': 55}
# 3-28-2020 {'cases': 5237, 'deaths': 65}
# 3-29-2020 {'cases': 5582, 'deaths': 93}
# 3-30-2020 {'cases': 6060, 'deaths': 103}
# 3-31-2020 {'cases': 6539, 'deaths': 119}
# 4-1-2020 {'cases': 7022, 'deaths': 132}
# 4-2-2020 {'cases': 7398, 'deaths': 165}
# 4-3-2020 {'cases': 8222, 'deaths': 179}
# 4-4-2020 {'cases': 8781, 'deaths': 217}
# 4-5-2020 {'cases': 9251, 'deaths': 264}
# 4-6-2020 {'cases': 9624, 'deaths': 277}
# 4-7-2020 {'cases': 10098, 'deaths': 348}
# 4-8-2020 {'cases': 10642, 'deaths': 389}
# 4-9-2020 {'cases': 11244, 'deaths': 554}
# 4-10-2020 {'cases': 12088, 'deaths': 629}
# 4-11-2020 {'cases': 12391, 'deaths': 662}
# 4-12-2020 {'cases': 13280, 'deaths': 710}
# 4-13-2020 {'cases': 13705, 'deaths': 710}
# 3-16-2020 {'cases': 114, 'deaths': 7}
# 3-21-2020 {'cases': 1531, 'deaths': 60}
# 3-22-2020 {'deaths': 17, 'cases': 2324}
# 4-14-2020 {'cases': 15213, 'deaths': 823}

# %% [markdown]
# ## Calculate US data in total

# %%
us_json = {"properties":
                {
                    "population":0,
                    "beds":0,
                    "population_density":94,
                    "age0-19":0,
                    'age20-44': 0,
                     'age45-54': 0,
                     'age55-64': 0,
                     'age65-74': 0,
                     'age75-84': 0,
                     'age85+': 0,
                     'comorbid_obesity': 39.8,
                     'comorbid_hypertension': 33.2,
                     'comorbid_diabetes': 10.5,
                     'comorbid_cancer': .448,
                     'comorbid_smoking': 15.7,
                     'cases': 0,
                     'deaths': 0,
                     'active': 0,
                     'recovered': 0,
                     'test_grade': 'N/A',
                     'test_positive': 0,
                     'test_negative': 0,
                     'test_total': 0,
                     'risk_local':'N/A',
                     'risk_total':'N/A',
                     'risk_nearby':'N/A',
                     'rank_cases': 'N/A',
                     'rank_deaths': 'N/A',
                     'rank_tests': 'N/A',
                     'rank_risk_total': 'N/A'
                }
              
          }

# %%
summable_keys = ["population", "beds", "age0-19", "age20-44", "age45-54", "age55-64", "age65-74", "age75-84", "age85+",
                "cases", "deaths", "active", "recovered", "test_positive", "test_negative", "test_total"]
for state in state_json["features"]:
    props = state["properties"]
    if props["statename"] == "Puerto Rico": continue
    for key in summable_keys:
        us_json["properties"][key] += props[key]
    if "unassigned_cases" in props: us_json["properties"]["cases"] += props["unassigned_cases"]
    if "unassigned_deaths" in props: us_json["properties"]["deaths"] += props["unassigned_deaths"]

# %% [markdown]
# ### Add Percapita data

# %%
us_pop = us_json["properties"]["population"]
us_json["properties"]["pc_cases"] = us_json["properties"]["cases"]/(us_pop/100000)
us_json["properties"]["pc_deaths"] = us_json["properties"]["deaths"]/(us_pop/100000)
us_json["properties"]["pc_active"] = us_json["properties"]["active"]/(us_pop/100000)
us_json["properties"]["pc_tests"] = us_json["properties"]["test_total"]/(us_pop/100000)

# %% [markdown]
# ### Add time series data

# %%
us_time_series = {}
for state in state_json["features"]:
    for date, values in state["properties"]["time_series"].items():
        if not date in us_time_series:
            us_time_series[date] = defaultdict(int)
        for k, v in values.items():
            addend = v if v is not None else 0
            us_time_series[date][k] += addend

# %%
us_json["properties"]["time_series"] = us_time_series

# %%
state["properties"]["time_series"]
# Out:
# {'3-14-2020': {'cases': 3, 'deaths': 0, 'recovered': 0},
#  '3-15-2020': {'cases': 5, 'deaths': 0, 'recovered': 0},
#  '3-16-2020': {'cases': 5,
#   'deaths': 0,
#   'recovered': 0,
#   'test_total': 14,
#   'test_positive': 5,
#   'test_negative': 9},
#  '3-17-2020': {'cases': 5,
#   'deaths': 0,
#   'recovered': 0,
#   'test_total': 22,
#   'test_positive': 5,
#   'test_negative': 13},
#  '3-18-2020': {'cases': 5,
#   'deaths': 0,
#   'recovered': 0,
#   'test_total': 57,
#   'test_positive': 5,
#   'test_negative': 31},
#  '3-19-2020': {'cases': 5,
#   'deaths': 0,
#   'recovered': 0,
#   'test_total': 90,
#   'test_positive': 5,
#   'test_negative': 56},
#  '3-20-2020': {'cases': 14,
#   'deaths': 0,
#   'recovered': 0,
#   'test_total': 180,
#   'test_positive': 14,
#   'test_negative': 114},
#  '3-21-2020': {'cases': 21,
#   'deaths': 1,
#   'recovered': 0,
#   'test_total': 235,
#   'test_positive': 21,
#   'test_negative': 143},
#  '3-22-2020': {'cases': 23,
#   'deaths': 1,
#   'recovered': 0,
#   'test_total': 275,
#   'test_positive': 23,
#   'test_negative': 183},
#  '3-23-2020': {'cases': 31,
#   'deaths': 2,
#   'recovered': 0,
#   'test_total': 255,
#   'test_positive': 31,
#   'test_negative': 189},
#  '3-24-2020': {'cases': 39,
#   'deaths': 2,
#   'recovered': 0,
#   'test_total': 349,
#   'test_positive': 39,
#   'test_negative': 268},
#  '3-25-2020': {'cases': 51,
#   'deaths': 2,
#   'recovered': 0,
#   'test_total': 438,
#   'test_positive': 51,
#   'test_negative': 317},
#  '3-26-2020': {'cases': 64,
#   'deaths': 2,
#   'recovered': 0,
#   'test_total': 776,
#   'test_positive': 64,
#   'test_negative': 377},
#  '3-27-2020': {'cases': 79,
#   'deaths': 3,
#   'recovered': 0,
#   'test_total': 932,
#   'test_positive': 79,
#   'test_negative': 519},
#  '3-28-2020': {'cases': 100,
#   'deaths': 3,
#   'recovered': 0,
#   'test_total': 1631,
#   'test_positive': 100,
#   'test_negative': 739},
#  '3-29-2020': {'cases': 127,
#   'deaths': 3,
#   'recovered': 0,
#   'test_total': 1785,
#   'test_positive': 127,
#   'test_negative': 841},
#  '3-30-2020': {'cases': 174,
#   'deaths': 6,
#   'recovered': 0,
#   'test_total': 1899,
#   'test_positive': 174,
#   'test_negative': 931},
#  '3-31-2020': {'cases': 239,
#   'deaths': 8,
#   'recovered': 0,
#   'test_total': 2288,
#   'test_positive': 239,
#   'test_negative': 1195},
#  '4-1-2020': {'cases': 286,
#   'deaths': 11,
#   'recovered': 0,
#   'test_total': 2592,
#   'test_positive': 286,
#   'test_negative': 1409},
#  '4-2-2020': {'cases': 316,
#   'deaths': 12,
#   'recovered': 0,
#   'test_total': 3039,
#   'test_positive': 316,
#   'test_negative': 1604},
#  '4-3-2020': {'cases': 316,
#   'deaths': 15,
#   'recovered': 0,
#   'test_total': 3482,
#   'test_positive': 378,
#   'test_negative': 2049},
#  '4-4-2020': {'cases': 452,
#   'deaths': 18,
#   'recovered': 0,
#   'test_total': 4186,
#   'test_positive': 452,
#   'test_negative': 2605},
#  '4-5-2020': {'cases': 475,
#   'deaths': 20,
#   'recovered': 0,
#   'test_total': 4587,
#   'test_positive': 475,
#   'test_negative': 3073},
#  '4-6-2020': {'cases': 513,
#   'deaths': 21,
#   'recovered': 0,
#   'test_total': 4945,
#   'test_positive': 513,
#   'test_negative': 3432},
#  '4-7-2020': {'cases': 573,
#   'deaths': 23,
#   'recovered': 0,
#   'test_total': 5507,
#   'test_positive': 573,
#   'test_negative': 3966},
#  '4-8-2020': {'cases': 620,
#   'deaths': 24,
#   'recovered': 0,
#   'test_total': 6046,
#   'test_positive': 620,
#   'test_negative': 4266},
#  '4-9-2020': {'cases': 683,
#   'deaths': 33,
#   'recovered': 0,
#   'test_total': 6690,
#   'test_positive': 683,
#   'test_negative': 4703},
#  '4-10-2020': {'cases': 725,
#   'deaths': 39,
#   'recovered': 0,
#   'test_total': 7238,
#   'test_positive': 725,
#   'test_negative': 5121},
#  '4-11-2020': {'cases': 788,
#   'deaths': 42,
#   'recovered': 0,
#   'test_total': 7703,
#   'test_positive': 788,
#   'test_negative': 5583},
#  '4-12-2020': {'cases': 897,
#   'deaths': 44,
#   'recovered': 0,
#   'test_total': 7967,
#   'test_positive': 897,
#   'test_negative': 5819},
#  '4-13-2020': {'cases': 903,
#   'deaths': 45,
#   'recovered': 0,
#   'test_total': 8151,
#   'test_positive': 903,
#   'test_negative': 5960},
#  '4-14-2020': {'cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'test_total': 8529,
#   'test_negative': 6284,
#   'test_positive': 923}}

# %%
us_json
# Out:
# {'properties': {'population': 328300544,
#   'beds': 1007169,
#   'population_density': 94,
#   'age0-19': 81982665,
#   'age20-44': 108849241,
#   'age45-54': 41631699,
#   'age55-64': 42272636,
#   'age65-74': 30492316,
#   'age75-84': 15394374,
#   'age85+': 6544503,
#   'comorbid_obesity': 39.8,
#   'comorbid_hypertension': 33.2,
#   'comorbid_diabetes': 10.5,
#   'comorbid_cancer': 0.448,
#   'comorbid_smoking': 15.7,
#   'cases': 587825,
#   'deaths': 23543,
#   'active': 559260,
#   'recovered': 0,
#   'test_grade': 'N/A',
#   'test_positive': 578268,
#   'test_negative': 2386367,
#   'test_total': 2979840,
#   'risk_local': 'N/A',
#   'risk_total': 'N/A',
#   'risk_nearby': 'N/A',
#   'rank_cases': 'N/A',
#   'rank_deaths': 'N/A',
#   'rank_tests': 'N/A',
#   'rank_risk_total': 'N/A',
#   'pc_cases': 179.0508760168244,
#   'pc_deaths': 7.1711730090828,
#   'pc_active': 170.3500070959371,
#   'pc_tests': 907.656126210988,
#   'time_series': {'3-13-2020': defaultdict(int,
#                {'cases': 2112,
#                 'deaths': 47,
#                 'recovered': 12,
#                 'test_total': 17838,
#                 'test_positive': 3095,
#                 'test_negative': 13613}),
#    '3-14-2020': defaultdict(int,
#                {'cases': 2658,
#                 'deaths': 54,
#                 'recovered': 12,
#                 'test_total': 22184,
#                 'test_positive': 3846,
#                 'test_negative': 17102}),
#    '3-15-2020': defaultdict(int,
#                {'cases': 3428,
#                 'deaths': 63,
#                 'recovered': 12,
#                 'test_total': 29768,
#                 'test_positive': 4902,
#                 'test_negative': 22624}),
#    '3-16-2020': defaultdict(int,
#                {'cases': 4561,
#                 'deaths': 85,
#                 'recovered': 17,
#                 'test_total': 43950,
#                 'test_positive': 6178,
#                 'test_negative': 36081}),
#    '3-17-2020': defaultdict(int,
#                {'cases': 6348,
#                 'deaths': 108,
#                 'recovered': 17,
#                 'test_total': 58058,
#                 'test_positive': 8359,
#                 'test_negative': 48012}),
#    '3-18-2020': defaultdict(int,
#                {'cases': 7708,
#                 'deaths': 118,
#                 'recovered': 0,
#                 'test_total': 80566,
#                 'test_positive': 10929,
#                 'test_negative': 67111}),
#    '3-19-2020': defaultdict(int,
#                {'cases': 13593,
#                 'deaths': 200,
#                 'recovered': 0,
#                 'test_total': 107005,
#                 'test_positive': 15119,
#                 'test_negative': 88870}),
#    '3-20-2020': defaultdict(int,
#                {'cases': 19011,
#                 'deaths': 244,
#                 'recovered': 0,
#                 'test_total': 143105,
#                 'test_positive': 20891,
#                 'test_negative': 118884}),
#    '3-21-2020': defaultdict(int,
#                {'cases': 25420,
#                 'deaths': 307,
#                 'recovered': 0,
#                 'test_total': 188310,
#                 'test_positive': 27414,
#                 'test_negative': 157428}),
#    '3-22-2020': defaultdict(int,
#                {'cases': 33732,
#                 'deaths': 425,
#                 'recovered': 0,
#                 'test_total': 234180,
#                 'test_positive': 36358,
#                 'test_negative': 194980}),
#    '3-23-2020': defaultdict(int,
#                {'cases': 43550,
#                 'deaths': 550,
#                 'recovered': 0,
#                 'test_total': 301590,
#                 'test_positive': 47020,
#                 'test_negative': 239999}),
#    '3-24-2020': defaultdict(int,
#                {'cases': 53610,
#                 'deaths': 704,
#                 'recovered': 0,
#                 'test_total': 367992,
#                 'test_positive': 57175,
#                 'test_negative': 296384}),
#    '3-25-2020': defaultdict(int,
#                {'cases': 65647,
#                 'deaths': 940,
#                 'recovered': 0,
#                 'test_total': 483590,
#                 'test_positive': 69454,
#                 'test_negative': 362903}),
#    '3-26-2020': defaultdict(int,
#                {'cases': 83697,
#                 'deaths': 1207,
#                 'recovered': 0,
#                 'test_total': 588961,
#                 'test_positive': 86749,
#                 'test_negative': 441963}),
#    '3-27-2020': defaultdict(int,
#                {'cases': 101510,
#                 'deaths': 1577,
#                 'recovered': 0,
#                 'test_total': 699398,
#                 'test_positive': 105414,
#                 'test_negative': 533895}),
#    '3-28-2020': defaultdict(int,
#                {'cases': 121236,
#                 'deaths': 2022,
#                 'recovered': 0,
#                 'test_total': 812833,
#                 'test_positive': 124805,
#                 'test_negative': 622374}),
#    '3-29-2020': defaultdict(int,
#                {'cases': 140678,
#                 'deaths': 2463,
#                 'recovered': 0,
#                 'test_total': 905719,
#                 'test_positive': 144296,
#                 'test_negative': 695915}),
#    '3-30-2020': defaultdict(int,
#                {'cases': 161591,
#                 'deaths': 2974,
#                 'recovered': 0,
#                 'test_total': 1024170,
#                 'test_positive': 165507,
#                 'test_negative': 793318}),
#    '3-31-2020': defaultdict(int,
#                {'cases': 187919,
#                 'deaths': 3868,
#                 'recovered': 0,
#                 'test_total': 1125256,
#                 'test_positive': 189977,
#                 'test_negative': 875787}),
#    '4-1-2020': defaultdict(int,
#                {'cases': 213107,
#                 'deaths': 4750,
#                 'recovered': 0,
#                 'test_total': 1228837,
#                 'test_positive': 215216,
#                 'test_negative': 953982}),
#    '4-2-2020': defaultdict(int,
#                {'cases': 243329,
#                 'deaths': 5919,
#                 'recovered': 0,
#                 'test_total': 1353112,
#                 'test_positive': 243280,
#                 'test_negative': 1047791}),
#    '4-3-2020': defaultdict(int,
#                {'cases': 275305,
#                 'deaths': 7079,
#                 'recovered': 0,
#                 'test_total': 1484961,
#                 'test_positive': 275327,
#                 'test_negative': 1147726}),
#    '4-4-2020': defaultdict(int,
#                {'cases': 308560,
#                 'deaths': 8399,
#                 'recovered': 0,
#                 'test_total': 1667782,
#                 'test_positive': 308852,
#                 'test_negative': 1343415}),
#    '4-5-2020': defaultdict(int,
#                {'cases': 336758,
#                 'deaths': 9610,
#                 'recovered': 0,
#                 'test_total': 1792079,
#                 'test_positive': 334805,
#                 'test_negative': 1440001}),
#    '4-6-2020': defaultdict(int,
#                {'cases': 366351,
#                 'deaths': 10774,
#                 'recovered': 0,
#                 'test_total': 1941275,
#                 'test_positive': 363555,
#                 'test_negative': 1560469}),
#    '4-7-2020': defaultdict(int,
#                {'cases': 395899,
#                 'deaths': 12712,
#                 'recovered': 0,
#                 'test_total': 2088615,
#                 'test_positive': 393984,
#                 'test_negative': 1678105}),
#    '4-8-2020': defaultdict(int,
#                {'cases': 428723,
#                 'deaths': 14685,
#                 'recovered': 0,
#                 'test_total': 2228724,
#                 'test_positive': 424108,
#                 'test_negative': 1787443}),
#    '4-9-2020': defaultdict(int,
#                {'cases': 461101,
#                 'deaths': 16468,
#                 'recovered': 0,
#                 'test_total': 2391865,
#                 'test_positive': 458450,
#                 'test_negative': 1915846}),
#    '4-10-2020': defaultdict(int,
#                {'cases': 496192,
#                 'deaths': 18576,
#                 'recovered': 0,
#                 'test_total': 2545505,
#                 'test_positive': 493061,
#                 'test_negative': 2035065}),
#    '4-11-2020': defaultdict(int,
#                {'cases': 526049,
#                 'deaths': 20452,
#                 'recovered': 0,
#                 'test_total': 2681011,
#                 'test_positive': 522648,
#                 'test_negative': 2141801}),
#    '4-12-2020': defaultdict(int,
#                {'cases': 554966,
#                 'deaths': 22012,
#                 'recovered': 0,
#                 'test_total': 2821063,
#                 'test_positive': 551631,
#                 'test_negative': 2253044}),
#    '4-13-2020': defaultdict(int,
#                {'cases': 580272,
#                 'deaths': 23521,
#                 'recovered': 0,
#                 'test_total': 2950835,
#                 'test_positive': 576577,
#                 'test_negative': 2357110}),
#    '3-12-2020': defaultdict(int,
#                {'test_total': 10935,
#                 'test_positive': 2221,
#                 'test_negative': 8041,
#                 'cases': 1596,
#                 'deaths': 40,
#                 'recovered': 12}),
#    '3-11-2020': defaultdict(int,
#                {'test_total': 8426,
#                 'test_positive': 1757,
#                 'test_negative': 6106,
#                 'cases': 1214,
#                 'deaths': 36,
#                 'recovered': 8}),
#    '3-10-2020': defaultdict(int,
#                {'test_total': 5646,
#                 'test_positive': 1365,
#                 'test_negative': 3812,
#                 'cases': 892,
#                 'deaths': 28,
#                 'recovered': 8}),
#    '3-9-2020': defaultdict(int,
#                {'test_total': 4705,
#                 'test_positive': 1048,
#                 'test_negative': 3344,
#                 'cases': 539,
#                 'deaths': 22,
#                 'recovered': 8}),
#    '3-8-2020': defaultdict(int,
#                {'test_total': 3413,
#                 'test_positive': 731,
#                 'test_negative': 2335,
#                 'cases': 471,
#                 'deaths': 21,
#                 'recovered': 8}),
#    '3-7-2020': defaultdict(int,
#                {'test_total': 2991,
#                 'test_positive': 550,
#                 'test_negative': 1839,
#                 'cases': 351,
#                 'deaths': 17,
#                 'recovered': 8}),
#    '4-14-2020': defaultdict(int,
#                {'cases': 582803,
#                 'deaths': 23543,
#                 'recovered': 0,
#                 'test_total': 2988369,
#                 'test_negative': 2392651,
#                 'test_positive': 579191}),
#    '3-6-2020': defaultdict(int,
#                {'test_total': 2440,
#                 'test_positive': 394,
#                 'test_negative': 1588,
#                 'cases': 233,
#                 'deaths': 14,
#                 'recovered': 8}),
#    '1-26-2020': defaultdict(int, {'cases': 5, 'deaths': 0, 'recovered': 0}),
#    '1-27-2020': defaultdict(int, {'cases': 5, 'deaths': 0, 'recovered': 0}),
#    '1-28-2020': defaultdict(int, {'cases': 5, 'deaths': 0, 'recovered': 0}),
#    '1-29-2020': defaultdict(int, {'cases': 5, 'deaths': 0, 'recovered': 0}),
#    '1-30-2020': defaultdict(int, {'cases': 5, 'deaths': 0, 'recovered': 0}),
#    '1-31-2020': defaultdict(int, {'cases': 6, 'deaths': 0, 'recovered': 0}),
#    '2-1-2020': defaultdict(int, {'cases': 8, 'deaths': 0, 'recovered': 0}),
#    '2-2-2020': defaultdict(int, {'cases': 8, 'deaths': 0, 'recovered': 0}),
#    '2-3-2020': defaultdict(int, {'cases': 11, 'deaths': 0, 'recovered': 0}),
#    '2-4-2020': defaultdict(int, {'cases': 11, 'deaths': 0, 'recovered': 0}),
#    '2-5-2020': defaultdict(int, {'cases': 12, 'deaths': 0, 'recovered': 0}),
#    '2-6-2020': defaultdict(int, {'cases': 12, 'deaths': 0, 'recovered': 0}),
#    '2-7-2020': defaultdict(int, {'cases': 12, 'deaths': 0, 'recovered': 0}),
#    '2-8-2020': defaultdict(int, {'cases': 12, 'deaths': 0, 'recovered': 0}),
#    '2-9-2020': defaultdict(int, {'cases': 12, 'deaths': 0, 'recovered': 3}),
#    '2-10-2020': defaultdict(int, {'cases': 12, 'deaths': 0, 'recovered': 3}),
#    '2-11-2020': defaultdict(int, {'cases': 13, 'deaths': 0, 'recovered': 3}),
#    '2-12-2020': defaultdict(int, {'cases': 13, 'deaths': 0, 'recovered': 3}),
#    '2-13-2020': defaultdict(int, {'cases': 15, 'deaths': 0, 'recovered': 3}),
#    '2-14-2020': defaultdict(int, {'cases': 15, 'deaths': 0, 'recovered': 3}),
#    '2-15-2020': defaultdict(int, {'cases': 15, 'deaths': 0, 'recovered': 3}),
#    '2-16-2020': defaultdict(int, {'cases': 15, 'deaths': 0, 'recovered': 3}),
#    '2-17-2020': defaultdict(int, {'cases': 15, 'deaths': 0, 'recovered': 3}),
#    '2-18-2020': defaultdict(int, {'cases': 15, 'deaths': 0, 'recovered': 3}),
#    '2-19-2020': defaultdict(int, {'cases': 15, 'deaths': 0, 'recovered': 3}),
#    '2-20-2020': defaultdict(int, {'cases': 15, 'deaths': 0, 'recovered': 3}),
#    '2-21-2020': defaultdict(int, {'cases': 35, 'deaths': 0, 'recovered': 5}),
#    '2-22-2020': defaultdict(int, {'cases': 35, 'deaths': 0, 'recovered': 5}),
#    '2-23-2020': defaultdict(int, {'cases': 35, 'deaths': 0, 'recovered': 5}),
#    '2-24-2020': defaultdict(int, {'cases': 17, 'deaths': 0, 'recovered': 5}),
#    '2-25-2020': defaultdict(int, {'cases': 17, 'deaths': 0, 'recovered': 6}),
#    '2-26-2020': defaultdict(int, {'cases': 17, 'deaths': 0, 'recovered': 6}),
#    '2-27-2020': defaultdict(int, {'cases': 18, 'deaths': 0, 'recovered': 6}),
#    '2-28-2020': defaultdict(int,
#                {'cases': 18,
#                 'deaths': 0,
#                 'recovered': 7,
#                 'test_total': 9,
#                 'test_positive': 9,
#                 'test_negative': 0}),
#    '2-29-2020': defaultdict(int,
#                {'cases': 26,
#                 'deaths': 1,
#                 'recovered': 7,
#                 'test_total': 18,
#                 'test_positive': 18,
#                 'test_negative': 0}),
#    '3-1-2020': defaultdict(int,
#                {'cases': 32,
#                 'deaths': 1,
#                 'recovered': 7,
#                 'test_total': 40,
#                 'test_positive': 40,
#                 'test_negative': 0}),
#    '3-2-2020': defaultdict(int,
#                {'cases': 56,
#                 'deaths': 6,
#                 'recovered': 7,
#                 'test_total': 53,
#                 'test_positive': 53,
#                 'test_negative': 0}),
#    '3-3-2020': defaultdict(int,
#                {'cases': 77,
#                 'deaths': 7,
#                 'recovered': 8,
#                 'test_total': 100,
#                 'test_positive': 94,
#                 'test_negative': 6}),
#    '3-4-2020': defaultdict(int,
#                {'cases': 108,
#                 'deaths': 11,
#                 'recovered': 8,
#                 'test_total': 1071,
#                 'test_positive': 209,
#                 'test_negative': 759}),
#    '3-5-2020': defaultdict(int,
#                {'cases': 176,
#                 'deaths': 12,
#                 'recovered': 8,
#                 'test_total': 1443,
#                 'test_positive': 276,
#                 'test_negative': 970}),
#    '1-24-2020': defaultdict(int, {'cases': 2, 'deaths': 0, 'recovered': 0}),
#    '1-25-2020': defaultdict(int, {'cases': 2, 'deaths': 0, 'recovered': 0}),
#    '1-22-2020': defaultdict(int, {'cases': 1, 'deaths': 0, 'recovered': 0}),
#    '1-23-2020': defaultdict(int, {'cases': 1, 'deaths': 0, 'recovered': 0})}}}

# %% [markdown]
# ### Add in daily changes in cases/deaths

# %%
add_change(us_json, "cases", "growth_cases")
add_change(us_json, "deaths", "growth_deaths")

# %% [markdown]
# ## Export

# %%
print_and_log("Exporting Files")
# this just makes sure we dont have any encoding problems, taken from stackoverflow
class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(NpEncoder, self).default(obj)

with open("states.json", 'w') as f:
    json.dump(state_json, f, cls=NpEncoder)

with open("stateData.js", 'w') as f:
    f.write("let stateData = ")
    json.dump(state_json, f, cls=NpEncoder)
    
with open("USData.js", 'w') as f:
    f.write("let USData = ")
    json.dump(us_json, f, cls=NpEncoder)    
    
with open("counties.json", 'w') as f:
    json.dump(county_json, f, cls=NpEncoder)

with open("countyData.js", 'w') as f:
    f.write("let countyData = ")
    json.dump(county_json, f, cls=NpEncoder)
# Out:
# Exporting Files

# %%
live_path = Path("/var/www/html/data")
test_path = Path("../data")
if(live_path.exists()):
    print_and_log("Copying data to the /var/www/html")
    shutil.copy("stateData.js", live_path/"stateData.js")
    shutil.copy("countyData.js", live_path/"countyData.js")
    shutil.copy("USData.js", live_path/"USData.js")
    shutil.copy("counties.json", live_path/"counties.json")
    shutil.copy("states.json", live_path/"states.json")
    print_and_log("Data successfully copied to live path")
else:
    print_and_log(f"{live_path} not found, NOT COPYING DATA")
    if(test_path.exists()):
        print_and_log("Copying data to the test path")
        shutil.copy("stateData.js", test_path/"stateData.js")
        shutil.copy("countyData.js", test_path/"countyData.js")
        shutil.copy("USData.js", test_path/"USData.js")
        print_and_log("Data successfully copied to test path")
    else:
        print_and_log(f"{test_path} test path not found, no data exported")
# Out:
# \var\www\html\data not found, NOT COPYING DATA
# Copying data to the test path
# Data successfully copied to test path

# %%
us_json
# Out:
# {'properties': {'population': 328300544,
#   'beds': 1007169,
#   'population_density': 94,
#   'age0-19': 81982665,
#   'age20-44': 108849241,
#   'age45-54': 41631699,
#   'age55-64': 42272636,
#   'age65-74': 30492316,
#   'age75-84': 15394374,
#   'age85+': 6544503,
#   'comorbid_obesity': 39.8,
#   'comorbid_hypertension': 33.2,
#   'comorbid_diabetes': 10.5,
#   'comorbid_cancer': 0.448,
#   'comorbid_smoking': 15.7,
#   'cases': 587825,
#   'deaths': 23543,
#   'active': 559260,
#   'recovered': 0,
#   'test_grade': 'N/A',
#   'test_positive': 578268,
#   'test_negative': 2386367,
#   'test_total': 2979840,
#   'risk_local': 'N/A',
#   'risk_total': 'N/A',
#   'risk_nearby': 'N/A',
#   'rank_cases': 'N/A',
#   'rank_deaths': 'N/A',
#   'rank_tests': 'N/A',
#   'rank_risk_total': 'N/A',
#   'pc_cases': 179.0508760168244,
#   'pc_deaths': 7.1711730090828,
#   'pc_active': 170.3500070959371,
#   'pc_tests': 907.656126210988,
#   'time_series': {'3-13-2020': defaultdict(int,
#                {'cases': 2112,
#                 'deaths': 47,
#                 'recovered': 12,
#                 'test_total': 17838,
#                 'test_positive': 3095,
#                 'test_negative': 13613}),
#    '3-14-2020': defaultdict(int,
#                {'cases': 2658,
#                 'deaths': 54,
#                 'recovered': 12,
#                 'test_total': 22184,
#                 'test_positive': 3846,
#                 'test_negative': 17102}),
#    '3-15-2020': defaultdict(int,
#                {'cases': 3428,
#                 'deaths': 63,
#                 'recovered': 12,
#                 'test_total': 29768,
#                 'test_positive': 4902,
#                 'test_negative': 22624}),
#    '3-16-2020': defaultdict(int,
#                {'cases': 4561,
#                 'deaths': 85,
#                 'recovered': 17,
#                 'test_total': 43950,
#                 'test_positive': 6178,
#                 'test_negative': 36081}),
#    '3-17-2020': defaultdict(int,
#                {'cases': 6348,
#                 'deaths': 108,
#                 'recovered': 17,
#                 'test_total': 58058,
#                 'test_positive': 8359,
#                 'test_negative': 48012}),
#    '3-18-2020': defaultdict(int,
#                {'cases': 7708,
#                 'deaths': 118,
#                 'recovered': 0,
#                 'test_total': 80566,
#                 'test_positive': 10929,
#                 'test_negative': 67111}),
#    '3-19-2020': defaultdict(int,
#                {'cases': 13593,
#                 'deaths': 200,
#                 'recovered': 0,
#                 'test_total': 107005,
#                 'test_positive': 15119,
#                 'test_negative': 88870}),
#    '3-20-2020': defaultdict(int,
#                {'cases': 19011,
#                 'deaths': 244,
#                 'recovered': 0,
#                 'test_total': 143105,
#                 'test_positive': 20891,
#                 'test_negative': 118884}),
#    '3-21-2020': defaultdict(int,
#                {'cases': 25420,
#                 'deaths': 307,
#                 'recovered': 0,
#                 'test_total': 188310,
#                 'test_positive': 27414,
#                 'test_negative': 157428}),
#    '3-22-2020': defaultdict(int,
#                {'cases': 33732,
#                 'deaths': 425,
#                 'recovered': 0,
#                 'test_total': 234180,
#                 'test_positive': 36358,
#                 'test_negative': 194980}),
#    '3-23-2020': defaultdict(int,
#                {'cases': 43550,
#                 'deaths': 550,
#                 'recovered': 0,
#                 'test_total': 301590,
#                 'test_positive': 47020,
#                 'test_negative': 239999}),
#    '3-24-2020': defaultdict(int,
#                {'cases': 53610,
#                 'deaths': 704,
#                 'recovered': 0,
#                 'test_total': 367992,
#                 'test_positive': 57175,
#                 'test_negative': 296384}),
#    '3-25-2020': defaultdict(int,
#                {'cases': 65647,
#                 'deaths': 940,
#                 'recovered': 0,
#                 'test_total': 483590,
#                 'test_positive': 69454,
#                 'test_negative': 362903}),
#    '3-26-2020': defaultdict(int,
#                {'cases': 83697,
#                 'deaths': 1207,
#                 'recovered': 0,
#                 'test_total': 588961,
#                 'test_positive': 86749,
#                 'test_negative': 441963}),
#    '3-27-2020': defaultdict(int,
#                {'cases': 101510,
#                 'deaths': 1577,
#                 'recovered': 0,
#                 'test_total': 699398,
#                 'test_positive': 105414,
#                 'test_negative': 533895}),
#    '3-28-2020': defaultdict(int,
#                {'cases': 121236,
#                 'deaths': 2022,
#                 'recovered': 0,
#                 'test_total': 812833,
#                 'test_positive': 124805,
#                 'test_negative': 622374}),
#    '3-29-2020': defaultdict(int,
#                {'cases': 140678,
#                 'deaths': 2463,
#                 'recovered': 0,
#                 'test_total': 905719,
#                 'test_positive': 144296,
#                 'test_negative': 695915}),
#    '3-30-2020': defaultdict(int,
#                {'cases': 161591,
#                 'deaths': 2974,
#                 'recovered': 0,
#                 'test_total': 1024170,
#                 'test_positive': 165507,
#                 'test_negative': 793318}),
#    '3-31-2020': defaultdict(int,
#                {'cases': 187919,
#                 'deaths': 3868,
#                 'recovered': 0,
#                 'test_total': 1125256,
#                 'test_positive': 189977,
#                 'test_negative': 875787}),
#    '4-1-2020': defaultdict(int,
#                {'cases': 213107,
#                 'deaths': 4750,
#                 'recovered': 0,
#                 'test_total': 1228837,
#                 'test_positive': 215216,
#                 'test_negative': 953982}),
#    '4-2-2020': defaultdict(int,
#                {'cases': 243329,
#                 'deaths': 5919,
#                 'recovered': 0,
#                 'test_total': 1353112,
#                 'test_positive': 243280,
#                 'test_negative': 1047791}),
#    '4-3-2020': defaultdict(int,
#                {'cases': 275305,
#                 'deaths': 7079,
#                 'recovered': 0,
#                 'test_total': 1484961,
#                 'test_positive': 275327,
#                 'test_negative': 1147726}),
#    '4-4-2020': defaultdict(int,
#                {'cases': 308560,
#                 'deaths': 8399,
#                 'recovered': 0,
#                 'test_total': 1667782,
#                 'test_positive': 308852,
#                 'test_negative': 1343415}),
#    '4-5-2020': defaultdict(int,
#                {'cases': 336758,
#                 'deaths': 9610,
#                 'recovered': 0,
#                 'test_total': 1792079,
#                 'test_positive': 334805,
#                 'test_negative': 1440001}),
#    '4-6-2020': defaultdict(int,
#                {'cases': 366351,
#                 'deaths': 10774,
#                 'recovered': 0,
#                 'test_total': 1941275,
#                 'test_positive': 363555,
#                 'test_negative': 1560469}),
#    '4-7-2020': defaultdict(int,
#                {'cases': 395899,
#                 'deaths': 12712,
#                 'recovered': 0,
#                 'test_total': 2088615,
#                 'test_positive': 393984,
#                 'test_negative': 1678105}),
#    '4-8-2020': defaultdict(int,
#                {'cases': 428723,
#                 'deaths': 14685,
#                 'recovered': 0,
#                 'test_total': 2228724,
#                 'test_positive': 424108,
#                 'test_negative': 1787443}),
#    '4-9-2020': defaultdict(int,
#                {'cases': 461101,
#                 'deaths': 16468,
#                 'recovered': 0,
#                 'test_total': 2391865,
#                 'test_positive': 458450,
#                 'test_negative': 1915846}),
#    '4-10-2020': defaultdict(int,
#                {'cases': 496192,
#                 'deaths': 18576,
#                 'recovered': 0,
#                 'test_total': 2545505,
#                 'test_positive': 493061,
#                 'test_negative': 2035065}),
#    '4-11-2020': defaultdict(int,
#                {'cases': 526049,
#                 'deaths': 20452,
#                 'recovered': 0,
#                 'test_total': 2681011,
#                 'test_positive': 522648,
#                 'test_negative': 2141801}),
#    '4-12-2020': defaultdict(int,
#                {'cases': 554966,
#                 'deaths': 22012,
#                 'recovered': 0,
#                 'test_total': 2821063,
#                 'test_positive': 551631,
#                 'test_negative': 2253044}),
#    '4-13-2020': defaultdict(int,
#                {'cases': 580272,
#                 'deaths': 23521,
#                 'recovered': 0,
#                 'test_total': 2950835,
#                 'test_positive': 576577,
#                 'test_negative': 2357110}),
#    '3-12-2020': defaultdict(int,
#                {'test_total': 10935,
#                 'test_positive': 2221,
#                 'test_negative': 8041,
#                 'cases': 1596,
#                 'deaths': 40,
#                 'recovered': 12}),
#    '3-11-2020': defaultdict(int,
#                {'test_total': 8426,
#                 'test_positive': 1757,
#                 'test_negative': 6106,
#                 'cases': 1214,
#                 'deaths': 36,
#                 'recovered': 8}),
#    '3-10-2020': defaultdict(int,
#                {'test_total': 5646,
#                 'test_positive': 1365,
#                 'test_negative': 3812,
#                 'cases': 892,
#                 'deaths': 28,
#                 'recovered': 8}),
#    '3-9-2020': defaultdict(int,
#                {'test_total': 4705,
#                 'test_positive': 1048,
#                 'test_negative': 3344,
#                 'cases': 539,
#                 'deaths': 22,
#                 'recovered': 8}),
#    '3-8-2020': defaultdict(int,
#                {'test_total': 3413,
#                 'test_positive': 731,
#                 'test_negative': 2335,
#                 'cases': 471,
#                 'deaths': 21,
#                 'recovered': 8}),
#    '3-7-2020': defaultdict(int,
#                {'test_total': 2991,
#                 'test_positive': 550,
#                 'test_negative': 1839,
#                 'cases': 351,
#                 'deaths': 17,
#                 'recovered': 8}),
#    '4-14-2020': defaultdict(int,
#                {'cases': 582803,
#                 'deaths': 23543,
#                 'recovered': 0,
#                 'test_total': 2988369,
#                 'test_negative': 2392651,
#                 'test_positive': 579191}),
#    '3-6-2020': defaultdict(int,
#                {'test_total': 2440,
#                 'test_positive': 394,
#                 'test_negative': 1588,
#                 'cases': 233,
#                 'deaths': 14,
#                 'recovered': 8}),
#    '1-26-2020': defaultdict(int, {'cases': 5, 'deaths': 0, 'recovered': 0}),
#    '1-27-2020': defaultdict(int, {'cases': 5, 'deaths': 0, 'recovered': 0}),
#    '1-28-2020': defaultdict(int, {'cases': 5, 'deaths': 0, 'recovered': 0}),
#    '1-29-2020': defaultdict(int, {'cases': 5, 'deaths': 0, 'recovered': 0}),
#    '1-30-2020': defaultdict(int, {'cases': 5, 'deaths': 0, 'recovered': 0}),
#    '1-31-2020': defaultdict(int, {'cases': 6, 'deaths': 0, 'recovered': 0}),
#    '2-1-2020': defaultdict(int, {'cases': 8, 'deaths': 0, 'recovered': 0}),
#    '2-2-2020': defaultdict(int, {'cases': 8, 'deaths': 0, 'recovered': 0}),
#    '2-3-2020': defaultdict(int, {'cases': 11, 'deaths': 0, 'recovered': 0}),
#    '2-4-2020': defaultdict(int, {'cases': 11, 'deaths': 0, 'recovered': 0}),
#    '2-5-2020': defaultdict(int, {'cases': 12, 'deaths': 0, 'recovered': 0}),
#    '2-6-2020': defaultdict(int, {'cases': 12, 'deaths': 0, 'recovered': 0}),
#    '2-7-2020': defaultdict(int, {'cases': 12, 'deaths': 0, 'recovered': 0}),
#    '2-8-2020': defaultdict(int, {'cases': 12, 'deaths': 0, 'recovered': 0}),
#    '2-9-2020': defaultdict(int, {'cases': 12, 'deaths': 0, 'recovered': 3}),
#    '2-10-2020': defaultdict(int, {'cases': 12, 'deaths': 0, 'recovered': 3}),
#    '2-11-2020': defaultdict(int, {'cases': 13, 'deaths': 0, 'recovered': 3}),
#    '2-12-2020': defaultdict(int, {'cases': 13, 'deaths': 0, 'recovered': 3}),
#    '2-13-2020': defaultdict(int, {'cases': 15, 'deaths': 0, 'recovered': 3}),
#    '2-14-2020': defaultdict(int, {'cases': 15, 'deaths': 0, 'recovered': 3}),
#    '2-15-2020': defaultdict(int, {'cases': 15, 'deaths': 0, 'recovered': 3}),
#    '2-16-2020': defaultdict(int, {'cases': 15, 'deaths': 0, 'recovered': 3}),
#    '2-17-2020': defaultdict(int, {'cases': 15, 'deaths': 0, 'recovered': 3}),
#    '2-18-2020': defaultdict(int, {'cases': 15, 'deaths': 0, 'recovered': 3}),
#    '2-19-2020': defaultdict(int, {'cases': 15, 'deaths': 0, 'recovered': 3}),
#    '2-20-2020': defaultdict(int, {'cases': 15, 'deaths': 0, 'recovered': 3}),
#    '2-21-2020': defaultdict(int, {'cases': 35, 'deaths': 0, 'recovered': 5}),
#    '2-22-2020': defaultdict(int, {'cases': 35, 'deaths': 0, 'recovered': 5}),
#    '2-23-2020': defaultdict(int, {'cases': 35, 'deaths': 0, 'recovered': 5}),
#    '2-24-2020': defaultdict(int, {'cases': 17, 'deaths': 0, 'recovered': 5}),
#    '2-25-2020': defaultdict(int, {'cases': 17, 'deaths': 0, 'recovered': 6}),
#    '2-26-2020': defaultdict(int, {'cases': 17, 'deaths': 0, 'recovered': 6}),
#    '2-27-2020': defaultdict(int, {'cases': 18, 'deaths': 0, 'recovered': 6}),
#    '2-28-2020': defaultdict(int,
#                {'cases': 18,
#                 'deaths': 0,
#                 'recovered': 7,
#                 'test_total': 9,
#                 'test_positive': 9,
#                 'test_negative': 0}),
#    '2-29-2020': defaultdict(int,
#                {'cases': 26,
#                 'deaths': 1,
#                 'recovered': 7,
#                 'test_total': 18,
#                 'test_positive': 18,
#                 'test_negative': 0}),
#    '3-1-2020': defaultdict(int,
#                {'cases': 32,
#                 'deaths': 1,
#                 'recovered': 7,
#                 'test_total': 40,
#                 'test_positive': 40,
#                 'test_negative': 0}),
#    '3-2-2020': defaultdict(int,
#                {'cases': 56,
#                 'deaths': 6,
#                 'recovered': 7,
#                 'test_total': 53,
#                 'test_positive': 53,
#                 'test_negative': 0}),
#    '3-3-2020': defaultdict(int,
#                {'cases': 77,
#                 'deaths': 7,
#                 'recovered': 8,
#                 'test_total': 100,
#                 'test_positive': 94,
#                 'test_negative': 6}),
#    '3-4-2020': defaultdict(int,
#                {'cases': 108,
#                 'deaths': 11,
#                 'recovered': 8,
#                 'test_total': 1071,
#                 'test_positive': 209,
#                 'test_negative': 759}),
#    '3-5-2020': defaultdict(int,
#                {'cases': 176,
#                 'deaths': 12,
#                 'recovered': 8,
#                 'test_total': 1443,
#                 'test_positive': 276,
#                 'test_negative': 970}),
#    '1-24-2020': defaultdict(int, {'cases': 2, 'deaths': 0, 'recovered': 0}),
#    '1-25-2020': defaultdict(int, {'cases': 2, 'deaths': 0, 'recovered': 0}),
#    '1-22-2020': defaultdict(int, {'cases': 1, 'deaths': 0, 'recovered': 0}),
#    '1-23-2020': defaultdict(int, {'cases': 1, 'deaths': 0, 'recovered': 0})},
#   'growth_cases24hr': 1.0455991898602797,
#   'growth_cases72hr': 1.0535632637825476,
#   'growth_cases1w': 1.067907070517273,
#   'growth_deaths24hr': 1.068553516263856,
#   'growth_deaths72hr': 1.0818520188147496,
#   'growth_deaths1w': 1.1179949197787693}}

# %% [markdown]
# ### Keep a record of each update for future time series use

# %%
with open(f"logs/data_logs/state-{date_str}.json", 'w') as f:
    json.dump(state_json, f, cls=NpEncoder)

# %%
with open(f"logs/data_logs/county-{date_str}.json", 'w') as f:
    json.dump(county_json, f, cls=NpEncoder)
